# %% [markdown]
# # Data Preprocessing Summary
#
# The purpose of this notebook is to process and prepare data from the original EEA source for modeling. This involves making decisions regarding the handling of missing values, outliers, and the exclusion of specific columns, rows and categories. The considerations behind the decisions are explained in Report3_CO2.pdf.
#
# Data Source: [European Environment Agency (EEA)](https://www.eea.europa.eu/en/datahub/datahubitem-view/fa8b1229-3db6-495d-b18e-9c9b3267c02b)
#
# ### Preprocessing Steps Overview
#
# **Data Loading**
# - Downloaded yearly CSV files (2010-2023) from EEA.
# - Loaded data per year, optimized data types, and removed duplicates by creating a frequency column to store the count of similar vehicle entries.
#
# **Data Cleaning**
# - Converted non-standard or inconsistent categories in select columns (e.g., Country, Fuel Type) using a dictionary-mapping function.
# - Parsed and extracted individual codes in the "IT" column (Innovative Technologies) and split them across five columns to support multi-code entries.
#
# **Data Transformation**
# - Memory Optimization: Converted numerical columns to `float32` and categorical columns to `category`.
# - Area Feature Creation: Combined wheelbase and axle widths to create an "Area (m²)" feature to capture vehicle footprint and potential aerodynamic effects.
#
# **Data Reduction**
# - Filtered dataset to include only data from 2019 onward for the largest three countries (DE, FR, IT).
# - Dropped all electric and hybrid vehicles for focused CO₂ emissions prediction.
#
# **Attribute Selection**
# - Retained relevant technical features for CO₂ emissions prediction, excluding highly collinear features like fuel consumption and redundant metrics (e.g., obsolete standard "Enedc").
# - Categorical attributes kept: Manufacturer (`Mh`), Vehicle Category (`Ct`), Fuel Type (`Ft`), Fuel Mode (`Fm`), and Innovative Technologies (`IT`).
# - Numerical attributes kept: Test Mass (`Mt`), Engine Power (`ep`), Engine Capacity (`ec`), Axle Width (`At1`), and Area (`Area`).
#
# **Category Reduction**
# - Automatically reduced categories using parameters for top frequency (`top_n`) and minimum representation (`min_cat_percent`), relabeling infrequent categories as "Other."
#
# **Outlier Handling**
# - Replaced outliers in Gaussian-distributed attributes with the median, while capping non-Gaussian attributes.
# - Applied Box-Cox transformations to skewed attributes ( `ep (KW)` and `ec (cm3)`) to adjust distribution and reduce outlier sensitivity.
#
# **NaN Handling**
# - Dropped rows with missing values, except in the "IT" column where NaNs were expected (not every car has ITs built in)
#
# **Encoding**
# - One-hot encoded categorical variables, excluding one category to avoid multicollinearity.
# - Encoded each distinct "IT" code as a separate indicator variable.
#
# **Final Data Aggregation**
# - Dropped duplicates, recording occurrences in a frequency column to maintain dataset distribution.
# - The final dataset contains ~14 million rows, reduced to ~300 MB on disk and ~1.6 GB in memory.
#
# **Batch Processing**
# - A batch processing function (`process_datasets`) enables automated preprocessing variations across different parameters, such as `top_n`, `min_cat_percent` for category selection, and IQR multipliers for outlier handling. This function streamlines the creation of multiple dataset versions with controlled adjustments.

# %% [markdown]
# # Importing necessary libraries

# %%
# Import the required libraries

# Data manipulation and math operations
import pandas as pd
import numpy as np
import re
import pyarrow.parquet as pq  # For working with parquet files

# Visualization libraries
import matplotlib.pyplot as plt  # For Matplotlib visualizations
import seaborn as sns            # For Seaborn visualizations
#import plotly.express as px      # For interactive visualizations with Plotly
# %matplotlib inline  # Uncomment for Jupyter notebooks to display plots inline

# System libraries
import warnings
import sys
import os
# Ignore all warnings (useful for ignoring non-critical warnings)
warnings.filterwarnings("ignore")

# Add the src directory to the system path
src_path = os.path.abspath(os.path.join('..', 'src'))
# for g-colab a cloned repo under MyDrive is assumed : /
if os.getcwd() == "/content": src_path =  "/content/drive/MyDrive/aug24_bds_int---co2/src"
if src_path not in sys.path: sys.path.append(src_path)
# Path to the neighboring 'data' folder in the local repository
data_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))

# Import utils library with custom functions
from utils_CO2 import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1.A Initial loading and processing of Raw Data

# %% [markdown]
# ## Loading individual years

# %%
# This is the routine that was used to convert the csvs of all years one by one

# 1. Read Dataframe from csv and specify datatypes

# 2. Optimize dataypes for memory usage

# 3. Fill all missing values in all columns with nanplaceholder
# This seemed necessary in order to be able to compare rows to count and remove duplicates. I encountered
# problems before: the comparison didnt work because NaN != NaN

# 4. Count number of identical occurences and write in new column, then remove dupes to save space

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# set option so that e.g. df.head() will show all columns and none are omitted 
pd.set_option('display.max_columns', None)

import os
print("Current working directory: ", os.getcwd())

# Specify the year
year = "2022"  # Change this to the desired year

# Define file paths based on the year
csv_file_path = f"..\\Data\\EU\\EU {year}.csv"
parquet_file_path = f"..\\Data\\EU\\EU {year}_dtypes.parquet"
parquet_nanplaceholder_path = f"..\\Data\\EU\\EU {year}_dtypes_nanplaceholder.parquet"
parquet_dupecounts_reduced_path = f"..\\Data\\EU\\EU {year}_dtypes_nanplaceholder_dupecounts_reduced.parquet"

# 1. Read Dataframe from csv and specify datatypes. "category" for all string values reduces memory usage a lot.
df = pd.read_csv(csv_file_path, dtype={
    'ID': 'Int32',
    'Country': 'category',
    'VFN': 'category',
    'Mp': 'category',
    'Mh': 'category',
    'Man': 'category',
    'MMS': 'category',
    'Tan': 'category',
    'T': 'category',
    'Va': 'category',
    'Ve': 'category',
    'Mk': 'category',
    'Cn': 'category',
    'Ct': 'category',
    'Cr': 'category',
    'r': 'Int32',
    'm (kg)': 'Int32',
    'Mt': 'Int32',
    'Enedc (g/km)': 'Int32',
    'Ewltp (g/km)': 'Int32',
    'W (mm)': 'Int32',
    'At1 (mm)': 'Int32',
    'At2 (mm)': 'Int32',
    'Ft': 'category',
    'Fm': 'category',
    'ec (cm3)': 'Int32',
    'ep (KW)': 'Int32',
    'z (Wh/km)': 'Int32',
    'IT': 'category',
    'Ernedc (g/km)': 'Float64',
    'Erwltp (g/km)': 'Float64',
    'De': 'Float64',
    'Vf': 'Int32',
    'Status': 'category',
    'year': 'Int32',
    'Date of registration': 'category',
    'Fuel consumption ': 'Float64',
    'ech': 'category',
    'RLFI': 'category',
    'Electric range (km)': 'Int32',
})

print(f"Dataframe for year {year} has been read from CSV and datatypes specified:")
print(df.info())

#----------------------------------------------------------------------------------
# 2. Optimize dataypes for memory usage

def optimize_dtypes(df):
    # Calculate total memory usage before optimization
    before_mem = df.memory_usage(deep=True).sum()
    print(f"Total memory usage before optimization: {before_mem / 1024**2:.2f} MB")
    
    # Downcast integer columns in place
    int_cols = df.select_dtypes(include='int').columns
    df[int_cols] = df[int_cols].apply(pd.to_numeric, downcast='integer')
    
    # Downcast float columns in place
    float_cols = df.select_dtypes(include='float').columns
    df[float_cols] = df[float_cols].apply(pd.to_numeric, downcast='float')
    
    # Calculate total memory usage after optimization
    after_mem = df.memory_usage(deep=True).sum()
    print(f"Total memory usage after optimization: {after_mem / 1024**2:.2f} MB")
    
optimize_dtypes(df)

# Save to parquet format (is able to store categorized data in its reduced format)
df.to_parquet(parquet_file_path)
print(f"Dataframe with optimized datatypes has been saved as parquet to {parquet_file_path}")


#-----------------------------------------------------------
# 3. Fill all missing values in all columns with nanplaceholder

# Check for values < -50 to see if nanplaceholder -99 is ok

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# If there are no values less than -50 in any row of any column, proceed to fill NaNs with placeholders
if not (numeric_df < -50).any().any():
    nanplaceholder_num = -99
    nanplaceholder_str = str(nanplaceholder_num)

    # Handle categorical columns
    for col in df.select_dtypes(include=["category", "object"]).columns:
        # Add the placeholder to the category if it's not already present
        df[col] = df[col].cat.add_categories([nanplaceholder_str])
        # Fill NaNs with nanplaceholder_str
        df[col].fillna(nanplaceholder_str, inplace=True)

    # Handle numerical columns
    for col in df.select_dtypes(include='number').columns:
        # Fill NaNs with nanplaceholder_num
        df[col].fillna(nanplaceholder_num, inplace=True)
else:
    # Print warning message
    print("Warning: There are values less than -50 in the numeric columns. Cannot use -99 as NaN placeholder.")

    
# save again
df.to_parquet(parquet_nanplaceholder_path)
print(f"Dataframe NaNs have been filled with placeholder \"{nanplaceholder_num}\" and saved to {parquet_nanplaceholder_path}")


#-----------------------------------------------------------
# 4. Count number of identical occurences and write in new column, then remove dupes

# i) specify the columns to be grouped by, i.e the ones that have to be identical in order to be counted
# excluding "Date of Registration" and "ID" ==> they don't have to be identical 
group_cols = [col for col in df.columns if col != "Date of registration" and col != "ID"]

# ii) count number of members in the group, i..e. number of identical occurences and add as new column
df['#identical occurences'] = df.groupby(group_cols)['ID'].transform('count')  

print("Dataframe duplicate counts have been calculated.")

# iii) remove dupes
df = df.drop_duplicates(subset = group_cols, keep = "first")

# save again
df.to_parquet(parquet_dupecounts_reduced_path)
print(f"Duplicates have been dropped and dataframe saved to {parquet_dupecounts_reduced_path}")
#----------------------------------------------------------------------------------

print(df.info())
print(df.head())

# %% [markdown]
# ## Merging all years into single dataframe

# %%
# as a prerequisit before merging (concatenating) the DFs, check if all rows are labeled with the correct year

for year in ["2010-2015"] + [str(x) for x in range(2016,2024)]:
    # load latest version of year file
    parquet_dupecounts_reduced_path = f"..\\Data\\EU\\EU {year}_dtypes_nanplaceholder_dupecounts_reduced.parquet"
    df = pd.read_parquet(parquet_dupecounts_reduced_path)
    
    # check, which years are in the file (value of the coumn "year")
    years_in_year = df["year"].value_counts()
    print(f"In the dataset for {year} these are the values of the \"year\" column: \n{years_in_year}")
    # check how many rows have any year specified
    rows_labeled_with_a_year = df["year"].value_counts().sum()
    print(f"There are {len(df)} rows in the dataset altogether and {rows_labeled_with_a_year} entries for \"year\".\n")

# %%
# Join all years vertically

EU_dfs = []

for year in ["2010-2015"] + [str(x) for x in range(2016, 2024)]:
    parquet_dupecounts_reduced_path = f"..\\Data\\EU\\EU {year}_dtypes_nanplaceholder_dupecounts_reduced.parquet"
    df = pd.read_parquet(parquet_dupecounts_reduced_path)
    EU_dfs.append(df)

EU_df = pd.concat(EU_dfs, axis = 0, ignore_index=True)

# %%
# Display number of rows per year in merged df (can visually compare to above counts before merge)
EU_df["year"].value_counts().sort_index()

# %% [markdown]
# ### save/load

# %%
# Save merged Dataframe
EU_df.to_parquet("..\Data\EU\EU all.parquet")

# %%
# load dataset
EU_df = pd.read_parquet("..\Data\EU\EU all.parquet")

# %%
EU_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14442792 entries, 0 to 14442791
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     Int32
#  1   Country                object
#  2   VFN                    object
#  3   Mp                     object
#  4   Mh                     object
#  5   Man                    object
#  6   MMS                    object
#  7   Tan                    object
#  8   T                      object
#  9   Va                     object
#  10  Ve                     object
#  11  Mk                     object
#  12  Cn                     object
#  13  Ct                     object
#  14  Cr                     object
#  15  r                      Int32
#  16  m (kg)                 Int16
#  17  Mt                     Int16
#  18  Enedc (g/km)           Int16
#  19  Ewltp (g/km)           Int16
#  20  W (mm)                 Int16
#  21  At1 (mm)               Int16
#  22  At2 (mm)               Int16
#  23  Ft                     object
#  24  Fm                     object
#  25  ec (cm3)               Int32
#  26  ep (KW)                Int16
#  27  z (Wh/km)              Int16
#  28  IT                     object
#  29  Ernedc (g/km)          Float32
#  30  Erwltp (g/km)          Float32
#  31  De                     Float32
#  32  Vf                     Int8
#  33  Status                 category
#  34  year                   Int16
#  35  Date of registration   object
#  36  Fuel consumption       Float32
#  37  ech                    object
#  38  RLFI                   object
#  39  Electric range (km)    Int16
#  40  #identical occurences  int64
# dtypes: Float32(4), Int16(11), Int32(3), Int8(1), category(1), int64(1), object(20)
# memory usage: 3.2+ GB

# %% [markdown]
# ## Optimize datatypes

# %%
# Optimize memory usage by checking if after the merge any column (dataype) can still be optimized/reduced

EU_df = optimize_dtypes(EU_df)
# Out:
# Total memory usage before optimization: 18782.69 MB
# Converted 20 object columns to 'category' dtype.
# Downcasted 4 integer columns.
# Downcasted 4 float columns.
# Total memory usage after optimization: 1616.06 MB

# %%
EU_df.info()  

# shows that aside from object type being converted to category only #identical occurences was reduced from int64 to int16
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14442792 entries, 0 to 14442791
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     Int32
#  1   Country                category
#  2   VFN                    category
#  3   Mp                     category
#  4   Mh                     category
#  5   Man                    category
#  6   MMS                    category
#  7   Tan                    category
#  8   T                      category
#  9   Va                     category
#  10  Ve                     category
#  11  Mk                     category
#  12  Cn                     category
#  13  Ct                     category
#  14  Cr                     category
#  15  r                      Int32
#  16  m (kg)                 Int16
#  17  Mt                     Int16
#  18  Enedc (g/km)           Int16
#  19  Ewltp (g/km)           Int16
#  20  W (mm)                 Int16
#  21  At1 (mm)               Int16
#  22  At2 (mm)               Int16
#  23  Ft                     category
#  24  Fm                     category
#  25  ec (cm3)               Int32
#  26  ep (KW)                Int16
#  27  z (Wh/km)              Int16
#  28  IT                     category
#  29  Ernedc (g/km)          Float32
#  30  Erwltp (g/km)          Float32
#  31  De                     Float32
#  32  Vf                     Int8
#  33  Status                 category
#  34  year                   Int16
#  35  Date of registration   category
#  36  Fuel consumption       Float32
#  37  ech                    category
#  38  RLFI                   category
#  39  Electric range (km)    Int16
#  40  #identical occurences  int16
# dtypes: Float32(4), Int16(11), Int32(3), Int8(1), category(21), int16(1)
# memory usage: 1.5 GB

# %% [markdown]
# ### save/load

# %%
# Save again
EU_df.to_parquet("..\Data\EU\EU all_dtypes.parquet")

# %%
EU_df = pd.read_parquet("..\..\data\EU\EU all_dtypes.parquet")

# %% [markdown]
# ## Standardize NaN represantation

# %% [markdown]
# ### check Missing/NaN

# %%
check_missing_value_markers(df)
# Out:
#                    Column  np.nan  pd.NA       -99     "-99"
# 0                      ID       0      0         0         0
# 1                 Country       0      0         0         0
# 2                     VFN       0      0         0   6022343
# 3                      Mp       0      0         0   1538457
# 4                      Mh       0      0         0         0
# 5                     Man       0      0         0    310768
# 6                     MMS       0      0         0   6048284
# 7                     Tan       0      0         0    490543
# 8                       T       0      0         0     62037
# 9                      Va       0      0         0    100484
# 10                     Ve       0      0         0    225223
# 11                     Mk       0      0         0     42908
# 12                     Cn       0      0         0     49370
# 13                     Ct       0      0         0     24689
# 14                     Cr       0      0         0   2811048
# 15                      r       0      0         4         0
# 16                 m (kg)       0      0     14075         0
# 17                     Mt       0      0   3802983         0
# 18           Enedc (g/km)       0      0   5466691         0
# 19           Ewltp (g/km)       0      0   3565598         0
# 20                 W (mm)       0      0   2252091         0
# 21               At1 (mm)       0      0   2523206         0
# 22               At2 (mm)       0      0   2738433         0
# 23                     Ft       0      0         0      6689
# 24                     Fm       0      0         0     80678
# 25               ec (cm3)       0      0    613895         0
# 26                ep (KW)       0      0   1401419         0
# 27              z (Wh/km)       0      0  13141566         0
# 28                     IT       0      0         0   9564034
# 29          Ernedc (g/km)       0      0  12638415         0
# 30          Erwltp (g/km)       0      0  11588146         0
# 31                     De       0      0  14116055         0
# 32                     Vf       0      0  13299530         0
# 33                 Status       0      0         0         0
# 34                   year       0      0         0         0
# 35   Date of registration       0      0         0   9206861
# 36      Fuel consumption        0      0  10470116         0
# 37                    ech       0      0         0  13991213
# 38                   RLFI       0      0         0  13685744
# 39    Electric range (km)       0      0  13347797         0
# 40  #identical occurences       0      0         0         0

# %% [markdown]
# ### convert missing and dtypes

# %%
# Convert all missing values (-99, "-99") to np.nan for numerical values and pd.NA for categorical, respectively
# For 'ID' and 'year', handle missing values appropriately and convert to Int64 data type
# Also make all numerical cols float32 (can handle np.nan).
# This increases memory usage slightly but gives better consistency and compatibility with numpy, pandas and other libraries


df = optimize_nan_handling(df)
# Out:
# Total memory usage before optimization: 1616.06 MB
# Numerical columns to be converted: ['r', 'm (kg)', 'Mt', 'Enedc (g/km)', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'ec (cm3)', 'ep (KW)', 'z (Wh/km)', 'Ernedc (g/km)', 'Erwltp (g/km)', 'De', 'Vf', 'Fuel consumption ', 'Electric range (km)', '#identical occurences']
# Column 'r' converted to float32.
# Column 'm (kg)' converted to float32.
# Column 'Mt' converted to float32.
# Column 'Enedc (g/km)' converted to float32.
# Column 'Ewltp (g/km)' converted to float32.
# Column 'W (mm)' converted to float32.
# Column 'At1 (mm)' converted to float32.
# Column 'At2 (mm)' converted to float32.
# Column 'ec (cm3)' converted to float32.
# Column 'ep (KW)' converted to float32.
# Column 'z (Wh/km)' converted to float32.
# Column 'Ernedc (g/km)' converted to float32.
# Column 'Erwltp (g/km)' converted to float32.
# Column 'De' converted to float32.
# Column 'Vf' converted to float32.
# Column 'Fuel consumption ' converted to float32.
# Column 'Electric range (km)' converted to float32.
# Column '#identical occurences' converted to float32.
# Column 'ID' processed for missing values with Int64 dtype.
# Column 'year' processed for missing values with Int64 dtype.
# Category columns: ['Country', 'VFN', 'Mp', 'Mh', 'Man', 'MMS', 'Tan', 'T', 'Va', 'Ve', 'Mk', 'Cn', 'Ct', 'Cr', 'Ft', 'Fm', 'IT', 'Status', 'Date of registration', 'ech', 'RLFI']
# Column 'Country' processed for missing values.
# Column 'VFN' processed for missing values.
# Column 'Mp' processed for missing values.
# Column 'Mh' processed for missing values.
# Column 'Man' processed for missing values.
# Column 'MMS' processed for missing values.
# Column 'Tan' processed for missing values.
# Column 'T' processed for missing values.
# Column 'Va' processed for missing values.
# Column 'Ve' processed for missing values.
# Column 'Mk' processed for missing values.
# Column 'Cn' processed for missing values.
# Column 'Ct' processed for missing values.
# Column 'Cr' processed for missing values.
# Column 'Ft' processed for missing values.
# Column 'Fm' processed for missing values.
# Column 'IT' processed for missing values.
# Column 'Status' processed for missing values.
# Column 'Date of registration' processed for missing values.
# Column 'ech' processed for missing values.
# Column 'RLFI' processed for missing values.
# Object columns: []
#
# Data types after conversion:
# ID                          Int64
# Country                  category
# VFN                      category
# Mp                       category
# Mh                       category
# Man                      category
# MMS                      category
# Tan                      category
# T                        category
# Va                       category
# Ve                       category
# Mk                       category
# Cn                       category
# Ct                       category
# Cr                       category
# r                         float32
# m (kg)                    float32
# Mt                        float32
# Enedc (g/km)              float32
# Ewltp (g/km)              float32
# W (mm)                    float32
# At1 (mm)                  float32
# At2 (mm)                  float32
# Ft                       category
# Fm                       category
# ec (cm3)                  float32
# ep (KW)                   float32
# z (Wh/km)                 float32
# IT                       category
# Ernedc (g/km)             float32
# Erwltp (g/km)             float32
# De                        float32
# Vf                        float32
# Status                   category
# year                        Int64
# Date of registration     category
# Fuel consumption          float32
# ech                      category
# RLFI                     category
# Electric range (km)       float32
# #identical occurences     float32
# dtype: object
#
# Total memory usage after optimization: 1863.98 MB
# Memory usage difference: 247.93 MB

# %% [markdown]
# ### check if NaN conversion successfull

# %%
# Check if conversion successfull
# Therefore again print number of pd.NA, np.nan, -99, "-99"
check_missing_value_markers(df)
# Out:
#                    Column    np.nan     pd.NA  -99  "-99"
# 0                      ID         0         0    0      0
# 1                 Country         0         0    0      0
# 2                     VFN         0   6022343    0      0
# 3                      Mp         0   1538457    0      0
# 4                      Mh         0         0    0      0
# 5                     Man         0    310768    0      0
# 6                     MMS         0   6048284    0      0
# 7                     Tan         0    490543    0      0
# 8                       T         0     62037    0      0
# 9                      Va         0    100484    0      0
# 10                     Ve         0    225223    0      0
# 11                     Mk         0     42908    0      0
# 12                     Cn         0     49370    0      0
# 13                     Ct         0     24689    0      0
# 14                     Cr         0   2811048    0      0
# 15                      r         4         0    0      0
# 16                 m (kg)     14075         0    0      0
# 17                     Mt   3802983         0    0      0
# 18           Enedc (g/km)   5466691         0    0      0
# 19           Ewltp (g/km)   3565598         0    0      0
# 20                 W (mm)   2252091         0    0      0
# 21               At1 (mm)   2523206         0    0      0
# 22               At2 (mm)   2738433         0    0      0
# 23                     Ft         0      6689    0      0
# 24                     Fm         0     80678    0      0
# 25               ec (cm3)    613895         0    0      0
# 26                ep (KW)   1401419         0    0      0
# 27              z (Wh/km)  13141566         0    0      0
# 28                     IT         0   9564034    0      0
# 29          Ernedc (g/km)  12638415         0    0      0
# 30          Erwltp (g/km)  11588146         0    0      0
# 31                     De  14116055         0    0      0
# 32                     Vf  13299530         0    0      0
# 33                 Status         0         0    0      0
# 34                   year         0         0    0      0
# 35   Date of registration         0   9206861    0      0
# 36      Fuel consumption   10470116         0    0      0
# 37                    ech         0  13991213    0      0
# 38                   RLFI         0  13685744    0      0
# 39    Electric range (km)  13347797         0    0      0
# 40  #identical occurences         0         0    0      0

# %% [markdown]
# ### save

# %%
# Save again

EU_df.to_parquet("..\data\EU\EU all_dtypes_NaN_float32_Int64.parquet")

# %% [markdown]
# # 1.B Renaming/Mapping Categories

# %% [markdown]
# ## **Import and read df**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from utils_CO2 import *

# set option so that e.g. df.head() will show all columns and none are omitted
pd.set_option('display.max_columns', None)

# %%
# read latest version of df
df = pd.read_parquet("..\\data\\EU\\EU all_dtypes_NaN_float32_Int64.parquet")

# %%
inspect_data(df)
# Out:
# ========================================
# 🚀 Basic Data Overview
# ========================================
# 🗂 Shape of the DataFrame: 14442792 rows, 41 columns
#
# 🔍 First 5 rows of the DataFrame:
#        ID Country  VFN              Mp              Mh  \
# 0  280060      UK  NaN             NaN         UNKNOWN
# 1  280060      GB  NaN             NaN         AUDI AG
# 2  280060      PL  NaN     VW GROUP PC      VOLKSWAGEN
# 3  280060      HU  NaN             NaN  HYUNDAI ASSAN
# 4  280060      HU  NaN  GENERAL MOTORS            OPEL
#
#                                 Man       MMS                  Tan  \
# 0                           UNKNOWN  VAUXHALL                  NaN
# 1                               NaN      AUDI                  NaN
# 2                     VOLKSWAGEN AG       NaN  E1*2001/116*0211*27
# 3  HYUNDAI ASSAN OTOMOTIV SANAYI VE   Hyundai  e11*2007/46*0192*04
# 4                      ADAM OPEL AG      Opel   e1*2007/46*0374*14
#
#              T       Va                       Ve              Mk  \
# 0  A-H/MONOCAB     BF11              2A05ASXEGA7        VAUXHALL
# 1           B8  LCAKAQ1      QM6B4006R8K927MGEM0            AUDI
# 2           1T   CFHCAF  FD6FD62E0187MQS7N1VR0S0      VOLKSWAGEN
# 3          ELH    F5D31                   M65AZ1  HYUNDAI ASSAN
# 4         0G-A  CAHBC12               BA1N1FMHD5            Opel
#
#                          Cn  Ct   Cr     r  m (kg)  Mt  Enedc (g/km)  \
# 0  ZAFIRA SRI XP 150 CDTI A  M1  NaN  14.0  1613.0 NaN         191.0
# 1              S4 T QUATTRO  M1  NaN   3.0  1735.0 NaN           NaN
# 2                    TOURAN  M1  NaN   1.0  1629.0 NaN         131.0
# 3                      ix35  M1  NaN   1.0  1500.0 NaN         139.0
# 4     Insignia Limousine HB  M1  NaN   4.0  1613.0 NaN         114.0
#
#    Ewltp (g/km)  W (mm)  At1 (mm)  At2 (mm)      Ft Fm  ec (cm3)  ep (KW)  \
# 0           NaN  2703.0    1488.0    1512.0  diesel  M    1910.0      NaN
# 1           NaN     NaN       NaN       NaN  petrol  M    2995.0      NaN
# 2           NaN  2675.0    1794.0    1794.0  DIESEL  M    1968.0    103.0
# 3           NaN  2640.0    1585.0    1586.0  Diesel  M    1685.0     85.0
# 4           NaN  2737.0    1587.0    1590.0  Diesel  M    1956.0    120.0
#
#    z (Wh/km)   IT  Ernedc (g/km)  Erwltp (g/km)  De  Vf Status  year  \
# 0        NaN  NaN            NaN            NaN NaN NaN      P  2010
# 1        NaN  NaN            NaN            NaN NaN NaN      P  2011
# 2        NaN  NaN            NaN            NaN NaN NaN      P  2012
# 3        NaN  NaN            NaN            NaN NaN NaN      P  2013
# 4        NaN  NaN            NaN            NaN NaN NaN      P  2014
#
#   Date of registration  Fuel consumption   ech RLFI  Electric range (km)  \
# 0                  NaN                NaN  NaN  NaN                  NaN
# 1                  NaN                NaN  NaN  NaN                  NaN
# 2                  NaN                NaN  NaN  NaN                  NaN
# 3                  NaN                NaN  NaN  NaN                  NaN
# 4                  NaN                NaN  NaN  NaN                  NaN
#
#    #identical occurences
# 0                    1.0
# 1                    1.0
# 2                    1.0
# 3                   30.0
# 4                    1.0
#
# 📊 DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14442792 entries, 0 to 14442791
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     Int64
#  1   Country                category
#  2   VFN                    category
#  3   Mp                     category
#  4   Mh                     category
#  5   Man                    category
#  6   MMS                    category
#  7   Tan                    category
#  8   T                      category
#  9   Va                     category
#  10  Ve                     category
#  11  Mk                     category
#  12  Cn                     category
#  13  Ct                     category
#  14  Cr                     category
#  15  r                      float32
#  16  m (kg)                 float32
#  17  Mt                     float32
#  18  Enedc (g/km)           float32
#  19  Ewltp (g/km)           float32
#  20  W (mm)                 float32
#  21  At1 (mm)               float32
#  22  At2 (mm)               float32
#  23  Ft                     category
#  24  Fm                     category
#  25  ec (cm3)               float32
#  26  ep (KW)                float32
#  27  z (Wh/km)              float32
#  28  IT                     category
#  29  Ernedc (g/km)          float32
#  30  Erwltp (g/km)          float32
#  31  De                     float32
#  32  Vf                     float32
#  33  Status                 category
#  34  year                   Int64
#  35  Date of registration   category
#  36  Fuel consumption       float32
#  37  ech                    category
#  38  RLFI                   category
#  39  Electric range (km)    float32
#  40  #identical occurences  float32
# dtypes: Int64(2), category(21), float32(18)
# memory usage: 1.8 GB
#
# 📈 Summary Statistics of Numeric Columns:
#                     ID             r        m (kg)            Mt  \
# count       14442792.0  1.444279e+07  1.442872e+07  1.063981e+07
# mean    35442140.89188  7.544409e+00  1.634169e+03  1.799300e+03
# std    44079806.984158  1.099097e+02  3.443328e+02  3.689104e+02
# min                1.0  1.000000e+00  1.000000e+00  0.000000e+00
# 25%         1901050.75  1.000000e+00  1.393000e+03  1.533000e+03
# 50%          9007275.0  1.000000e+00  1.590000e+03  1.748000e+03
# 75%         65014533.0  1.000000e+00  1.825000e+03  2.003000e+03
# max        149695043.0  5.909200e+04  9.928000e+03  6.612000e+03
#
#        Enedc (g/km)  Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)  \
# count  8.976101e+06  1.087719e+07  1.219070e+07  1.191959e+07  1.170436e+07
# mean   1.275489e+02  1.424030e+02  2.742043e+03  1.572893e+03  1.572726e+03
# std    4.481242e+01  5.580564e+01  3.241919e+02  1.746379e+02  1.635476e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.550000e+02  0.000000e+00
# 25%    1.110000e+02  1.280000e+02  2.626000e+03  1.538000e+03  1.536000e+03
# 50%    1.270000e+02  1.460000e+02  2.700000e+03  1.569000e+03  1.570000e+03
# 75%    1.490000e+02  1.700000e+02  2.850000e+03  1.605000e+03  1.611000e+03
# max    9.850000e+02  7.300000e+02  6.100000e+03  5.361000e+03  1.583000e+04
#
#            ec (cm3)       ep (KW)     z (Wh/km)  Ernedc (g/km)  Erwltp (g/km)  \
# count  1.382890e+07  1.304137e+07  1.301226e+06   1.804377e+06   2.854646e+06
# mean   1.829225e+03  1.297542e+02  1.910682e+02   1.920890e+00   1.524807e+00
# std    6.009905e+02  6.176083e+01  5.642786e+01   8.527987e-01   4.958403e-01
# min    0.000000e+00  0.000000e+00  1.000000e+00   0.000000e+00   0.000000e+00
# 25%    1.496000e+03  9.200000e+01  1.600000e+02   1.200000e+00   1.100000e+00
# 50%    1.950000e+03  1.100000e+02  1.770000e+02   1.700000e+00   1.660000e+00
# 75%    1.995000e+03  1.430000e+02  2.150000e+02   2.600000e+00   1.950000e+00
# max    8.463800e+04  1.770000e+03  2.756000e+03   9.200000e+00   2.000000e+01
#
#                   De            Vf         year  Fuel consumption   \
# count  326737.000000  1.143262e+06   14442792.0       3.972676e+06
# mean        0.044491  4.228077e-02  2019.142349       5.787786e+00
# std         0.339691  1.983620e-01      3.21264       2.254286e+00
# min        -1.000000  0.000000e+00       2010.0       1.000000e-01
# 25%         0.001000  0.000000e+00       2018.0       5.000000e+00
# 50%         0.015000  0.000000e+00       2020.0       5.800000e+00
# 75%         0.030000  0.000000e+00       2022.0       6.800000e+00
# max         7.200000  2.000000e+00       2023.0       9.900000e+01
#
#        Electric range (km)  #identical occurences
# count         1.094995e+06           1.444279e+07
# mean          2.040938e+02           5.553494e+00
# std           1.918173e+02           5.717576e+01
# min           1.000000e+00           1.000000e+00
# 25%           5.600000e+01           1.000000e+00
# 50%           7.600000e+01           1.000000e+00
# 75%           4.120000e+02           2.000000e+00
# max           8.830000e+02           2.744900e+04
#
# ❓ Missing Values Overview:
#                           Dtype Missing Count Percent Missing
# ID                        Int64             0           0.00%
# Country                category             0           0.00%
# VFN                    category       6022343          41.70%
# Mp                     category       1538457          10.65%
# Mh                     category             0           0.00%
# Man                    category        310768           2.15%
# MMS                    category       6048284          41.88%
# Tan                    category        490543           3.40%
# T                      category         62037           0.43%
# Va                     category        100484           0.70%
# Ve                     category        225223           1.56%
# Mk                     category         42908           0.30%
# Cn                     category         49370           0.34%
# Ct                     category         24689           0.17%
# Cr                     category       2811048          19.46%
# r                       float32             4           0.00%
# m (kg)                  float32         14075           0.10%
# Mt                      float32       3802983          26.33%
# Enedc (g/km)            float32       5466691          37.85%
# Ewltp (g/km)            float32       3565598          24.69%
# W (mm)                  float32       2252091          15.59%
# At1 (mm)                float32       2523206          17.47%
# At2 (mm)                float32       2738433          18.96%
# Ft                     category          6689           0.05%
# Fm                     category         80678           0.56%
# ec (cm3)                float32        613895           4.25%
# ep (KW)                 float32       1401419           9.70%
# z (Wh/km)               float32      13141566          90.99%
# IT                     category       9564034          66.22%
# Ernedc (g/km)           float32      12638415          87.51%
# Erwltp (g/km)           float32      11588146          80.23%
# De                      float32      14116055          97.74%
# Vf                      float32      13299530          92.08%
# Status                 category             0           0.00%
# year                      Int64             0           0.00%
# Date of registration   category       9206861          63.75%
# Fuel consumption        float32      10470116          72.49%
# ech                    category      13991213          96.87%
# RLFI                   category      13685744          94.76%
# Electric range (km)     float32      13347797          92.42%
# #identical occurences   float32             0           0.00%
#
# 🔑 Unique Values in Categorical/Object Columns:
# Column 'Country' has 31 unique values
# Column 'VFN' has 29048 unique values
# Column 'Mp' has 46 unique values
# Column 'Mh' has 261 unique values
# Column 'Man' has 477 unique values
# Column 'MMS' has 11561 unique values
# Column 'Tan' has 64236 unique values
# Column 'T' has 26611 unique values
# Column 'Va' has 72533 unique values
# Column 'Ve' has 182640 unique values
# Column 'Mk' has 1745 unique values
# Column 'Cn' has 80814 unique values
# Column 'Ct' has 16 unique values
# Column 'Cr' has 8 unique values
# Column 'Ft' has 54 unique values
# Column 'Fm' has 14 unique values
# Column 'IT' has 1928 unique values
# Column 'Status' has 1 unique values
# Column 'Date of registration' has 1095 unique values
# Column 'ech' has 36 unique values
# Column 'RLFI' has 1544 unique values

# %% [markdown]
# ## **Inspect categories**

# %%
# First, inspect the unique categories in each categorical column
for col in df.select_dtypes(include=['category']):
    num_categories = df[col].nunique(dropna=False)
    print(f"Column '{col}' has {num_categories} unique categorical values (including NaN).")
# Out:
# Column 'Country' has 31 unique categorical values (including NaN).
# Column 'VFN' has 29049 unique categorical values (including NaN).
# Column 'Mp' has 47 unique categorical values (including NaN).
# Column 'Mh' has 261 unique categorical values (including NaN).
# Column 'Man' has 478 unique categorical values (including NaN).
# Column 'MMS' has 11562 unique categorical values (including NaN).
# Column 'Tan' has 64237 unique categorical values (including NaN).
# Column 'T' has 26612 unique categorical values (including NaN).
# Column 'Va' has 72534 unique categorical values (including NaN).
# Column 'Ve' has 182641 unique categorical values (including NaN).
# Column 'Mk' has 1746 unique categorical values (including NaN).
# Column 'Cn' has 80815 unique categorical values (including NaN).
# Column 'Ct' has 17 unique categorical values (including NaN).
# Column 'Cr' has 9 unique categorical values (including NaN).
# Column 'Ft' has 55 unique categorical values (including NaN).
# Column 'Fm' has 15 unique categorical values (including NaN).
# Column 'IT' has 1929 unique categorical values (including NaN).
# Column 'Status' has 1 unique categorical values (including NaN).
# Column 'Date of registration' has 1096 unique categorical values (including NaN).
# Column 'ech' has 37 unique categorical values (including NaN).
# Column 'RLFI' has 1545 unique categorical values (including NaN).

# %% [markdown]
# ## **Tan (Type Approval number)**

# %%
# In column "Tan" (Type Approval number) fix inconsistent naming (capital "E" vs small "e")

# 1. Check how many of each

count_e = df.Tan.apply(lambda x: x.startswith("e")).sum()
count_E = df.Tan.apply(lambda x: x.startswith("E")).sum()

print(f"{count_e} times e, {count_E} times E, sum = {count_E+count_e}. #values in df: {len(df)}")
# Out:
# 8505255 times e, 5436932 times E, sum = 13942187. #values in df: 14442792

# %%
# 2. Change to consistent small "e"

df["Tan"] = df.Tan.apply(lambda x: "e" + x[1:] if x.startswith("E") else x).astype("category")

# %%
# 3. Check if conversion successful

count_e = df.Tan.apply(lambda x: x.startswith("e")).sum()
count_E = df.Tan.apply(lambda x: x.startswith("E")).sum()

print(f"{count_e} times e, {count_E} times E, sum = {count_E+count_e}. #values in df: {len(df)}")
# Out:
# 13942187 times e, 0 times E, sum = 13942187. #values in df: 14442792

# %% [markdown]
# ## **Ct (Category of the vehicle type approved)**

# %%
# Inspect the categories and value counts of 'Ct'
print(df.Ct.cat.categories)
df.Ct.value_counts()
# Out:
# Index([' ', '  ', 'M1', 'M1 ', 'M1  ', 'M1G', 'M1G ', 'M2 ', 'N1', 'N1 ',
#        'N1G', 'N2', 'N2G', 'N3', 'N3G', 'm1'],
#       dtype='object')
# M1      13191645
# M1G       988772
# M1        189244
# M1         20165
# m1         15709
# N1          7752
# M1G         4550
# N1G          114
# N2            73
# N1            27
#               20
# N3            19
# N2G           10
#                1
# M2             1
# N3G            1
# Name: Ct, dtype: int64

# %%
df[df.Ct == 'm1'].year.value_counts()
# Out:
# 2017    15705
# 2021        4
# Name: year, dtype: Int64

# %%
df[df["year"] == 2017].Ct.value_counts()
# Out:
# M1      395054
# m1       15705
# M1G       9261
# M1        4077
# N1          35
# N2           9
# N1G          2
#              0
#              0
# M1           0
# M1G          0
# M2           0
# N1           0
# N2G          0
# N3           0
# N3G          0
# Name: Ct, dtype: int64

# %% [markdown]
# as it appears basically only in one year, "m1" seems to be a misspelling as well ==> rename to "M1"

# %%
# Define mappings for 'Ct'
mappings_ct = [
    ([' ', '  '], pd.NA),
    (['M1 ', 'M1  ', 'm1'], 'M1'),
    (['M1G '], 'M1G'),
    (['M2 '], 'M2'),
    (['N1 '], 'N1'),
]

# Apply the renaming to the 'Ct' column
rename_catval(df, "Ct", mappings_ct)
print(df.Ct.cat.categories)
df.Ct.value_counts()
# Out:
# Index(['M1', 'M1G', 'M2', 'N1', 'N1G', 'N2', 'N2G', 'N3', 'N3G'], dtype='string')
# M1     13416763
# M1G      993322
# N1         7779
# N1G         114
# N2           73
# N3           19
# N2G          10
# M2            1
# N3G           1
# Name: Ct, dtype: int64

# %% [markdown]
# ## **Cr (Category of the vehicle registered)**

# %%
# Inspect the categories and value counts of 'Cr'
print(df.Cr.cat.categories)
df.Cr.value_counts()
# Out:
# Index([' ', 'M1', 'M1 ', 'M1  ', 'M1G', 'M1G ', 'M1S', 'm1'], dtype='object')
# M1      10442199
# M1G       924140
# M1        224723
# M1         20165
#            15705
# M1G         4550
# m1           243
# M1S           19
# Name: Cr, dtype: int64

# %%
df[df.Cr == 'M1S'].year.value_counts()
# Out:
# 2022    19
# Name: year, dtype: Int64

# %% [markdown]
# only one year ==> probably misspelling of "M1G"

# %%
# Define mappings for 'Cr'
mappings_cr = [
    ([' ', '  '], pd.NA),
    (['M1 ', 'M1  ', 'm1'], 'M1'),
    (['M1G ', 'M1S'], 'M1G'),
]

# Apply the renaming to the 'Cr' column
rename_catval(df, "Cr", mappings_cr)
print(df.Cr.cat.categories)
df.Cr.value_counts()
# Out:
# Index(['M1', 'M1G'], dtype='string')
# M1     10687330
# M1G      928709
# Name: Cr, dtype: int64

# %% [markdown]
# ## **Fm (Fuel Mode)**

# %%
# Inspect the categories and value counts of 'Fm'
print(df.Fm.cat.categories)
df.Fm.value_counts()
# Out:
# Index(['2', 'Alimentazione Sconosciuta', 'B', 'E', 'F', 'F  ', 'H', 'M', 'M  ',
#        'P', 'h', 'm', 'na', 'p'],
#       dtype='object')
# M                            11486700
# H                             1370724
# P                              886030
# E                              538105
# B                               65385
# F                                7513
# na                               5194
# M                                2229
# m                                 188
# F                                  18
# p                                  17
# 2                                   7
# h                                   3
# Alimentazione Sconosciuta           1
# Name: Fm, dtype: int64

# %%
df[df.Fm == 'na'].Country.value_counts()
# Out:
# NL    5059
# IT      95
# DE      32
# MT       5
# RO       2
# FI       1
# AT       0
# SK       0
# SI       0
# SE       0
# PT       0
# PL       0
# NO       0
# LV       0
# LU       0
# LT       0
# IE       0
# IS       0
# BE       0
# HU       0
# HR       0
# GR       0
# GB       0
# FR       0
# ES       0
# EE       0
# DK       0
# CZ       0
# CY       0
# BG       0
# UK       0
# Name: Country, dtype: int64

# %%
df[df["Fm"].isna()]["Country"].value_counts()
# Out:
# NL    44926
# ES    29351
# MT     2886
# BG     2717
# PL      528
# BE      129
# DE       89
# UK       11
# FI       10
# RO        6
# CY        6
# SK        5
# LU        4
# IT        3
# GB        2
# PT        2
# DK        1
# GR        1
# SE        1
# SI        0
# NO        0
# AT        0
# LV        0
# LT        0
# IS        0
# HU        0
# HR        0
# FR        0
# EE        0
# CZ        0
# IE        0
# Name: Country, dtype: int64

# %% [markdown]
# "na"concentrated in the Netherlands where there is a lot of pd.NA ==> treat "na" as pd.NA

# %%
# Define mappings for 'Fm'
mappings_fm = [
    (['na', 'Alimentazione Sconosciuta', '2'], pd.NA),
    (['F  '], 'F'),
    (['M  ', 'm'], 'M'),
    (['h'], 'H'),
    (['p'], 'P'),
]

# Apply the renaming to the 'Fm' column
rename_catval(df, "Fm", mappings_fm)
print(df.Fm.cat.categories)
df.Fm.value_counts()
# Out:
# Index(['B', 'E', 'F', 'H', 'M', 'P'], dtype='string')
# M    11489117
# H     1370727
# P      886047
# E      538105
# B       65385
# F        7531
# Name: Fm, dtype: int64

# %% [markdown]
# ## **Ft (Fuel Type)**

# %%
# Inspect the categories and value counts of 'Ft'
print(df.Ft.cat.categories)
df.Ft.value_counts()
# Out:
# Index([' ', 'BIODIESEL', 'Biodiesel', 'DIESEL', 'DIESEL                   ',
#        'DIESEL-ELECTRIC', 'DIESEL/ELECTRIC', 'Diesel', 'Diesel-Electric',
#        'Diesel-electric', 'Diesel/Electric', 'Diesel/electric', 'E85',
#        'ELECTRIC', 'Electric', 'Electric                 ', 'HYDROGEN',
#        'Hydrogen', 'LPG', 'LPG                      ', 'NG', 'NG-BIOMETHANE',
#        'NG-Biomethane', 'NG-biomethane', 'NG-biomethane            ',
#        'NG_biomethane', 'OTHER', 'Other', 'PETROL', 'PETROL ',
#        'PETROL                   ', 'PETROL-ELECTRIC', 'PETROL/ELECTRIC',
#        'Petrol', 'Petrol ', 'Petrol-Electric', 'Petrol-Gas', 'Petrol-electric',
#        'Petrol/Electric', 'UNKNOWN', 'diesel', 'diesel-electric',
#        'diesel/electric', 'e85', 'electric', 'hydrogen', 'lpg', 'ng',
#        'ng-biomethane', 'petrol', 'petrol ', 'petrol-electric',
#        'petrol/electric', 'unknown'],
#       dtype='object')
# PETROL                       3322376
# DIESEL                       2945617
# petrol                       2228168
# diesel                       2003718
# Diesel                       1320232
# Petrol                       1006352
# PETROL/ELECTRIC               550171
# ELECTRIC                      296497
# petrol/electric               266837
# electric                      233016
# DIESEL/ELECTRIC                53038
# LPG                            40570
# diesel/electric                25681
# NG                             18718
#                                16995
# lpg                            14985
# Petrol/Electric                14454
# DIESEL                         12494
# Electric                       11011
# E85                             8766
# NG-biomethane                   8720
# ng                              8593
# NG-BIOMETHANE                   6440
# PETROL                          6059
# ng-biomethane                   4058
# Petrol-electric                 3371
# e85                             2391
# petrol-electric                 1583
# Petrol-Electric                 1045
# UNKNOWN                          666
# Diesel-electric                  493
# Diesel/Electric                  490
# diesel-electric                  357
# LPG                              345
# Diesel-Electric                  308
# Petrol                           306
# NG-biomethane                    230
# Electric                         188
# HYDROGEN                         155
# NG-Biomethane                     99
# hydrogen                          98
# Biodiesel                         90
# PETROL-ELECTRIC                   84
# petrol                            72
# Hydrogen                          61
# PETROL                            37
# unknown                           23
# DIESEL-ELECTRIC                   23
# Diesel/electric                    7
# OTHER                              5
# BIODIESEL                          4
# Other                              4
# Petrol-Gas                         1
# NG_biomethane                      1
# Name: Ft, dtype: int64

# %%
# Define mappings for 'Ft'
mappings_ft = [
    # Map 'PETROL' variants
    ([
        'PETROL', 'PETROL ', 'PETROL                   ', 'Petrol', 'Petrol ', 'petrol', 'petrol ', 'Petrol-Gas'
    ], 'PETROL'),
    # Map 'DIESEL' variants
    ([
        'DIESEL', 'DIESEL                   ', 'Diesel', 'diesel'
    ], 'DIESEL'),
    # Map 'PETROL/ELECTRIC' variants
    ([
        'PETROL-ELECTRIC', 'PETROL/ELECTRIC', 'Petrol-Electric', 'Petrol-electric',
        'Petrol/Electric', 'petrol-electric', 'petrol/electric'
    ], 'PETROL/ELECTRIC'),
    # Map 'DIESEL/ELECTRIC' variants
    ([
        'DIESEL-ELECTRIC', 'DIESEL/ELECTRIC', 'Diesel-Electric', 'Diesel-electric',
        'Diesel/Electric', 'Diesel/electric', 'diesel-electric', 'diesel/electric'
    ], 'DIESEL/ELECTRIC'),
    # Map 'ELECTRIC' variants
    ([
        'ELECTRIC', 'Electric', 'Electric                 ', 'electric'
    ], 'ELECTRIC'),
    # Map 'LPG' variants
    ([
        'LPG', 'LPG                      ', 'lpg'
    ], 'LPG'),
    # Map 'NG-BIOMETHANE' variants
    ([
        'NG-BIOMETHANE', 'NG-Biomethane', 'NG-biomethane', 'NG-biomethane            ',
        'NG_biomethane', 'ng-biomethane', 'NG', 'ng'
    ], 'NG-BIOMETHANE'),
    # Map 'HYDROGEN' variants
    ([
        'HYDROGEN', 'Hydrogen', 'hydrogen'
    ], 'HYDROGEN'),
    # Map 'E85' variants
    ([
        'E85', 'e85'
    ], 'E85'),
    # Map 'BIODIESEL' variants
    ([
        'BIODIESEL', 'Biodiesel'
    ], 'BIODIESEL'),
    # Map 'OTHER' variants
    ([
        'OTHER', 'Other'
    ], 'OTHER'),
    # Map unknown variants to pd.NA
    ([
        'UNKNOWN', 'unknown', ' '
    ], pd.NA),
]

# Apply the renaming to the 'Ft' column
rename_catval(df, "Ft", mappings_ft)
print(df.Ft.cat.categories)
df.Ft.value_counts(dropna=False)
# Out:
# Index(['BIODIESEL', 'DIESEL', 'DIESEL/ELECTRIC', 'E85', 'ELECTRIC', 'HYDROGEN',
#        'LPG', 'NG-BIOMETHANE', 'OTHER', 'PETROL', 'PETROL/ELECTRIC'],
#       dtype='string')
# PETROL             6563371
# DIESEL             6282061
# PETROL/ELECTRIC     837545
# ELECTRIC            540712
# DIESEL/ELECTRIC      80397
# LPG                  55900
# NG-BIOMETHANE        46859
# NaN                  24373
# E85                  11157
# HYDROGEN               314
# BIODIESEL               94
# OTHER                    9
# Name: Ft, dtype: int64

# %% [markdown]
# ## **Country**

# %%
# Inspect the categories and value counts of 'Country'
print(df.Country.cat.categories)
df.Country.value_counts(dropna=False)
# Out:
# Index(['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GB',
#        'GR', 'HR', 'HU', 'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO',
#        'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK'],
#       dtype='object')
# DE    4543321
# FR    1205514
# IT    1015799
# BE     953725
# GB     806369
# AT     740210
# PL     706497
# ES     705075
# NL     453097
# SE     400220
# CZ     382540
# LU     261769
# SK     258416
# HU     225802
# DK     218723
# PT     211956
# FI     206949
# RO     189734
# SI     154920
# GR     140088
# IE     108558
# BG      91622
# LT      74733
# EE      71633
# HR      69821
# UK      60569
# NO      57066
# LV      56635
# MT      37243
# CY      25292
# IS       8896
# Name: Country, dtype: int64

# %%
# Check GB and UK
print("UK:", df[df.Country == "UK"].year.value_counts())
print("GB:", df[df.Country == "GB"].year.value_counts())
# Out:
# UK: 2010    60569
# Name: year, dtype: Int64
# GB: 2019    203328
# 2020    147335
# 2018    107083
# 2011     59294
# 2012     58269
# 2016     48916
# 2017     48504
# 2013     45627
# 2014     44746
# 2015     43267
# Name: year, dtype: Int64

# %% [markdown]
# GB and UK are complementary ==> rename all to UK

# %%
# Define mappings for 'Country'
mappings_country = [
    (['GB'], 'UK'),
]

# Apply the renaming to the 'Country' column
rename_catval(df, "Country", mappings_country)
print(df.Country.cat.categories)
df.Country.value_counts()
# Out:
# Index(['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR',
#        'HR', 'HU', 'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL',
#        'PT', 'RO', 'SE', 'SI', 'SK', 'UK'],
#       dtype='string')
# DE    4543321
# FR    1205514
# IT    1015799
# BE     953725
# UK     866938
# AT     740210
# PL     706497
# ES     705075
# NL     453097
# SE     400220
# CZ     382540
# LU     261769
# SK     258416
# HU     225802
# DK     218723
# PT     211956
# FI     206949
# RO     189734
# SI     154920
# GR     140088
# IE     108558
# BG      91622
# LT      74733
# EE      71633
# HR      69821
# NO      57066
# LV      56635
# MT      37243
# CY      25292
# IS       8896
# Name: Country, dtype: int64

# %% [markdown]
# ## **Mp**

# %%
print(df.Mp.cat.categories)
df.Mp.value_counts()
# Out:
# Index(['BMW', 'BMW GROUP', 'DAIMLER AG', 'FCA', 'FCA ITALY SPA', 'FCA-TESLA',
#        'FIAT GROUP AUTOMOBILES SPA', 'FORD', 'FORD POOL', 'FORD-WERKE GMBH',
#        'GENERAL MOTORS', 'HONDA MOTOR EUROPE LTD', 'HYUNDAI',
#        'HYUNDAI MOTOR EUROPE', 'JLT POOL', 'KG MOBILITY GREAT WALL MOTOR',
#        'KIA', 'MAZDA', 'MAZDA-SUBARU-SUZUKI-TOYOTA', 'MERCEDES-BENZ',
#        'MERCEDES-BENZ AG', 'MG-SAIC', 'MITSUBISHI MOTORS', 'MITSUBISHI POOL',
#        'POOL RENAULT', 'PSA', 'PSA-OPEL', 'RENAULT', 'RENAULT-MITSUBISHI',
#        'RENAULT-NISSAN-MITSUBISHI', 'STELLANTIS', 'SUBARU-SUZUKI-TOYOTA',
#        'SUZUKI', 'SUZUKI POOL', 'TATA MOTORS JAGUAR LAND ROVER',
#        'TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER',
#        'TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER', 'TESLA',
#        'TESLA-HONDA-JLR', 'TOYOTA -DAIHATSU GROUP', 'TOYOTA-DAHAITSU GROUP',
#        'TOYOTA-MAZDA', 'VOLKSWAGEN', 'VW GROUP PC', 'VW-SAIC', 'na'],
#       dtype='object')
# VOLKSWAGEN                                       2446297
# VW GROUP PC                                      1938866
# BMW                                              1133403
# BMW GROUP                                         827705
# VW-SAIC                                           792555
# MERCEDES-BENZ                                     768198
# DAIMLER AG                                        750495
# STELLANTIS                                        514750
# PSA-OPEL                                          444418
# FORD-WERKE GMBH                                   402987
# FORD                                              378882
# RENAULT-NISSAN-MITSUBISHI                         264594
# MERCEDES-BENZ AG                                  258285
# RENAULT                                           233984
# GENERAL MOTORS                                    214183
# PSA                                               201674
# KIA                                               134935
# RENAULT-MITSUBISHI                                108225
# TATA MOTORS JAGUAR LAND ROVER                      98234
# HYUNDAI                                            95499
# POOL RENAULT                                       93266
# TOYOTA-MAZDA                                       87923
# FCA ITALY SPA                                      84136
# FCA-TESLA                                          79483
# MAZDA-SUBARU-SUZUKI-TOYOTA                         78845
# na                                                 66629
# FIAT GROUP AUTOMOBILES SPA                         66057
# FCA                                                49563
# HYUNDAI MOTOR EUROPE                               39668
# TESLA                                              34084
# SUBARU-SUZUKI-TOYOTA                               30680
# TESLA-HONDA-JLR                                    28802
# HONDA MOTOR EUROPE LTD                             25633
# TOYOTA -DAIHATSU GROUP                             22964
# SUZUKI POOL                                        16128
# FORD POOL                                          14998
# MITSUBISHI MOTORS                                  14386
# TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER       14203
# TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER      12971
# TOYOTA-DAHAITSU GROUP                              12220
# MAZDA                                               9410
# SUZUKI                                              6713
# MITSUBISHI POOL                                     2857
# JLT POOL                                            2801
# KG MOBILITY GREAT WALL MOTOR                        1703
# MG-SAIC                                               43
# Name: Mp, dtype: int64

# %%
# Share of NAs in coluumn "Mp" per year
df[df.Mp.isna()].year.value_counts()/df[df.Mp.isna()].year.shape[0]
# Out:
# 2011    0.201999
# 2010    0.161852
# 2019    0.106234
# 2018    0.078397
# 2023    0.070553
# 2021    0.065618
# 2022    0.054267
# 2013    0.051249
# 2017    0.047979
# 2020    0.046909
# 2012    0.041457
# 2016    0.038732
# 2015    0.034754
# Name: year, dtype: Float64

# %%
# Create a contingency table using pd.crosstab
mp_year_table = pd.crosstab(df['Mp'], df['year'], dropna=False)

# Display the table
print(mp_year_table)
# Out:
# year                                            2010  2011   2012   2013  \
# Mp
# BMW                                                0     0      0      0
# BMW GROUP                                          0     0  23302  29066
# DAIMLER AG                                         0     0  27991  37766
# FCA                                                0     0      0      0
# FCA ITALY SPA                                      0     0      0      0
# FCA-TESLA                                          0     0      0      0
# FIAT GROUP AUTOMOBILES SPA                         0     0  19558  28566
# FORD                                               0     0      0      0
# FORD POOL                                      14998     0      0      0
# FORD-WERKE GMBH                                    0     0  17038  17605
# GENERAL MOTORS                                     0     0  31673  39903
# HONDA MOTOR EUROPE LTD                             0     0   2519   3048
# HYUNDAI                                            0     0      0      0
# HYUNDAI MOTOR EUROPE                               0     0      0      0
# JLT POOL                                        2801     0      0      0
# KG MOBILITY GREAT WALL MOTOR                       0     0      0      0
# KIA                                                0     0      0      0
# MAZDA                                              0     0      0      0
# MAZDA-SUBARU-SUZUKI-TOYOTA                         0     0      0      0
# MERCEDES-BENZ                                      0     0      0      0
# MERCEDES-BENZ AG                                   0     0      0      0
# MG-SAIC                                            0     0      0      0
# MITSUBISHI MOTORS                                  0     0   1687   1746
# MITSUBISHI POOL                                 2857     0      0      0
# POOL RENAULT                                       0     0  33015  31262
# PSA                                                0     0      0      0
# PSA-OPEL                                           0     0      0      0
# RENAULT                                            0     0      0      0
# RENAULT-MITSUBISHI                                 0     0      0      0
# RENAULT-NISSAN-MITSUBISHI                          0     0      0      0
# STELLANTIS                                         0     0      0      0
# SUBARU-SUZUKI-TOYOTA                               0     0      0      0
# SUZUKI                                             0     0   1972   2152
# SUZUKI POOL                                     2621     0      0      0
# TATA MOTORS JAGUAR LAND ROVER                      0     0      0      0
# TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER      0     0   3035   4556
# TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER       0     0      0      0
# TESLA                                              0     0      0      0
# TESLA-HONDA-JLR                                    0     0      0      0
# TOYOTA -DAIHATSU GROUP                             0     0   9740  13224
# TOYOTA-DAHAITSU GROUP                              0     0      0      0
# TOYOTA-MAZDA                                       0     0      0      0
# VOLKSWAGEN                                         0     0      0      0
# VW GROUP PC                                        0     0  72132  92895
# VW-SAIC                                            0     0      0      0
# na                                                 0     0      0      0
#
# year                                             2014    2015    2016    2017  \
# Mp
# BMW                                                 0       0       0       0
# BMW GROUP                                       35780   44812   42786   44687
# DAIMLER AG                                      40060   42820   47548   48333
# FCA                                                 0       0       0       0
# FCA ITALY SPA                                       0   16129   17963   18377
# FCA-TESLA                                           0       0       0       0
# FIAT GROUP AUTOMOBILES SPA                      17933       0       0       0
# FORD                                                0       0       0       0
# FORD POOL                                           0       0       0       0
# FORD-WERKE GMBH                                 16937   18478   20912   20888
# GENERAL MOTORS                                  38968   34812   36229   32598
# HONDA MOTOR EUROPE LTD                           2990    2746    1760    1991
# HYUNDAI                                          6987    7860    6648    6001
# HYUNDAI MOTOR EUROPE                                0       0       0       0
# JLT POOL                                            0       0       0       0
# KG MOBILITY GREAT WALL MOTOR                        0       0       0       0
# KIA                                              9237    8103    5747    5720
# MAZDA                                               0       0       0       0
# MAZDA-SUBARU-SUZUKI-TOYOTA                          0       0       0       0
# MERCEDES-BENZ                                       0       0       0       0
# MERCEDES-BENZ AG                                    0       0       0       0
# MG-SAIC                                             0       0       0       0
# MITSUBISHI MOTORS                                1777    1943    1529    1357
# MITSUBISHI POOL                                     0       0       0       0
# POOL RENAULT                                    28989       0       0       0
# PSA                                                 0       0       0       0
# PSA-OPEL                                            0       0       0       0
# RENAULT                                             0   29090   24775   29117
# RENAULT-MITSUBISHI                                  0       0       0       0
# RENAULT-NISSAN-MITSUBISHI                           0       0       0       0
# STELLANTIS                                          0       0       0       0
# SUBARU-SUZUKI-TOYOTA                                0       0       0       0
# SUZUKI                                              0       0       0       0
# SUZUKI POOL                                      1938    2098    1799    1566
# TATA MOTORS JAGUAR LAND ROVER                       0       0       0    6595
# TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER    5380       0       0       0
# TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER        0    6985    7218       0
# TESLA                                               0       0       0       0
# TESLA-HONDA-JLR                                     0       0       0       0
# TOYOTA -DAIHATSU GROUP                              0       0       0       0
# TOYOTA-DAHAITSU GROUP                               0   12220       0       0
# TOYOTA-MAZDA                                        0       0       0       0
# VOLKSWAGEN                                          0       0       0       0
# VW GROUP PC                                    124442  149996  169604  133101
# VW-SAIC                                             0       0       0       0
# na                                              66629       0       0       0
#
# year                                             2018    2019    2020    2021  \
# Mp
# BMW                                                 0       0  313534  279976
# BMW GROUP                                      240755  366517       0       0
# DAIMLER AG                                     178870  327107       0       0
# FCA                                                 0       0   49563       0
# FCA ITALY SPA                                   31667       0       0       0
# FCA-TESLA                                           0   79483       0       0
# FIAT GROUP AUTOMOBILES SPA                          0       0       0       0
# FORD                                                0       0  215720   78104
# FORD POOL                                           0       0       0       0
# FORD-WERKE GMBH                                 96094  195035       0       0
# GENERAL MOTORS                                      0       0       0       0
# HONDA MOTOR EUROPE LTD                           4482    6097       0       0
# HYUNDAI                                         11595   21248   15202   19958
# HYUNDAI MOTOR EUROPE                                0       0       0       0
# JLT POOL                                            0       0       0       0
# KG MOBILITY GREAT WALL MOTOR                        0       0       0       0
# KIA                                             10601   24657   19651   18559
# MAZDA                                               0       0       0       0
# MAZDA-SUBARU-SUZUKI-TOYOTA                          0       0       0   39850
# MERCEDES-BENZ                                       0       0  271385  233000
# MERCEDES-BENZ AG                                    0       0       0       0
# MG-SAIC                                             0      43       0       0
# MITSUBISHI MOTORS                                2074    2273       0       0
# MITSUBISHI POOL                                     0       0       0       0
# POOL RENAULT                                        0       0       0       0
# PSA                                                 0       0  201674       0
# PSA-OPEL                                       142681  301737       0       0
# RENAULT                                         50048  100954       0       0
# RENAULT-MITSUBISHI                                  0       0  108225       0
# RENAULT-NISSAN-MITSUBISHI                           0       0       0   81401
# STELLANTIS                                          0       0       0  209416
# SUBARU-SUZUKI-TOYOTA                                0       0       0       0
# SUZUKI                                              0       0    2589       0
# SUZUKI POOL                                      2866    3240       0       0
# TATA MOTORS JAGUAR LAND ROVER                   27066   64573       0       0
# TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER       0       0       0       0
# TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER        0       0       0       0
# TESLA                                               0       0       0   34084
# TESLA-HONDA-JLR                                     0       0       0       0
# TOYOTA -DAIHATSU GROUP                              0       0       0       0
# TOYOTA-DAHAITSU GROUP                               0       0       0       0
# TOYOTA-MAZDA                                    20468   35985   31470       0
# VOLKSWAGEN                                          0       0  841007       0
# VW GROUP PC                                    301028  895668       0       0
# VW-SAIC                                             0       0       0  792555
# na                                                  0       0       0       0
#
# year                                             2022    2023
# Mp
# BMW                                            266677  273216
# BMW GROUP                                           0       0
# DAIMLER AG                                          0       0
# FCA                                                 0       0
# FCA ITALY SPA                                       0       0
# FCA-TESLA                                           0       0
# FIAT GROUP AUTOMOBILES SPA                          0       0
# FORD                                            50764   34294
# FORD POOL                                           0       0
# FORD-WERKE GMBH                                     0       0
# GENERAL MOTORS                                      0       0
# HONDA MOTOR EUROPE LTD                              0       0
# HYUNDAI                                             0       0
# HYUNDAI MOTOR EUROPE                            24860   14808
# JLT POOL                                            0       0
# KG MOBILITY GREAT WALL MOTOR                        0    1703
# KIA                                             18961   13699
# MAZDA                                               0    9410
# MAZDA-SUBARU-SUZUKI-TOYOTA                      38995       0
# MERCEDES-BENZ                                  263813       0
# MERCEDES-BENZ AG                                    0  258285
# MG-SAIC                                             0       0
# MITSUBISHI MOTORS                                   0       0
# MITSUBISHI POOL                                     0       0
# POOL RENAULT                                        0       0
# PSA                                                 0       0
# PSA-OPEL                                            0       0
# RENAULT                                             0       0
# RENAULT-MITSUBISHI                                  0       0
# RENAULT-NISSAN-MITSUBISHI                       88938   94255
# STELLANTIS                                     172797  132537
# SUBARU-SUZUKI-TOYOTA                                0   30680
# SUZUKI                                              0       0
# SUZUKI POOL                                         0       0
# TATA MOTORS JAGUAR LAND ROVER                       0       0
# TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER       0       0
# TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER        0       0
# TESLA                                               0       0
# TESLA-HONDA-JLR                                 28802       0
# TOYOTA -DAIHATSU GROUP                              0       0
# TOYOTA-DAHAITSU GROUP                               0       0
# TOYOTA-MAZDA                                        0       0
# VOLKSWAGEN                                     772604  832686
# VW GROUP PC                                         0       0
# VW-SAIC                                             0       0
# na                                                  0       0

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh.parquet")

# %% [markdown]
# ==> many names only appear in mutually exclusive specific years. So we will try to map them on a timeline.

# %%
# Detailed mapping with the help of ChatGPT considering mergers/aquisitions in specific years and pooling agreements changing over time:

import pandas as pd

# mapping list with pd.NA for missing values
mapping_list = [
    # BMW Group remained consistent throughout the years
    {'old_names': ['BMW', 'BMW GROUP'], 'new_name': 'BMW Group', 'start_year': None, 'end_year': None},

    # Daimler AG operated under this name until it rebranded in 2022
    {'old_names': ['DAIMLER AG'], 'new_name': 'Daimler AG', 'start_year': None, 'end_year': 2021},

    # From 2022 onwards, Daimler AG rebranded to Mercedes-Benz Group
    {'old_names': ['MERCEDES-BENZ AG', 'MERCEDES-BENZ'], 'new_name': 'Mercedes-Benz Group', 'start_year': 2022, 'end_year': None},

    # Fiat Chrysler Automobiles (FCA) operated until merging with PSA to form Stellantis in 2021
    {'old_names': ['FIAT GROUP AUTOMOBILES SPA', 'FCA', 'FCA ITALY SPA'], 'new_name': 'Fiat Chrysler Automobiles', 'start_year': None, 'end_year': 2020},

    # PSA Group operated independently until merging with FCA to form Stellantis in 2021
    {'old_names': ['PSA', 'PSA-OPEL'], 'new_name': 'PSA Group', 'start_year': None, 'end_year': 2020},

    # Stellantis formed in 2021 from the merger of FCA and PSA
    {'old_names': ['STELLANTIS'], 'new_name': 'Stellantis', 'start_year': 2021, 'end_year': None},

    # Ford Motor Company remained consistent throughout
    {'old_names': ['FORD', 'FORD POOL', 'FORD-WERKE GMBH'], 'new_name': 'Ford', 'start_year': None, 'end_year': None},

    # General Motors remained consistent throughout
    {'old_names': ['GENERAL MOTORS'], 'new_name': 'General Motors', 'start_year': None, 'end_year': None},

    # Honda Motor Company remained consistent throughout
    {'old_names': ['HONDA MOTOR EUROPE LTD'], 'new_name': 'Honda', 'start_year': None, 'end_year': None},

    # Hyundai Motor Company remained consistent throughout
    {'old_names': ['HYUNDAI', 'HYUNDAI MOTOR EUROPE'], 'new_name': 'Hyundai', 'start_year': None, 'end_year': None},

    # Kia Motors remained consistent throughout
    {'old_names': ['KIA'], 'new_name': 'Kia', 'start_year': None, 'end_year': None},

    # Jaguar Land Rover has been owned by Tata Motors since 2008
    {'old_names': [
        'TATA MOTORS JAGUAR LAND ROVER',
        'TATA MOTORS LTD, JAGUAR CARS LTD , LAND ROVER',
        'TATA MOTORS LTD, JAGUAR CARS LTD, LAND ROVER'
    ], 'new_name': 'Jaguar Land Rover', 'start_year': 2008, 'end_year': None},

    # Mazda operated independently up to 2018
    {'old_names': ['MAZDA'], 'new_name': 'Mazda', 'start_year': None, 'end_year': 2018},

    # Mazda and Toyota entered a pooling agreement from 2019 to 2020
    {'old_names': ['MAZDA', 'TOYOTA-MAZDA'], 'new_name': 'Toyota-Mazda', 'start_year': 2019, 'end_year': 2020},

    # Mazda joined a larger pooling agreement with Toyota, Suzuki, and Subaru from 2021 onwards
    {'old_names': ['MAZDA'], 'new_name': 'Toyota-Mazda-Suzuki-Subaru', 'start_year': 2021, 'end_year': None},

    # Suzuki operated independently up to 2018
    {'old_names': ['SUZUKI', 'SUZUKI POOL'], 'new_name': 'Suzuki', 'start_year': None, 'end_year': 2018},

    # Suzuki and Toyota entered a pooling agreement from 2019 to 2020
    {'old_names': ['SUZUKI'], 'new_name': 'Toyota-Suzuki', 'start_year': 2019, 'end_year': 2020},

    # Suzuki joined the larger pooling agreement with Toyota, Mazda, and Subaru from 2021 onwards
    {'old_names': ['SUZUKI'], 'new_name': 'Toyota-Mazda-Suzuki-Subaru', 'start_year': 2021, 'end_year': None},

    # Subaru operated independently up to 2020
    {'old_names': ['SUBARU'], 'new_name': 'Subaru', 'start_year': None, 'end_year': 2020},

    # Subaru joined the pooling agreement with Toyota, Mazda, and Suzuki from 2021 onwards
    {'old_names': ['SUBARU'], 'new_name': 'Toyota-Mazda-Suzuki-Subaru', 'start_year': 2021, 'end_year': None},

    # Toyota operated independently up to 2018
    {'old_names': ['TOYOTA', 'TOYOTA -DAIHATSU GROUP', 'TOYOTA-DAHAITSU GROUP'], 'new_name': 'Toyota', 'start_year': None, 'end_year': 2018},

    # Toyota and Mazda entered a pooling agreement from 2019 to 2020
    {'old_names': ['TOYOTA'], 'new_name': 'Toyota-Mazda', 'start_year': 2019, 'end_year': 2020},

    # Toyota expanded its pooling agreement to include Mazda, Suzuki, and Subaru from 2021 onwards
    {'old_names': ['TOYOTA', 'MAZDA-SUBARU-SUZUKI-TOYOTA', 'SUBARU-SUZUKI-TOYOTA'], 'new_name': 'Toyota-Mazda-Suzuki-Subaru', 'start_year': 2021, 'end_year': None},

    # Reflects the Toyota-Mazda pooling agreement during 2019-2020
    {'old_names': ['TOYOTA-MAZDA'], 'new_name': 'Toyota-Mazda', 'start_year': 2019, 'end_year': 2020},

    # Reflects the expanded pooling agreement including Mazda, Suzuki, and Subaru from 2021 onwards
    {'old_names': ['MAZDA-SUBARU-SUZUKI-TOYOTA', 'SUBARU-SUZUKI-TOYOTA'], 'new_name': 'Toyota-Mazda-Suzuki-Subaru', 'start_year': 2021, 'end_year': None},

    # Mitsubishi Motors operated independently up to 2015
    {'old_names': ['MITSUBISHI MOTORS'], 'new_name': 'Mitsubishi Motors', 'start_year': None, 'end_year': 2015},

    # Mitsubishi joined the Renault-Nissan-Mitsubishi Alliance in 2016
    {'old_names': ['MITSUBISHI MOTORS'], 'new_name': 'Renault-Nissan-Mitsubishi Alliance', 'start_year': 2016, 'end_year': None},

    # Renault operated independently up to 1998
    {'old_names': ['RENAULT', 'POOL RENAULT'], 'new_name': 'Renault', 'start_year': None, 'end_year': 1998},

    # Renault formed an alliance with Nissan from 1999 to 2015
    {'old_names': ['RENAULT', 'POOL RENAULT', 'RENAULT-MITSUBISHI'], 'new_name': 'Renault-Nissan Alliance', 'start_year': 1999, 'end_year': 2015},

    # Mitsubishi joined the alliance in 2016
    {'old_names': ['RENAULT', 'POOL RENAULT', 'RENAULT-MITSUBISHI', 'RENAULT-NISSAN-MITSUBISHI'], 'new_name': 'Renault-Nissan-Mitsubishi Alliance', 'start_year': 2016, 'end_year': None},

    # Volkswagen Group remained consistent throughout
    {'old_names': ['VOLKSWAGEN', 'VW GROUP PC', 'VW-SAIC'], 'new_name': 'Volkswagen Group', 'start_year': None, 'end_year': None},

    # SAIC Motor Corporation remained consistent
    {'old_names': ['MG-SAIC'], 'new_name': 'SAIC Motor', 'start_year': None, 'end_year': None},

    # Great Wall Motor remained consistent
    {'old_names': ['KG MOBILITY GREAT WALL MOTOR'], 'new_name': 'Great Wall Motor', 'start_year': None, 'end_year': None},

    # Tesla remained independent
    {'old_names': ['TESLA'], 'new_name': 'Tesla', 'start_year': None, 'end_year': None},

    # Reflects pooling agreement between FCA and Tesla
    {'old_names': ['FCA-TESLA'], 'new_name': 'FCA-Tesla', 'start_year': None, 'end_year': None},

    # Adding mapping for 'JLT POOL'
    {'old_names': ['JLT POOL'], 'new_name': 'Jaguar Land Rover - Tesla Pool', 'start_year': None, 'end_year': None},

    # Adding mapping for 'MITSUBISHI POOL'
    {'old_names': ['MITSUBISHI POOL'], 'new_name': 'Mitsubishi Motors', 'start_year': None, 'end_year': 2015},
    {'old_names': ['MITSUBISHI POOL'], 'new_name': 'Renault-Nissan-Mitsubishi Alliance', 'start_year': 2016, 'end_year': None},

    # Adding mapping for 'TESLA-HONDA-JLR'
    {'old_names': ['TESLA-HONDA-JLR'], 'new_name': 'Tesla-Honda-Jaguar Land Rover Pool', 'start_year': None, 'end_year': None},

    # Missing values represented as pd.NA
    {'old_names': ['na'], 'new_name': pd.NA, 'start_year': None, 'end_year': None},
]

df = rename_catval_mp(df, mapping_list)

# %%
print(df.Mp.cat.categories)
df.Mp.value_counts()
# Out:
# Index([], dtype='object')
# Series([], Name: Mp, dtype: int64)

# %%
# Create a contingency table using pd.crosstab
mp_year_table = pd.crosstab(df['Mp'], df['year'], dropna=False)

# Display the table
print(mp_year_table)
# Out:
# Empty DataFrame
# Columns: [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# Index: []

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp.parquet")

# %% [markdown]
# ## **Mh**

# %%
print("Mh: ", df.Mh.nunique(), "Man: ", df.Man.nunique(), "MMS: ", df.MMS.nunique())
# Out:
# Mh:  218 Man:  477 MMS:  11561

# %%
with pd.option_context('display.max_rows', None):
    print(df.Mh.value_counts())

with pd.option_context('display.max_rows', None):
    print(df.Man.value_counts())
# Out:
# BMW AG                                              1955014
# VOLKSWAGEN                                          1953152
# MERCEDES-BENZ AG                                    1825205
# AUDI AG                                             1419262
# SKODA                                               1163682
# FORD WERKE GMBH                                      703349
# RENAULT                                              550884
# VOLVO                                                538602
# SEAT                                                 496161
# AUTOMOBILES PEUGEOT                                  337900
# OPEL AUTOMOBILE                                      304787
# PSA                                                  279158
# FIAT GROUP                                           278010
# OPEL                                                 268778
# JAGUAR LAND ROVER LIMITED                            265060
# TOYOTA                                               235862
# PORSCHE                                              223456
# AUTOMOBILES CITROEN                                  208749
# DACIA                                                145006
# NISSAN AUTOMOTIVE EUROPE                             133072
# AA-IVA                                                97830
# STELLANTIS EUROPE                                     89030
# KIA                                                   85326
# KIA SLOVAKIA                                          77738
# HYUNDAI CZECH                                         71059
# CHRYSLER                                              68016
# MAZDA                                                 65104
# HYUNDAI                                               59123
# ALFA ROMEO                                            50777
# BMW GMBH                                              42629
# HONDA MOTOR CO                                        41542
# AUDI SPORT                                            36686
# duplicate                                             34420
# HYUNDAI ASSAN                                         23586
# MAGYAR SUZUKI                                         20646
# MITSUBISHI MOTORS CORPORATION                         19334
# SUBARU                                                18796
# GM KOREA                                              16915
# UNKNOWN                                               16489
# MASERATI                                              16428
# TESLA                                                 15173
# AUDI HUNGARIA                                         15163
# TOYOTA MOTOR EUROPE                                   14432
# SUZUKI MOTOR CORPORATION                              14410
# FORD MOTOR COMPANY                                    12270
# SSANGYONG                                             11087
# MERCEDES AMG                                          10524
# PSA                                                    8855
# MAZDA EUROPE                                           7408
# NISSAN INTERNATIONAL SA                                7221
# HYUNDAI ASSAN                                          6987
# BENTLEY                                                5683
# SAAB                                                   4072
# ASTON MARTIN                                           4057
# FERRARI                                                4039
# POLESTAR                                               3895
# LAMBORGHINI                                            3586
# MERCEDES-AMG GMBH                                      3579
# GENERAL MOTORS COMPANY                                 3315
# MITSUBISHI MOTORS THAILAND                             3061
# ALPINE                                                 2596
# LOTUS                                                  2526
# MCLAREN                                                2507
# ROLLS ROYCE                                            2156
# SAIC MOTOR CORPORATION                                 2130
# JAGUAR                                                 2056
# MORGAN                                                 2030
# LADA                                                   1874
# ALPINA                                                 1760
# AA-NSS                                                 1669
# CNG TECHNIK                                            1491
# GENERAL MOTORS HOLDINGS                                1469
# MARUTI SUZUKI                                          1298
# MITSUBISHI MOTORS EUROPE                               1251
# DAIHATSU                                               1168
# JAGUAR CARS LTD                                        1145
# FORD INDIA                                             1145
# VAUXHALL                                                812
# DFSK                                                    798
# GTF INNOVATIONS                                         740
# INEOS                                                   721
# HONDA OF THE UK MANUFACTURING                           713
# ROLLS-ROYCE                                             570
# CATERHAM                                                526
# PROTON                                                  434
# MG MOTOR                                                411
# SUZUKI THAILAND                                         402
# RENAULT TRUCKS                                          370
# GEELY                                                   362
# HYUNDAI INDIA                                           337
# TATA                                                    333
# DR AUTOMOBILES                                          328
# NIO                                                     300
# CHEVROLET ITALIA                                        279
# MAHINDRA                                                252
# BYD                                                     237
# HYUNDAI CZECH                                           212
# WUHAN LOTUS                                             198
# PERODUA                                                 194
# DR MOTOR                                                174
# GREAT WALL MOTOR                                        172
# MAZDA                                                   161
# JIANGLING MOTOR                                         158
# FISKER                                                  138
# SAIC MAXUS                                              135
# CHRYSLER                                                130
# TOYOTA GAZOO RACING                                     126
# KTM                                                     111
# SMART                                                   103
# ZHAOQING                                                101
# MIA                                                     100
# SAIC                                                     96
# ROLLS-ROYCE MOTOR CARS LTD                               92
# LANZHOU                                                  86
# GM KOREA                                                 83
# CHINA FAW                                                82
# SECMA                                                    81
# BUGATTI                                                  81
# IVECO                                                    77
# ANHUI                                                    73
# KIA SLOVAKIA                                             64
# MARUTI SUZUKI INDIA LTD                                  62
# MAN                                                      60
# THINK GLOBAL                                             60
# LADA                                                     56
# DONKERVOORT                                              52
# MG                                                       51
# BLUECAR                                                  51
# PGO                                                      51
# BRILLIANCE SHINERAY                                      50
# SOVAB                                                    46
# DALLARA                                                  46
# SANTANA                                                  42
# OMCI                                                     38
# SERES AUTO                                               31
# LTI CARBODIES                                            29
# ISUZU                                                    28
# LEVC                                                     27
# ADIDOR                                                   27
# FORD MOTOR AUSTRALIA                                     27
# LUCID USA                                                27
# WIESMANN                                                 27
# NANJING GOLDEN DRAGON                                    25
# NEXT EGO MOBILE                                          24
# LTI CARBODIES                                            23
# PAGANI                                                   22
# ROVER                                                    20
# KOENIGSEGG                                               18
# HENAN SUDA                                               18
# DONGFENG MOTOR                                           18
# IVECO SPA                                                17
# SAIC MOTOR                                               15
# BENTLEY                                                  15
# AUTOMOBILES DANGEL                                       12
# SHUANGHUAN                                               12
# BORGWARD                                                 11
# WESTFIELD                                                11
# OSV                                                      10
# MICRO VETT                                                9
# EURASIA                                                   9
# LEAPMOTOR                                                 8
# RADICAL MOTOSPORT                                         8
# TAZZARI                                                   7
# TECNO MECCANICA                                           7
# SHIJIAZHUANG SHUANGHUAN                                   7
# LITEX MOTORS                                              7
# NOBLE                                                     7
# RADICAL MOTORSPORT                                        7
# CNG-TECHNIK                                               6
# JAGUAR                                                    6
# HAIMA                                                     6
# E-GO                                                      6
# BUGATTI RIMAC                                             6
# SUZUKI MOTOR CORPORATION                                  5
# BLUECAR ITALY                                             5
# NEVS                                                      5
# CHERY                                                     5
# MICRO-VETT                                                4
# DONGFENG                                                  4
# GUMPERT                                                   4
# DONGFENG LIUZHOU                                          4
# SHANGHAI MAPLE                                            4
# ZOTYE                                                     4
# PIAGGIO                                                   4
# DONKEVOORT                                                4
# ARTEGA                                                    3
# FORD MOTOR BRASIL                                         3
# JIANGXI JIANGLING                                         3
# POTENZA SPORTS CARS                                       3
# UAZ                                                       2
# DONGFENG MOTOR CORPORATION                                2
# RADICAL MOTORSPORT LTD                                    2
# YUDO AUTO                                                 2
# CECOMP                                                    2
# CHONGQING LIFAN                                           2
# LEEH                                                      2
# ZHEJIANG HAOQING                                          2
# BEE BEE                                                   2
# BEE                                                       2
# OSV OPEL SPECIAL VEHICLES                                 2
# ZOTYE HOLDING NG GROUP                                    2
# QOROS                                                     2
# VINFAST                                                   2
# VEPB                                                      1
# AC CARS                                                   1
# TAIQI                                                     1
# VEHICULES ELECTRIQUES PININFARINA-BOLLORE S.A.S.          1
# FSO                                                       1
# General Motors Company                                    1
# HUNAN JIANGNAN                                            1
# BRABUS                                                    1
# ITALDESIGN                                                1
# SPYKER                                                    1
# KOENIGSEGG                                                1
# MOKE                                                      1
# NANJING GOLDEN DRAGON BUS CO., LTD.                       1
# AUDI HUNGARIA                                             1
# CECOMP S.P.A.                                             1
# Name: Mh, dtype: int64
# BAYERISCHE MOTOREN WERKE AG                                                        1930978
# VOLKSWAGEN AG                                                                      1903899
# AUDI AG                                                                            1382184
# SKODA AUTO AS                                                                      1140490
# MERCEDES-BENZ AG                                                                   1024898
# DAIMLER AG                                                                          738979
# FORD-WERKE GMBH                                                                     553782
# VOLVO CAR CORPORATION                                                               521648
# RENAULT SAS                                                                         489130
# SEAT SA                                                                             483804
# AUTOMOBILES PEUGEOT                                                                 329387
# OPEL AUTOMOBILE GMBH                                                                304716
# PSA AUTOMOBILES SA                                                                  280862
# JAGUAR LAND ROVER LIMITED                                                           259127
# DR ING HCF PORSCHE AG                                                               220847
# TOYOTA MOTOR EUROPE NV SA                                                           205162
# AUTOMOBILES CITROEN                                                                 201081
# FCA ITALY SPA                                                                       182877
# ADAM OPEL AG                                                                        165561
# AUTOMOBILE DACIA SA                                                                 139915
# FORD WERKE GMBH                                                                     128394
# NISSAN INTERNATIONAL SA                                                             106359
# AA-IVA                                                                               94694
# STELLANTIS AUTO SAS                                                                  74744
# HYUNDAI MOTOR MANUFACTURING CZECH SRO                                                71826
# FIAT GROUP AUTOMOBILES SPA                                                           71019
# ADAM OPEL GMBH                                                                       68720
# MAZDA MOTOR CORPORATION                                                              61389
# FCA US LLC                                                                           55756
# KIA MOTORS CORPORATION                                                               52009
# ALFA ROMEO SPA                                                                       50926
# KIA MOTORS SLOVAKIA SRO                                                              46632
# HYUNDAI MOTOR COMPANY                                                                46583
# RENAULT                                                                              41991
# BMW M GMBH                                                                           41445
# AUDI SPORT GMBH                                                                      32576
# KIA SLOVAKIA SRO                                                                     31554
# HYUNDAI ASSAN OTOMOTIV SANAYI VE TICARET AS                                          29359
# DAIMLER AG STUTTGART                                                                 27048
# VOLKSWAGEN                                                                           25293
# NISSAN AUTOMOTIVE EUROPE SAS                                                         24520
# HONDA MOTOR CO LTD                                                                   22557
# KIA CORPORATION                                                                      20185
# MAGYAR SUZUKI CORPORATION LTD                                                        19201
# AUDI                                                                                 19195
# MASERATI SPA                                                                         16260
# TOYOTA MOTOR CORPORATION                                                             15824
# STELLANTIS EUROPE SPA                                                                14633
# MITSUBISHI MOTORS CORPORATION MMC                                                    13088
# MERCEDES-AMG GMBH                                                                    12882
# SUZUKI MOTOR CORPORATION                                                             12825
# SKODA                                                                                12634
# FORD MOTOR COMPANY                                                                   12140
# GM KOREA COMPANY                                                                     11468
# CHRYSLER GROUP LLC                                                                   11024
# TOYOTA MOTOR EUROPE                                                                  10562
# HONDA OF THE UK MANUFACTURING LTD                                                    10278
# FUJI HEAVY INDUSTRIES LTD                                                            10154
# TESLA INC                                                                            10151
# AUDI HUNGARIA MOTOR KFT                                                               9175
# SSANGYONG MOTOR COMPANY                                                               8976
# SEAT                                                                                  8108
# VOLVO                                                                                 8014
# FORD                                                                                  7586
# PSA AUTOMOBILES SA                                                                    7581
# SUBARU CORPORATION                                                                    6633
# KIA                                                                                   6599
# HYUNDAI                                                                               5819
# TESLA MOTORS LTD                                                                      5325
# BENTLEY MOTORS LTD                                                                    5315
# AUDI HUNGARIA ZRT                                                                     5030
# MAZDA MOTOR LOGISTICS EUROPE NV                                                       4682
# OPEL                                                                                  4451
# TOYOTA MOTOR EUROPE  NV SA                                                            4238
# POLESTAR PERFORMANCE AB                                                               3899
# TOYOTA                                                                                3882
# ASTON MARTIN LAGONDA LTD                                                              3858
# LAND ROVER                                                                            3629
# FERRARI SPA                                                                           3560
# AUTOMOBILI LAMBORGHINI SPA                                                            3364
# DAIMLER                                                                               3150
# QUATTRO GMBH                                                                          2992
# GENERAL MOTORS COMPANY                                                                2811
# BMW AG                                                                                2739
# ROLLS-ROYCE MOTOR CARS LTD                                                            2681
# DACIA                                                                                 2606
# FIAT                                                                                  2581
# MCLAREN AUTOMOTIVE LIMITED                                                            2514
# UNKNOWN                                                                               2323
# LOTUS CARS LIMITED                                                                    2256
# BMW                                                                                   2206
# SAIC MOTOR CORPORATION LTD                                                            2206
# SAAB AUTOMOBILE AB                                                                    2165
# HONDA MOTOR CO                                                                        2116
# MAZDA MOTOR LOGISTICS EUROPE N.V.                                                     2109
# MITSUBISHI MOTORS THAILAND CO LTD MMTH                                                1997
# JAGUAR CARS LTD                                                                       1977
# GM DAEWOO AUTO U TECH COMP                                                            1828
# HONDA                                                                                 1750
# MANUFACTURE ALPINE DIEPPE JEAN REDELE                                                 1737
# Bayerische Motoren Werke AG                                                           1706
# MITSUBISHI MOTORS CORPORTION MMC                                                      1704
# ALPINA BURKARD BOVENSIEPEN GMBH E CO KG                                               1620
# AA-NSS                                                                                1614
# NISSAN                                                                                1610
# PORSCHE                                                                               1567
# KG MOBILITY CORPORATION                                                               1559
# Volkswagen AG                                                                         1550
# FIAT GROUP AUTOMOBILES SP                                                             1512
# CNG-TECHNIK GMBH                                                                      1469
# PEUGEOT                                                                               1442
# AVTOVAZ JSC                                                                           1429
# BAYERISCHE MOTOREN WERKEN AG                                                          1428
# AA_IVA                                                                                1374
# CITROEN                                                                               1365
# GENERAL MOTORS HOLDINGS LLC                                                           1358
# HYUNDAI ASSAN OTOMOTIV SANAYI VE                                                      1346
# MITSUBISHI MOTORS CORPORATION                                                         1276
# FIAT GROUP                                                                            1242
# MARUTI SUZUKI INDIA LTD                                                               1222
# Ford-Werke GmbH                                                                       1173
# FORD INDIA PRIVATE LIMITED                                                            1145
# MORGAN TECHNOLOGIES LTD                                                               1121
# MITSUBISHI MOTORS THAILAND CO LTD                                                     1083
# TOYOTA MOTOR EUROPE                                                                    908
# DFSK MOTOR CO LTD                                                                      906
# VAUXHALL                                                                               812
# MITSUBISHI MOTORS EUROPE BV MME                                                        807
# MITSUBISHI                                                                             780
# AUDI SPORT GMBH                                                                        774
# MERCEDES-AMG GMBH AFFALTERBACH                                                         768
# HONDA OF THE UK MANUFACTURING                                                          748
# GTF INNOVATIONS SAS                                                                    740
# Mercedes-Benz AG                                                                       728
# INEOS AUTOMOTIVE LIMITED                                                               722
# Adam Opel AG                                                                           718
# HONDA AUTOMOBILE CHINA CO LTD                                                          659
# HYUNDAI MOTOR EUROPE GMBH                                                              649
# Audi AG                                                                                635
# SOCIETE DES AUTOMOBILES ALPINE SAS                                                     627
# MORGAN MOTOR CO LTD                                                                    621
# MAZDA MOTOR LOGISTIC EUROPE N.V.                                                       618
# MAZDA                                                                                  595
# SUZUKI                                                                                 481
# Volvo Car Corporation                                                                  470
# HONDA TURKIYE AS                                                                       467
# CATERHAM CARS LIMITED                                                                  458
# MAGYAR SUZUKI                                                                          445
# CHRYSLER                                                                               433
# HYUNDAI MOTOR INDIA LTD                                                                422
# SUZUKI MOTOR THAILAND CO LTD                                                           405
# Automobiles Peugeot                                                                    400
# RENAULT TRUCKS                                                                         385
# FERRARI                                                                                359
# PSA Automobiles SA                                                                     344
# MG MOTOR UK LIMITED                                                                    340
# Jaguar Land Rover Limited                                                              336
# DR AUTOMOBILES SRL                                                                     314
# SUZUKI MOTOR CORPORATION                                                               312
# DAIHATSU MOTOR CO                                                                      307
# Opel Automobile GmbH                                                                   291
# JAGUAR LAND ROVER LIMITED                                                              289
# GM DAEWOO                                                                              279
# SSANGYONG                                                                              257
# Nissan International SA                                                                256
# DAIHATSU                                                                               254
# BYD AUTO INDUSTRY COMPANY LIMITED                                                      251
# HONDA AUTOMOBILE CHINA CO                                                              249
# BENTLEY                                                                                248
# GM KOREA                                                                               246
# AVTOVAZ                                                                                245
# HYUNDAI MOTOR CZECH                                                                    244
# MAHINDRA & MAHINDRA LTD                                                                244
# SOCIETE DES AUTOMOBILES ALPINE                                                         242
# Mazda Motor Corporation                                                                231
# NIO CO LTD                                                                             221
# Kia Motors Corporation                                                                 221
# MITSUBISHI MOTORS                                                                      216
# QUATTRO                                                                                207
# SAAB                                                                                   202
# WUHAN LOTUS CAR CO LTD                                                                 200
# FUJI HEAVY INDUSTRIES                                                                  195
# PERUSAHAAN OTOMOBIL NASIONAL SDN BHD                                                   192
# ZHEJIANG GEELY AUTOMOBILE CO LTD                                                       190
# DAIHATSU MOTOR CO LTD                                                                  189
# GEELY                                                                                  171
# MORGAN                                                                                 165
# JIANGLING MOTOR HOLDING CO LTD                                                         161
# Bayerische Motoren Werke                                                               157
# GREAT WALL MOTOR COMPANY LIMITED                                                       154
# LAMBORGHINI                                                                            150
# PROTON                                                                                 139
# FISKER AUTOMOTIVE INC                                                                  138
# SAIC MAXUS AUTOMOTIVE CO LTD                                                           137
# TOYOTA GAZOO RACING EUROPE GMBH                                                        126
# GROUP LOTUS PLC                                                                        126
# LADA AUTOMOBILE GMBH                                                                   121
# TATA MOTORS LIMITED                                                                    117
# FCA ITALY SPA                                                                          117
# GM DAEWOO AUTO AND TECHNOLOGY COMPANY                                                  116
# CHEVROLET ITALIA SPA                                                                   115
# DR MOTOR COMPANY SRL                                                                   113
# JAGUAR                                                                                 112
# SMART AUTOMOBILE CO LTD                                                                105
# MIA ELECTRIC SAS                                                                       105
# Hyundai Motor Company                                                                  105
# ZHAOQING XIAOPENG INVESTMENT OF NEW ENERGY CO LTD                                      103
# Daimler AG                                                                             101
# IVECO SPA                                                                              101
# Automobiles Citroen                                                                     99
# MAGYAR SUZUKI CORPORATION                                                               98
# FUJI HEAVY INDUSTRIES LTD.                                                              98
# CHINA FAW GROUP CO LTD                                                                  88
# AUDI AG DE 85045 Ingolsta                                                               86
# MITSUBISHI MOTORS CORPORT                                                               81
# TATA                                                                                    80
# KIA MOTORS SLOVAKIA                                                                     80
# NIO CO                                                                                  80
# PERODUA                                                                                 79
# KTM-SPORTMOTORCYCLE AG                                                                  79
# BUGATTI AUTOMOBILES SAS                                                                 77
# BMW M GmbH                                                                              75
# FORD - WERKE GMBH                                                                       74
# BEIJING BORGWARD AUTOMOTIVE CO LTD                                                      70
# CHEVROLET ITALIA                                                                        69
# MITSUBISHI MOTORS CORPORTION                                                            68
# SECMA SAS                                                                               67
# FORD-WERKE GmbH                                                                         66
# HONDA UK                                                                                65
# ND                                                                                      64
# AUDI                                                                                    64
# ROLLS-ROYCE MOTORS CARS LTD                                                             63
# MG MOTOR                                                                                61
# WIESMANN GMBH                                                                           60
# MASERATI                                                                                59
# PERODUA MANUFACTURING SDN BHD                                                           58
# GENERAL MOTORS HOLDINGS LLC                                                             57
# HONDA OF THE UK MANUFACTU                                                               56
# VOLKSWAGEN AG BERLINER RING 2 D-38440 WOLFSBURG                                         56
# HONDA OF THE UK MANUFACTURING                                                           54
# AUDI AG DE-85045 INGOLSTADT                                                             54
# Renault SAS                                                                             53
# BRILLIANCE SHINERAY CHONGQING AUTOMOBILE CO LTD                                         52
# DONKERVOORT AUTOMOBIELEN BV                                                             52
# LANZHOU ZHIDOU ELECTRIC VEHICLE CO LTD                                                  52
# SOVAB                                                                                   51
# MG                                                                                      51
# BLUECAR SAS                                                                             51
# RENAULT S.A.S                                                                           49
# FCA US LLC                                                                              47
# FABBRICA DALLARA SRL                                                                    46
# MITSUBISHI MOTORS EUROPE                                                                46
# Ford Motor Company                                                                      46
# KIA                                                                                     46
# HONDA AUTOMOBILE THAILAND CO                                                            45
# Suzuki Motor Corporation                                                                44
# ANHUI JIANGHUAI AUTOMOBILE                                                              42
# MAN TRUCK & BUS SE                                                                      41
# AUDI AG DE-85045 Ingolstadt                                                             38
# FUJI HEAVY INDUSTRIE                                                                    36
# CATERHAM                                                                                35
# THINK GLOBAL                                                                            35
# PGO AUTOMOBILES                                                                         34
# GM DAEWWO AUTO U TECH COMP                                                              34
# SANTANA                                                                                 34
# MAN TRUCK & BUS AG                                                                      33
# unknown                                                                                 33
# LANZHOU ZHIDOU ELETTRIC VEHICLE CO LTD                                                  32
# HONDA CHINA                                                                             32
# ANHUI JIANGHUAI AUTOMOBILE GROUP CORP LTD                                               31
# SERES AUTO CO LTD                                                                       31
# MERCEDES AMG                                                                            30
# GM ITALIA                                                                               30
# AUDI HUNGARIA                                                                           29
# LTI CARBODIES                                                                           29
# ADIDOR VOITURES SAS                                                                     28
# GM DAEWOO AUTO U TECH COM                                                               28
# ASTON MARTIN                                                                            28
# LUCID USA INC                                                                           27
# Audi Sport GmbH                                                                         27
# CHEVROLET ITALIA                                                                        26
# DONGFENG MOTOR CORPORATION                                                              26
# DR MOTOR COMPANY                                                                        26
# HYUNDAI ASSAN OTOMOTIV                                                                  25
# NANJING GOLDEN DRAGON BUS CO LTD                                                        25
# PAGANI AUTOMOBILI SPA                                                                   23
# ALPINA                                                                                  23
# PORCHE                                                                                  23
# FORD MOTOR COMPANY OF AUSTRALIA LIMITED                                                 23
# DR AUTOMOBILES Srl                                                                      23
# MARUTI SUZUKI                                                                           22
# TOYOTA SOUTH AFRICA MOTORS LTD                                                          21
# LONDON EV COMPANY                                                                       21
# ROVER                                                                                   20
# NEXT E.GO MOBILE SE                                                                     20
# Land Rover Banbuty Road Gaydon  Warwick CV35 0RR  UK                                    20
# GENERAL MOTORS                                                                          19
# LOTUS CARS LTD                                                                          18
# ISUZU MOTORS LIMITED                                                                    18
# KOENIGSEGG AUTOMOTIVE AB                                                                18
# AA_NSS                                                                                  17
# HYUNDAI ASSAN OTOMOTIV SANAYI VE TICARET AS                                             16
# LOTUS                                                                                   15
# UNKNWON                                                                                 15
# KTM                                                                                     15
# Volkswagen AG Berliner Ring 2 D-38440 Wolfsburg                                         14
# MERCEDES-AMG                                                                            13
# GWM                                                                                     13
# OUT OF SCOPE                                                                            12
# OMCI SRL                                                                                12
# CNG-TECHNIK                                                                             12
# SHUANGHUAN                                                                              12
# ISUZU MOTORS LTD                                                                        12
# Subaru Corporation                                                                      12
# LONDON EV COMPANY LIMITED                                                               11
# AUTOVAZ                                                                                 11
# Avto VAZ                                                                                11
# TESLA                                                                                   11
# OSV                                                                                     10
# PGO                                                                                     10
# FIAT GROUP AUTOMOBILES                                                                  10
# RADICAL MOTOSPORT LTD                                                                    9
# BRABUS                                                                                   9
# EURASIA MOTOR COMPANY SRL                                                                9
# RADICAL MOTORSPORT LTD                                                                   9
# GENERAL MOTORS CORPORATIO                                                                8
# duplicate                                                                                8
# SECMA                                                                                    8
# HENAN SUDA ELECTRIC VEHICLES TECHNOLOGY CO LTD                                           8
# THINK                                                                                    8
# MITSUBISHI MOTORS EUROPE MME                                                             8
# LADA                                                                                     8
# BMW GMBH                                                                                 8
# LEAPMOTOR AUTOMOBILE CO LTD                                                              8
# KTM SPORTCAR GMBH                                                                        7
# JAGUARCARS LTD                                                                           7
# AUTOMOBILES PEUGEOT                                                                      7
# MERCEDES-AMG GMBH AFFALTE                                                                7
# LITEX MOTORS AD                                                                          7
# TAZZARI GL SPA                                                                           7
# TECNO MECCANICA IMOLA SPA                                                                7
# BUGATTI                                                                                  7
# NOBLE AUTOMOTIVE LTD                                                                     7
# HENAN SUDA ELECTRIC VEHICLE TECHNOLOGY CO LTD                                            7
# ADAM OPEL GmbH                                                                           7
# OMCI                                                                                     6
# BUGATTI RIMAC DOO                                                                        6
# HAIMA CAR CO LTD                                                                         6
# E-GO MOBILE AG                                                                           6
# CHERY AUTOMOBILE CO LTD                                                                  5
# BLUECAR ITALY SRL                                                                        5
# BENTLEY MOTORS LTD.                                                                      5
# KNAUS TABBERT GMBH                                                                       5
# HONDA AUTOMOBILE THAILAND CO LTD                                                         5
# FORD MOTOR COMPANY OF AUSTRALIA PTY LIMITED                                              5
# MICRO-VETT SPA                                                                           5
# Alfa Romeo SPA                                                                           5
# PIAGGIO & C SPA                                                                          5
# NATIONAL ELECTRIC VEHICLE SWEDEN                                                         5
# AUDI HUNGARIA MOTOR Kft.                                                                 5
# OMCI S.R.L.                                                                              5
# HYUNDAI MOTOR                                                                            5
# MARUTI SUZUKI CORPORATION LTD                                                            5
# RENAULT                                                                                  4
# MICRO-VETT                                                                               4
# DONKEVOORT AUTOMOBIELEN BV                                                               4
# ZEJIANG ZOYTE AUTOMOBILE MANUFACTURING CO LTD                                            4
# NEXT EGO MOBILE SE                                                                       4
# WIESMANN                                                                                 4
# WESTFIELD                                                                                4
# GUMPERT SPORTWAGENMANUFAKTUR GMBH                                                        4
# SSANGYONG MOTOR COMPANY                                                                  4
# MAHINDRA                                                                                 4
# FORD MOTOR COMPANY OF BRAZIL LTDA                                                        4
# MITSUBISHI MOTORS EUROPE B.V MME                                                         4
# UAZ                                                                                      4
# MCLAREN AUTOMOTIVE LIMITE                                                                4
# BENTLEY MOTORS LDT                                                                       4
# BEE BEE AUTOMOTIVE                                                                       4
# FISKER AUTOMOTIVE                                                                        4
# LADA FRANCE SAS                                                                          4
# JIANGLING MOTORS                                                                         4
# Adam Opel GmbH                                                                           4
# DAIMLER CHRYSLER CORPORATION                                                             4
# DONGFENG LIUZHOU MOTOR CO LTD                                                            4
# AUDI AG D-85045 Ingolstadt                                                               3
# WESTFIELD SPORTS CARS                                                                    3
# LADA FRANCE                                                                              3
# Mercedes-AMG GmbH                                                                        3
# SHIJIAZHUANG SHUANGHUAN AUTOMOBILE COMPANY                                               3
# HONDA TURKIYE                                                                            3
# FISKER AUTOMOTIVE INC.                                                                   3
# HENAN SUDA ELECTRIC VEHICLES TECHNOLOGY                                                  3
# Renault SAS 13-15 Quai Alphonse Le Gallo 92110 Boulogne-Billancourt France               3
# GM ITALIA SRL                                                                            3
# ROLLS ROYCE                                                                              3
# GENARAL MOTORS COMPANY                                                                   3
# FIAT GROUP AUTOMOBILES SPA (I)                                                           3
# JIANGLING MOTOR HOLDING CO., LTD.                                                        3
# JIANGXI JIANGLING GROUP ELECTRIC VEHICLE CO LTD                                          3
# GENERAL MOTOR COMPANY                                                                    3
# LANZHOU ZHIDOU ELECTRIC VEHICLE                                                          2
# QINGDAO BOFENG NEW ENERGY CO LTD                                                         2
# FSO                                                                                      2
# MERCEDES-AMG GMBH                                                                        2
# AUDI HUNGARIA MOTOR KFT. HU-9027                                                         2
# AUSTIN                                                                                   2
# LECAPITAINE INDUSTRIE                                                                    2
# VINFAST TRADING AND PRODUCTION JOINT STOCK COMPANY                                       2
# LEEH GROUP KFT                                                                           2
# MARUTI SUZUKI INDIA LTD.                                                                 2
# YUDO AUTO CO LTD                                                                         2
# ZHEJIANG HAOQING AUTOMOBILE MANUFACTURING CO LTD                                         2
# QOROS AUTOMOTIVE CO LTD                                                                  2
# AUTOMOBILIES PEUGEOT                                                                     2
# KUNDENBETREUUNG                                                                          2
# DUPLICATE                                                                                2
# SPYKER AUTOMOBIELEN BV                                                                   2
# SHANGHAI MAPLE AUTOMOBILE CO LTD                                                         2
# CECOMP S.P.A.                                                                            2
# SANTANA MOTOR SA                                                                         2
# MICRO-VETT SRL                                                                           2
# VOLGA                                                                                    1
# OSV OPEL SPECIAL VEHICLES GMBH                                                           1
# MOKE INTERNATIONAL LIMITED                                                               1
# ARTEGA AUTOMOBIL GMBH E CO KG                                                            1
# ARTEGA                                                                                   1
# MIA                                                                                      1
# AM GENERAL                                                                               1
# MICHALAK                                                                                 1
# VEHICULES ELECTRIQUES PININFARINA-BOLLORE SAS                                            1
# GUMPERT                                                                                  1
# VOLKSWAGEN AG                                                                            1
# RAW ENGINEERING                                                                          1
# General Motors Company                                                                   1
# VEHICULES ELECTRIQUES PININFARINA-BOLLORE S.A.S.                                         1
# ADRIA MOBIL D.O.O.                                                                       1
# LUANO CAMP                                                                               1
# China First Automotive Group Company                                                     1
# ZEJIANG ZOTYE AUTOMOBILE MANUFACTURING CO., LTD                                          1
# HUNAN JIANGNAN AUTOMOBILE MANUFACTURE CO LTD                                             1
# NANJING GOLDEN DRAGON BUS CO., LTD.                                                      1
# LUANO CAMP S.R.L.                                                                        1
# SANYANG                                                                                  1
# ZOTYE HOLDING NG GROUP                                                                   1
# quattro GmbH DE 74148 Nec                                                                1
# ssangyong motor company                                                                  1
# COMARTH                                                                                  1
# Unknown                                                                                  1
# BERTONE                                                                                  1
# ITALDESIGN GIUGIARO SPA                                                                  1
# FISKER                                                                                   1
# BOMBARDIER RECREATIONAL PRODUCTS                                                         1
# QINGDAO BOFENG NEW ENERGY CO. LTD                                                        1
# RENAULT TRUCKS SAS                                                                       1
# TAIQI ELECTRIC VEHICLE CO. LIMITED                                                       1
# POTENZA SPORTS CARS                                                                      1
# Aston Martin Lagonda Ltd                                                                 1
# KARMA AUTOMOTIVE LLC                                                                     1
# SSANGYONG                                                                                1
# SSANG YONG MOTOR COMPANY                                                                 1
# PIAGGIO                                                                                  1
# Adidor Voitures SAS                                                                      1
# ROLLS-ROYCE MOTOR CARS LT                                                                1
# DAF TRUCKS N.V.                                                                          1
# AUTOMOBILI LAMBORGHINI SP                                                                1
# MINI                                                                                     1
# AUTOMOBILES DANGEL                                                                       1
# ROLLS-ROYCE MOTORS CARS L                                                                1
# TOYOTA MOTOR EUROPE  NV SA                                                  0            1
# PERODUA UK LIMITED                                                                       1
# CHONGQING LIFAN PASSENGER VEHICLE CO LTD                                                 1
# TVR                                                                                      1
# Opel Automobile Gmbh                                                                     1
# UAZ                                                                                      1
# CHRYSLER GROUP LLC  1000 CHRYSLER DRIVE  AUBURN HILLS  MICHIGAN  USA 48326 2766          1
# DONG FENG                                                                                1
# Name: Man, dtype: int64

# %%
# Temporarily set the option to display all rows
with pd.option_context('display.max_rows', None, 'display.max_seq_items', None):
    # Convert the unique values to a pandas Series to ensure full display
    print(pd.Series(df['Mh'].value_counts()))
# Out:
# BMW AG                                              1955014
# VOLKSWAGEN                                          1953152
# MERCEDES-BENZ AG                                    1825205
# AUDI AG                                             1419262
# SKODA                                               1163682
# FORD WERKE GMBH                                      703349
# RENAULT                                              550884
# VOLVO                                                538602
# SEAT                                                 496161
# AUTOMOBILES PEUGEOT                                  337900
# OPEL AUTOMOBILE                                      304787
# PSA                                                  279158
# FIAT GROUP                                           278010
# OPEL                                                 268778
# JAGUAR LAND ROVER LIMITED                            265060
# TOYOTA                                               235862
# PORSCHE                                              223456
# AUTOMOBILES CITROEN                                  208749
# DACIA                                                145006
# NISSAN AUTOMOTIVE EUROPE                             133072
# AA-IVA                                                97830
# STELLANTIS EUROPE                                     89030
# KIA                                                   85326
# KIA SLOVAKIA                                          77738
# HYUNDAI CZECH                                         71059
# CHRYSLER                                              68016
# MAZDA                                                 65104
# HYUNDAI                                               59123
# ALFA ROMEO                                            50777
# BMW GMBH                                              42629
# HONDA MOTOR CO                                        41542
# AUDI SPORT                                            36686
# duplicate                                             34420
# HYUNDAI ASSAN                                         23586
# MAGYAR SUZUKI                                         20646
# MITSUBISHI MOTORS CORPORATION                         19334
# SUBARU                                                18796
# GM KOREA                                              16915
# UNKNOWN                                               16489
# MASERATI                                              16428
# TESLA                                                 15173
# AUDI HUNGARIA                                         15163
# TOYOTA MOTOR EUROPE                                   14432
# SUZUKI MOTOR CORPORATION                              14410
# FORD MOTOR COMPANY                                    12270
# SSANGYONG                                             11087
# MERCEDES AMG                                          10524
# PSA                                                    8855
# MAZDA EUROPE                                           7408
# NISSAN INTERNATIONAL SA                                7221
# HYUNDAI ASSAN                                          6987
# BENTLEY                                                5683
# SAAB                                                   4072
# ASTON MARTIN                                           4057
# FERRARI                                                4039
# POLESTAR                                               3895
# LAMBORGHINI                                            3586
# MERCEDES-AMG GMBH                                      3579
# GENERAL MOTORS COMPANY                                 3315
# MITSUBISHI MOTORS THAILAND                             3061
# ALPINE                                                 2596
# LOTUS                                                  2526
# MCLAREN                                                2507
# ROLLS ROYCE                                            2156
# SAIC MOTOR CORPORATION                                 2130
# JAGUAR                                                 2056
# MORGAN                                                 2030
# LADA                                                   1874
# ALPINA                                                 1760
# AA-NSS                                                 1669
# CNG TECHNIK                                            1491
# GENERAL MOTORS HOLDINGS                                1469
# MARUTI SUZUKI                                          1298
# MITSUBISHI MOTORS EUROPE                               1251
# DAIHATSU                                               1168
# JAGUAR CARS LTD                                        1145
# FORD INDIA                                             1145
# VAUXHALL                                                812
# DFSK                                                    798
# GTF INNOVATIONS                                         740
# INEOS                                                   721
# HONDA OF THE UK MANUFACTURING                           713
# ROLLS-ROYCE                                             570
# CATERHAM                                                526
# PROTON                                                  434
# MG MOTOR                                                411
# SUZUKI THAILAND                                         402
# RENAULT TRUCKS                                          370
# GEELY                                                   362
# HYUNDAI INDIA                                           337
# TATA                                                    333
# DR AUTOMOBILES                                          328
# NIO                                                     300
# CHEVROLET ITALIA                                        279
# MAHINDRA                                                252
# BYD                                                     237
# HYUNDAI CZECH                                           212
# WUHAN LOTUS                                             198
# PERODUA                                                 194
# DR MOTOR                                                174
# GREAT WALL MOTOR                                        172
# MAZDA                                                   161
# JIANGLING MOTOR                                         158
# FISKER                                                  138
# SAIC MAXUS                                              135
# CHRYSLER                                                130
# TOYOTA GAZOO RACING                                     126
# KTM                                                     111
# SMART                                                   103
# ZHAOQING                                                101
# MIA                                                     100
# SAIC                                                     96
# ROLLS-ROYCE MOTOR CARS LTD                               92
# LANZHOU                                                  86
# GM KOREA                                                 83
# CHINA FAW                                                82
# SECMA                                                    81
# BUGATTI                                                  81
# IVECO                                                    77
# ANHUI                                                    73
# KIA SLOVAKIA                                             64
# MARUTI SUZUKI INDIA LTD                                  62
# MAN                                                      60
# THINK GLOBAL                                             60
# LADA                                                     56
# DONKERVOORT                                              52
# MG                                                       51
# BLUECAR                                                  51
# PGO                                                      51
# BRILLIANCE SHINERAY                                      50
# SOVAB                                                    46
# DALLARA                                                  46
# SANTANA                                                  42
# OMCI                                                     38
# SERES AUTO                                               31
# LTI CARBODIES                                            29
# ISUZU                                                    28
# LEVC                                                     27
# ADIDOR                                                   27
# FORD MOTOR AUSTRALIA                                     27
# LUCID USA                                                27
# WIESMANN                                                 27
# NANJING GOLDEN DRAGON                                    25
# NEXT EGO MOBILE                                          24
# LTI CARBODIES                                            23
# PAGANI                                                   22
# ROVER                                                    20
# KOENIGSEGG                                               18
# HENAN SUDA                                               18
# DONGFENG MOTOR                                           18
# IVECO SPA                                                17
# SAIC MOTOR                                               15
# BENTLEY                                                  15
# AUTOMOBILES DANGEL                                       12
# SHUANGHUAN                                               12
# BORGWARD                                                 11
# WESTFIELD                                                11
# OSV                                                      10
# MICRO VETT                                                9
# EURASIA                                                   9
# LEAPMOTOR                                                 8
# RADICAL MOTOSPORT                                         8
# TAZZARI                                                   7
# TECNO MECCANICA                                           7
# SHIJIAZHUANG SHUANGHUAN                                   7
# LITEX MOTORS                                              7
# NOBLE                                                     7
# RADICAL MOTORSPORT                                        7
# CNG-TECHNIK                                               6
# JAGUAR                                                    6
# HAIMA                                                     6
# E-GO                                                      6
# BUGATTI RIMAC                                             6
# SUZUKI MOTOR CORPORATION                                  5
# BLUECAR ITALY                                             5
# NEVS                                                      5
# CHERY                                                     5
# MICRO-VETT                                                4
# DONGFENG                                                  4
# GUMPERT                                                   4
# DONGFENG LIUZHOU                                          4
# SHANGHAI MAPLE                                            4
# ZOTYE                                                     4
# PIAGGIO                                                   4
# DONKEVOORT                                                4
# ARTEGA                                                    3
# FORD MOTOR BRASIL                                         3
# JIANGXI JIANGLING                                         3
# POTENZA SPORTS CARS                                       3
# UAZ                                                       2
# DONGFENG MOTOR CORPORATION                                2
# RADICAL MOTORSPORT LTD                                    2
# YUDO AUTO                                                 2
# CECOMP                                                    2
# CHONGQING LIFAN                                           2
# LEEH                                                      2
# ZHEJIANG HAOQING                                          2
# BEE BEE                                                   2
# BEE                                                       2
# OSV OPEL SPECIAL VEHICLES                                 2
# ZOTYE HOLDING NG GROUP                                    2
# QOROS                                                     2
# VINFAST                                                   2
# VEPB                                                      1
# AC CARS                                                   1
# TAIQI                                                     1
# VEHICULES ELECTRIQUES PININFARINA-BOLLORE S.A.S.          1
# FSO                                                       1
# General Motors Company                                    1
# HUNAN JIANGNAN                                            1
# BRABUS                                                    1
# ITALDESIGN                                                1
# SPYKER                                                    1
# KOENIGSEGG                                                1
# MOKE                                                      1
# NANJING GOLDEN DRAGON BUS CO., LTD.                       1
# AUDI HUNGARIA                                             1
# CECOMP S.P.A.                                             1
# Name: Mh, dtype: int64

# %%
# Define the mappings for each remapped value
import pandas as pd

mappings = [
    # 'DAIMLER AG' changed its name to 'MERCEDES-BENZ AG'
    (['DAIMLER AG'], 'MERCEDES-BENZ AG'),
    # 'NISSAN' is mapped to 'NISSAN AUTOMOTIVE EUROPE' as the official entity
    (['NISSAN'], 'NISSAN AUTOMOTIVE EUROPE'),
    # 'STELLANTIS AUTO' is mapped to 'STELLANTIS EUROPE' as per official naming
    (['STELLANTIS AUTO'], 'STELLANTIS EUROPE'),
    # Entries labeled 'duplicate' are mapped to 'duplicate' instead of 'UNKNOWN'
    (['DUPLICATE', 'Duplicate', 'duplicate'], 'duplicate'),
    # 'FIAT GROUP AUTOMOBILES SPA' is simplified to 'FIAT GROUP'
    (['FIAT GROUP AUTOMOBILES SPA'], 'FIAT GROUP'),
    # Full company name 'BAYERISCHE MOTOREN WERKE AG' is mapped to 'BMW AG'
    (['BAYERISCHE MOTOREN WERKE AG'], 'BMW AG'),
    # 'TOYOTA MOTOR CORPORATION' and 'TOYOTA MOTOR EUROPE' are simplified to 'TOYOTA'
    (['TOYOTA MOTOR CORPORATION', 'TOYOTA MOTOR EUROPE'], 'TOYOTA'),
    # Correcting typo in 'FORD-WERKE GMBH' to 'FORD WERKE GMBH'
    (['FORD-WERKE GMBH'], 'FORD WERKE GMBH'),
    # Mapping various regional 'HONDA' entities to 'HONDA MOTOR CO'
    (['HONDA UK', 'HONDA OF THE UK MANUFACTURING', 'HONDA TURKIYE', 'HONDA TURKIYE AS',
      'HONDA CHINA', 'HONDA AUTOMOBILE CHINA CO', 'HONDA THAILAND', 'HONDA AUTOMOBILE THAILAND CO'],
     'HONDA MOTOR CO'),
    # 'FUJI HEAVY INDUSTRIES' and 'FUJI HEAVY INDUSTRIES LTD' are parent companies of 'SUBARU'
    (['FUJI HEAVY INDUSTRIES', 'FUJI HEAVY INDUSTRIES LTD'], 'SUBARU'),
    # 'LAND ROVER' is part of 'JAGUAR LAND ROVER LIMITED'
    (['LAND ROVER'], 'JAGUAR LAND ROVER LIMITED'),
    # 'CHRYSLER GROUP LLC' is simplified to 'CHRYSLER'
    (['CHRYSLER GROUP LLC'], 'CHRYSLER'),
    # Full company name 'MAZDA MOTOR CORPORATION' is simplified to 'MAZDA'
    (['MAZDA MOTOR CORPORATION'], 'MAZDA'),
    # 'QUATTRO' is a model line of 'AUDI AG'
    (['QUATTRO'], 'AUDI SPORT'),
    # Correcting double space typo in 'HYUNDAI  CZECH' to 'HYUNDAI CZECH'
    (['HYUNDAI  CZECH'], 'HYUNDAI CZECH'),
    # Correcting misspelling in 'MITSUBISHI MOTORS CORPORTION MMC' to 'MITSUBISHI MOTORS CORPORATION'
    (['MITSUBISHI MOTORS CORPORTION MMC'], 'MITSUBISHI MOTORS CORPORATION'),
    # 'GM DAEWOO AUTO U TECH COMP' is now known as 'GM KOREA'
    (['GM DAEWOO AUTO U TECH COMP'], 'GM KOREA'),
    # 'SAAB AUTOMOBILE AB' is simplified to 'SAAB'
    (['SAAB AUTOMOBILE AB'], 'SAAB'),
    # 'AVTOVAZ' is the manufacturer of 'LADA' cars
    (['AVTOVAZ'], 'LADA'),
    # 'BMW M GMBH' is now mapped to 'BMW GMBH'
    (['BMW M GMBH'], 'BMW GMBH'),
    # 'KG MOBILITY' is the new name for 'SSANGYONG' as of 2023
    (['KG MOBILITY'], 'SSANGYONG'),
    # Full company name 'MAGYAR SUZUKI CORPORATION LTD' is simplified to 'MAGYAR SUZUKI'
    (['MAGYAR SUZUKI CORPORATION LTD'], 'MAGYAR SUZUKI'),
    # 'GTF INNOVATIONS' left as is
    (['GTF INNOVATIONS'], 'GTF INNOVATIONS'),
    # 'HYUNDAI EUROPE' is simplified to 'HYUNDAI'
    (['HYUNDAI EUROPE'], 'HYUNDAI'),
    # Full company name 'DAIHATSU MOTOR CO' is simplified to 'DAIHATSU'
    (['DAIHATSU MOTOR CO'], 'DAIHATSU'),
    # 'MITSUBISHI MOTORS EUROPE BV MME' is simplified to 'MITSUBISHI MOTORS EUROPE'
    (['MITSUBISHI MOTORS EUROPE BV MME'], 'MITSUBISHI MOTORS EUROPE'),
    # Full company name 'ASTON MARTIN LAGONDA LTD' is simplified to 'ASTON MARTIN'
    (['ASTON MARTIN LAGONDA LTD'], 'ASTON MARTIN'),
    # 'LOTUS GROUP PLC' is simplified to 'LOTUS'
    (['LOTUS GROUP PLC'], 'LOTUS'),
    # Full company name 'MASERATI SPA' is simplified to 'MASERATI'
    (['MASERATI SPA'], 'MASERATI'),
    # Correcting double space typo in 'HYUNDAI  INDIA' to 'HYUNDAI INDIA'
    (['HYUNDAI  INDIA'], 'HYUNDAI INDIA'),
    # 'MIA' is left as is
    (['MIA'], 'MIA'),
    # 'GM ITALIA' is mapped to 'GENERAL MOTORS HOLDINGS' as the parent company
    (['GM ITALIA'], 'GENERAL MOTORS HOLDINGS'),
    # 'LADA FRANCE' is simplified to 'LADA'
    (['LADA FRANCE'], 'LADA'),
    # 'DR MOTOR COMPANY' is simplified to 'DR MOTOR'
    (['DR MOTOR COMPANY'], 'DR MOTOR'),
    # Correcting plural in 'JIANGLING MOTORS' to 'JIANGLING MOTOR'
    (['JIANGLING MOTORS'], 'JIANGLING MOTOR'),
    # Correcting spelling in 'ZOYTE' to 'ZOTYE'
    (['ZOYTE'], 'ZOTYE'),
    # 'LANZHOU ZHIDOU' is simplified to 'LANZHOU'
    (['LANZHOU ZHIDOU'], 'LANZHOU'),
    # 'OUT OF SCOPE' is turned to pd.NA
    (['OUT OF SCOPE'], pd.NA),
]


# Now, apply the mapping to our DataFrame
rename_catval(df, 'Mh', mappings)

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh.parquet")

# %% [markdown]
# ## **IT, Ernedc, Erwltp**

# %% [markdown]
# ### **explore**

# %%
df.IT.value_counts()
# Out:
# e1 29               348575
# E1 29               206902
# e8 29 37            184344
# e13 29 37           141103
# e13 29              135410
#                      ...
# e4 / e4 28               1
# E2 E2 29                 1
# E2 37 029                1
# e4 17 19e4 29 28         1
# no                       1
# Name: IT, Length: 1928, dtype: int64

# %%
df["Ernedc (g/km)"].hist(bins = 50)
# Out:
# <Axes: >

# %%
df["Erwltp (g/km)"].hist(bins = 200)
plt.xlim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### **clean**

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh.parquet")

# %% [markdown]
# #### Step 1-8: cleanup

# %%
# Processing IT column to extract individual IT Codes

# Step 0: Initialize 'IT_valid' and 'IT_invalid' columns with np.nan
df['IT_valid'] = np.nan
df['IT_invalid'] = df['IT']

# Step 1: Replace Invalid Characters
def replace_invalid_chars(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values that have invalid characters
    matches = original_series.str.contains(r'[^a-zA-Z0-9\+\?]', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Replace invalid characters with space
    series[matches] = series[matches].str.replace(r'[^a-zA-Z0-9\+\?]', ' ', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 1
df['IT_invalid'], matched_values_invalid_chars, modified_rows_invalid_chars, diff_nunique_invalid_chars = replace_invalid_chars(df['IT_invalid'])
print(f"Modified {modified_rows_invalid_chars} rows by replacing invalid characters.")
print(f"Change in number of unique values: {diff_nunique_invalid_chars}")
print("Values that had invalid characters (original state):")
print(matched_values_invalid_chars)

# Step 2: Strip Leading and Trailing Spaces
def strip_spaces(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values with leading or trailing spaces
    matches = original_series.str.contains(r'^\s+|\s+$', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Strip leading and trailing spaces
    series[matches] = series[matches].str.strip()

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 2
df['IT_invalid'], matched_values_strip_spaces, modified_rows_strip_spaces, diff_nunique_strip_spaces = strip_spaces(df['IT_invalid'])
print(f"Modified {modified_rows_strip_spaces} rows by stripping leading and trailing spaces.")
print(f"Change in number of unique values: {diff_nunique_strip_spaces}")
print("Values that had leading or trailing spaces (original state):")
print(matched_values_strip_spaces)

# Step 3: Reduce Multiple Spaces to Single Spaces
def reduce_multiple_spaces(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values with multiple spaces
    matches = original_series.str.contains(r'\s{2,}', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Replace multiple spaces with a single space
    series[matches] = series[matches].str.replace(r'\s{2,}', ' ', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 3
df['IT_invalid'], matched_values_reduce_spaces, modified_rows_reduce_spaces, diff_nunique_reduce_spaces = reduce_multiple_spaces(df['IT_invalid'])
print(f"Modified {modified_rows_reduce_spaces} rows by reducing multiple spaces to single spaces.")
print(f"Change in number of unique values: {diff_nunique_reduce_spaces}")
print("Values that had multiple spaces (original state):")
print(matched_values_reduce_spaces)

# Step 4: Replace 'E' Not Followed by a Letter with 'e'
def replace_E_not_followed_by_letter(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify 'E' not followed by a letter
    matches = original_series.str.contains(r'E(?![a-zA-Z])', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Replace 'E' not followed by a letter with 'e'
    series[matches] = series[matches].str.replace(r'E(?![a-zA-Z])', 'e', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 4
df['IT_invalid'], matched_values_replace_E, modified_rows_replace_E, diff_nunique_replace_E = replace_E_not_followed_by_letter(df['IT_invalid'])
print(f"Modified {modified_rows_replace_E} rows by replacing 'E' not followed by a letter with 'e'.")
print(f"Change in number of unique values: {diff_nunique_replace_E}")
print("Values that had 'E' not followed by a letter (original state):")
print(matched_values_replace_E)

# Step 5: Replace 'i', 'I', 'l', 'L' Not Followed by a Letter with '1'
def replace_iIlL_not_followed_by_letter(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify 'i', 'I', 'l', 'L' not followed by a letter
    matches = original_series.str.contains(r'[iIlL](?![a-zA-Z])', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Replace 'i', 'I', 'l', 'L' not followed by a letter with '1'
    series[matches] = series[matches].str.replace(r'[iIlL](?![a-zA-Z])', '1', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 5
df['IT_invalid'], matched_values_replace_iIlL, modified_rows_replace_iIlL, diff_nunique_replace_iIlL = replace_iIlL_not_followed_by_letter(df['IT_invalid'])
print(f"Modified {modified_rows_replace_iIlL} rows by replacing 'i', 'I', 'l', 'L' not followed by a letter with '1'.")
print(f"Change in number of unique values: {diff_nunique_replace_iIlL}")
print("Values that had 'i', 'I', 'l', 'L' not followed by a letter (original state):")
print(matched_values_replace_iIlL)

# Step 6: Eliminate Spaces After 'e'
def eliminate_spaces_after_e(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values with spaces after 'e'
    matches = original_series.str.contains(r'e\s+', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Replace one or more spaces after 'e' with 'e'
    series[matches] = series[matches].str.replace(r'e\s+', 'e', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 6
df['IT_invalid'], matched_values_spaces_after_e, modified_rows_spaces_after_e, diff_nunique_spaces_after_e = eliminate_spaces_after_e(df['IT_invalid'])
print(f"Modified {modified_rows_spaces_after_e} rows by eliminating spaces after 'e'.")
print(f"Change in number of unique values: {diff_nunique_spaces_after_e}")
print("Values that had spaces after 'e' (original state):")
print(matched_values_spaces_after_e)

# Step 7: Remove Leading Zeros in Country Codes and Type Codes
def remove_leading_zeros(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values with leading zeros in country codes or type codes
    matches = original_series.str.contains(r'e0\d', regex=True) | original_series.str.contains(r'\s0\d', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Remove leading zeros in country codes: 'e0X' -> 'eX'
    series[matches] = series[matches].str.replace(r'e0(\d)', r'e\1', regex=True)

    # Remove leading zeros in type codes: ' 0Y' -> ' Y'
    series[matches] = series[matches].str.replace(r'\s0(\d)', r' \1', regex=True)

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 7
df['IT_invalid'], matched_values_leading_zeros, modified_rows_leading_zeros, diff_nunique_leading_zeros = remove_leading_zeros(df['IT_invalid'])
print(f"Modified {modified_rows_leading_zeros} rows by removing leading zeros in country and type codes.")
print(f"Change in number of unique values: {diff_nunique_leading_zeros}")
print("Values that had leading zeros in country or type codes (original state):")
print(matched_values_leading_zeros)

# Step 8: Eliminate Trailing Country Codes
def eliminate_trailing_country_codes(series):
    series = series.astype(str)
    original_nunique = series.nunique()
    original_series = series.copy()

    # Identify values that have trailing country codes without type codes
    matches = original_series.str.contains(r'e(?:[1-9]|[1-2][0-9]|3[0-5])\s*$', regex=True)
    matched_values = original_series[matches].unique().tolist()

    # Remove trailing country codes
    series[matches] = series[matches].str.replace(r'e(?:[1-9]|[1-2][0-9]|3[0-5])\s*$', '', regex=True)

    # Strip any trailing spaces resulting from removal
    series[matches] = series[matches].str.rstrip()

    # Convert back to category
    series = series.astype('category')

    # Calculate modifications
    modified_rows = matches.sum()
    diff_nunique = series.nunique() - original_nunique

    return series, matched_values, modified_rows, diff_nunique

# Execute Step 8
df['IT_invalid'], matched_values_trailing_cc, modified_rows_trailing_cc, diff_nunique_trailing_cc = eliminate_trailing_country_codes(df['IT_invalid'])
print(f"Modified {modified_rows_trailing_cc} rows by eliminating trailing country codes.")
print(f"Change in number of unique values: {diff_nunique_trailing_cc}")
print("Values that had trailing country codes (original state):")
print(matched_values_trailing_cc)
# Out:
# Modified 4874700 rows by replacing invalid characters.
# Change in number of unique values: -73
# Values that had invalid characters (original state):
# ['e1 8', 'e1 3', 'e1 08', ' ', 'e24 10 e24 3 e24 9', 'e24 9', 'e24 10 e24 9', 'e24 3 e24 9', 'e24 2', 'e24 10 e24 2', 'E24 3. E24 9', 'E24 10. E24 3. E24 9', 'E24 2', 'E24 10. E24 2', 'E24 9', 'E24 10. E24 9', 'e 24 3 e24 9', 'e 24 2', 'e24 3 9', 'e24 10 3 9', 'e24 3 9 10', 'e24 9 10', 'e24 2 10', '715/2007/EC*136/2014/EC  (ZX)', '715/2007/EC*136/2014/EC (ZX)', '715/2007/EC*136/2014/EC (J)', '715/2007/EC*136/2014/EC  (J)', 'e24 3, e24 9', 'e1 10', 'e1 10 8', 'e1 2', 'E24 3, E24 9', 'e24 10, e24 3, ', 'E13 1', 'e13 1', 'E1 8', 'E1 10', 'E1 3', 'e1 8 10', '715/2007/EC*195/2013/EC (J)', 'E24 10', 'E1 2', 'E24 3 9', 'E24 10 9', 'E1 08', 'e24 10', 'e24 3  e24 9', 'e24 10  e24 3  e24 9', 'e24 9  ', 'e24 10 e24 9 ', 'e24 3 e24 9 ', 'e24 2  ', 'e24 10  e24 9', 'e24 10 9', 'e1 13', 'e1 10 3', 'E1 10 8', 'e 24 9', 'e1 0', 'E24 3 9 10', 'e1 3 10', 'e24 10, e24 3, e24 9', 'E1 10 3', 'e 24 10 e24 9', 'e 24 10 e 24 3 e24 9', 'E24 10 3 9', 'E1 13', 'e11*19', 'e24*10', 'e24*9', 'e24*10 e24*9', 'e24*3 e24*9', 'e24*2', 'e1 19', 'e24 9 19', 'e24 9 e24 10', 'e1 9', 'e11 19', 'e24 19', 'e8 19', 'e 11 19', 'e8*19', 'e24 10 2', 'e24 19 e24 9', 'e1 18', 'e1 12', 'e24 9 ', 'e1 8 ', 'E24 10                 ', 'E19                    ', 'E24 9 10               ', 'E24 3 9 10             ', 'E24 9 19               ', 'E24 10. E24 9          ', 'E24 3 9                ', 'E24 9                  ', 'E24 19                 ', 'E24  19                ', 'E24 3. E24 9           ', 'E24 10. E24 3. E24 9   ', 'E8 19                  ', 'E11 19                 ', 'E24 2                  ', 'e24 19 9', 'E1 08                  ', 'e24 3', 'e24 10, e24 9', 'e24  19', 'E24 10 2', 'E24 9 10', 'E24 2 10', 'e 19', 'E24 9 19', 'E24 19', 'E1 19', 'E11 19', 'e 1 19', 'E8 19', 'e24 10, e24 2', 'e24 1', 'e1 2 10', 'e1 08 ', 'e1*8', 'e1*2', 'Not applicable', 'e13 19', 'e6 19', 'e9 19', '17 19', '17;19', 'E1 9', 'e 24 9 19', '19 1', 'e 24 19', 'e3 17', 'e3 17 19', 'E13 19', 'e3 19', '                         ', 'E 13 19', 'E24 10, E24 9', 'E24  19', 'E9 19', 'E6 19', 'e24 10 9 ', '-', 'E1-08', 'e24*19', 'e24*9*19', 'e1*10', 'e*19', 'e13*19', 'e1*19', 'e1*08', 'e1*9', 'e1-08', 'e2 4', 'E24 10, E24 3, E24 9', 'e24 9, e24 10', 'e1 2 ', 'E24 9 19                 ', 'E24 9                    ', 'E24 19                   ', 'E24 10                   ', 'E1 08                    ', 'E24  19                  ', 'E24 3 9 10               ', 'E24 3 9                  ', 'E24 10               ', 'E24 9 10                 ', 'E13 19                   ', 'E1 19                    ', 'E11 19                   ', 'e24 19, 9', 'e24 19   9', 'e29 9 19', 'e1 8  ', 'e1 9  ', 'e1 2  ', '          ', 'e24 19  9', 'E1 8 13', 'e 8 19', 'e 24 9 10', 'e2 22', 'e6 20', 'e2 17', 'e9 17 19', 'e9 17', 'e24 10 17', 'e5 17', 'e24 17', 'e24 17 19', 'e6 15', 'e13 17 19 low', 'e13 17 19', 'e13 17 19 mid', 'e8 17 19', 'e24 17 19 25', 'e2 12', 'e1 02', 'e24 3 17', 'e24 3 17 19', 'e13 22', 'e 20', 'e13 17', 'e24 3 19', 'e2 17 e9 17', 'e17 19', 'e2 19', 'e11 20', 'e1 14', 'e1 17', 'e2 17 19', 'e24 3 10', 'e24 3 17 19 25', 'e24 17 25', 'e9 27 19', 'e13 3', 'e4 17', 'e11 17', 'e34 3 17', 'e13 13', 'e8 17', 'e4 19', 'e24 3 10 17', 'e24 3 9 19', 'e4 17 19', 'e1 7', 'e13 19 22', 'e11 1 19', 'e11 119', 'e4 19 22', 'e2 19 22', 'e2 19 17', 'e24 3 17 25', 'e24 17 3', 'e24 19 3', 'e24 17 19 3', 'e12 17 19', 'e4 22', 'e24 3 27', 'e27 19', 'e24 2 19', 'e 17 e 19', 'e24 19 e19 9', '0.00e + 11', '1.47e + 12', '0.97e + 11', '4.43e + 11', '4.00e + 11', 'e1 8 13', 'e 15', 'e1 4', '1.12e + 11', '2.34e + 11', '1.35e + 11', '0.13e + 11', '2.27e + 11', '0.96e + 11', '1.02e + 11', '3.65e + 11', '2.56e + 11', '0.91e + 11', '2.80e + 11', '0.66e + 11', '0.03e + 11', '0.20e + 11', '0.95e + 11', '0.79e + 11', '1.60e + 11', 'e24 3  19', 'e24 3 19 17', 'e13 15', 'e2 24', 'e9 17 1', '2013/341 e1 2', 'e24 17 10', 'e24 3 17 10', 'e19 1', 'e24 3 17 1', 'e24 3 17 2', 'e24 3 10 1', 'e24 10 e2', 'e13 19 17', 'e3 19 17', 'e2 43 17 19', 'e24 17 19 25 ...
# Modified 95036 rows by stripping leading and trailing spaces.
# Change in number of unique values: -229
# Values that had leading or trailing spaces (original state):
# [' ', '715 2007 EC 136 2014 EC   ZX ', '715 2007 EC 136 2014 EC  ZX ', '715 2007 EC 136 2014 EC  J ', '715 2007 EC 136 2014 EC   J ', 'e24 10  e24 3  ', '715 2007 EC 195 2013 EC  J ', 'e24 9  ', 'e24 10 e24 9 ', 'e24 3 e24 9 ', 'e24 2  ', 'e24 9 ', 'e1 8 ', 'E24 10                 ', 'E19                    ', 'E24 9 10               ', 'E24 3 9 10             ', 'E24 9 19               ', 'E24 10  E24 9          ', 'E24 3 9                ', 'E24 9                  ', 'E24 19                 ', 'E24  19                ', 'E24 3  E24 9           ', 'E24 10  E24 3  E24 9   ', 'E8 19                  ', 'E11 19                 ', 'E24 2                  ', 'E1 08                  ', 'e1 08 ', '                         ', 'e24 10 9 ', 'e1 2 ', 'E24 9 19                 ', 'E24 9                    ', 'E24 19                   ', 'E24 10                   ', 'E1 08                    ', 'E24  19                  ', 'E24 3 9 10               ', 'E24 3 9                  ', 'E24 10               ', 'E24 9 10                 ', 'E13 19                   ', 'E1 19                    ', 'E11 19                   ', 'e1 8  ', 'e1 9  ', 'e1 2  ', '          ', ' e5 17 e5 29 ', ' e4 17 19 e4 29 28 ', ' e4 19 e4 28 ', 'e8 17 19 ', 'E4 29 E4 28 E4  E4 ', 'E ', 'e17 e19 e29 e28 ', 'E4 29 28 ', 'E4 29 E4 ', 'E2 29 ', 'e9  28 29 ', 'E9  28 29 ', 'E2 28 ', ' E5 28', 'E19  E19 28 29 ', 'e13 29 ', 'e19  e19 28 29 ', 'E4 32 37 ', 'E2  28 29 ', 'E1 29 ', 'e24 28 29 ', 'E5 E5 29 ', 'E24 28 29 ', 'E9 219 28 29 ', 'E4 28 ', 'E13 28 29 ', 'E2 29 28 ', 'E13 29 37 ', 'E13 29 ', 'E6 28 ', 'E19  E19 29 37 ', 'E24 3  28 ', 'E2  28 ', 'E24 3  28 29 ', 'E9 32 37 ', 'E8 29 ', 'E3 E3 33 ', 'E2 28 29 ', 'E2 29 37 ', 'E2 E2 29 ', 'E13 28 ', 'e2 29 ', 'e6  28 ', 'e2  28 29 ', 'e2 28 29 ', 'e8  29 28 ', 'e4  29 28 ', 'e4  28 ', 'e4  29 ', 'e13  28 29 ', 'e13 28 29 ', 'e1 29 ', 'e13  29 ', 'e24  28 29 ', 'e24  29 ', 'e9  29 ', 'e24 32 37 ', 'e24  28 ', 'e13  28 ', 'e1 28 29 ', ' e2 29', ' e19 28 29', ' e9 29', ' e6 28', ' e2 33', ' e2 28', ' e9 28', 'e13 3 28 ', 'e5 29 ', 'e4 29e4 28e4 e4 ', ' e2  28 29', 'e4 29 e4 28e4  e4 ', 'e4 29 e4 28 e4 e4 ', 'e4 29e4 28 e4 e4 ', 'e4 29e4 28 e4  e4 ', 'e4 32 37 ', 'e4 29e4 28e4  e4 ', 'e4 29 28 ', 'e429e428e417e4 ', 'e4 29 e4 28 e4 ', 'e4 29 28  ', 'e4 292817 ', ' e2 28 29', 'E4 33 37 ', 'e2  28 ', 'e4 32 ', 'e29 28 ', 'e4 29 2817 ', 'e2 29 28 ', 'e2 29 28  ', 'e2 29 e2 28 e2 e2 ', ' e5 29  e5 28', 'e2 29e2 28e2 e2 ', 'e2 29 e2 28 e2 ', 'e5 37 e9 32 ', ' e19 29 37', '  e19 28 29', ' e5 29', ' e9 37', '  e5  e5 29  ', '  e4   e4 29 28  ', '  e4  e4 28  ', 'e6  e6 28 ', 'e9 37 ', 'e11  e5 28 ', 'e8  28 29 ', 'e8  29 ', 'e8   28 29 ', 'e5  29 28 ', 'e8 25 29 ', 'e8  25 28 29 ', 'e4 29 e4 28 e4  e4 ', ' E19 28 29', ' E6 28', ' E9 29', ' E2 29', ' E2 28 29', ' E2 28', ' e5  e5 29', ' e5 28 WLTP', ' e3 29 28', 'e4 28  e4   ', 'e5   e5 28  ', 'e11   e5 28 ', 'e5 28 ', 'e4 29 e4 ', 'e4 29 ', 'e8  28 ', 'e8 28 ', 'e8 29 37 ', 'e8 28 29 ', 'e8 29 ', 'e9 29 ', 'e4 28 ', 'e9 29 e9 28 ', 'e5 32 ', 'e24 32 ', 'e24 29 ', 'e3 25 29 ', ' e4 37', 'e8 25 28 ', 'e3 29 28 ', 'e1 28 ', ' E9 28', ' e5 28', 'e13 28 ', 'e1 29     ', 'e6 28 ', 'e5 28 WLTP ', 'e13 33 37 ', 'e2 29 37 ', 'e2 28 ', 'e24 3  28 ', 'e24 29 37 ', 'e24 3  28 29 ', 'e9 32 37 ', 'e2 37 ', 'e9 28 29 ', 'e9 29 37 ', 'e8 37 ', 'e4 33 37 ', 'e6 37 ', 'e2 33 ', 'e1 29 37 ', ' e8 37', ' e24 28 e24 29', ' e3 28 e3 29', ' e1 29', ' e2 28 e2 29', ' e4 28 e4 29', 'E4 29 ', ' e13  28 29', 'e ', 'e24 3 29 ', 'e9 32 ', 'e13 37 ', 'e13  32 ', 'e11 28 ', ' e4 29 28', ' e5 29 28', 'e9 29 28 ', 'e5 32 37 ', 'e5 37 ', 'e2 28 33 ', 'e5 28  ', 'e3 32 ', 'e13 28  ', 'e13 29 37 ', 'e13 33 ', 'e24 37 ', 'e8 29 37  ', ' e1 28 e1 29', ' e24 29', ' e5 32', ' e4 28', ' e5 37', 'e19 29 37 ', 'e2 33 37 ', 'e9 28 ', 'E2 33 ', 'E24 29 ', 'E5 32 ', 'E5 29 ', 'E6 37 ', 'E2 28 E2 29 ', 'E2 37 ', 'E32 37 ', 'E13 37 ', 'E9 29 ', 'E9 29  ', 'E2 29   ', ' e5 32  e5 37', 'E9 29 37 ', 'e5 37    e9 32  ', 'e1 29  ']
# Modified 131379 rows by reducing multiple spaces to single spaces.
# Change in number of unique values: -249
# Values that had multiple spaces (original state):
# ['E24 3  E24 9', 'E24 10  E24 3  E24 9', 'E24 10  E24 2', 'E24 10  E24 9', '715 2007 EC 136 2014 EC   ZX', '715 2007 EC 136 2014 EC  ZX', '715 2007 EC 136 2014 EC  J', '715 2007 EC 136 2014 EC   J', 'e24 3  e24 9', 'e24 10  e24 3', '715 2007 EC 195 2013 EC  J', 'e24 10  e24 3  e24 9', 'e24 10  e24 9', 'E24  19', 'e24  19', 'e24 10  e24 2', 'e24 9  e24 10', 'e24 19  9', 'e24 19   9', 'e24 3  19', 'E24 3  E24  19', 'e24 3 e24  19', 'E6 19  E6 28', 'e11  19', 'e2 19  28', 'e19 17 19  e19 28 29', 'e9 19  28', 'e2 19  e2 28', 'e9 19  e9 28', 'E2  17', 'e4  17 e4 19', 'e4 17  e4', 'e2  17', 'e2  17 19', 'e9 17  e9 29', 'e9  17', 'e2 17 19  28 29', 'e2 17  e2 29', 'e6 19  e6 28', 'e13 3  e13 19', 'e2 17 19  e2 28 29', 'e9 17 19  e9 28 29', 'e2 17  e2 19', 'e9 17 19  e9 29 28', 'e24 17  e24 19', 'E2 19  E2 28', 'E9 19  E9 28', 'E9 17  E9 29', 'E9 17 19  E9 28 29', 'E2 17 19  E2 28 29', 'E9 17 19  E9 29 28', 'E2 17  E2 29', 'e4  28', 'e24 17 19  28 29', 'e24 17  25', 'e24 17  29', 'e24 17  19', 'e24  27 e24 3 e24 28', 'e9 17  29', 'e4 17  19', 'e4 17  19 28', 'E13 3  E13 19', 'e2 19  e2 17', 'e6 19  28', 'E4  22', 'e24 3 17  25', 'e5 19  28', 'e24  17 19', 'e8  19', 'e8  19 25 28', 'e4  22', 'E24  3 17 19', 'e24 3  17', 'e8 19  25', 'E19 17 19  E19 28 29', 'e13 17  19', 'e4 19  e4 28', 'e24 17 19  25', 'e24 19  3', 'e9  28 29', 'e9  32', 'E2  28 29', 'e5  e5 29', 'e13  28 29', 'e4  e4 28', 'E4 29 E4 28 E4  E4', 'E2  29 28', 'e13  32', 'e13  28', 'E4  E4  E4 28', 'e4   e4 29 28', 'e13  37', 'E4  29 28', 'E4  E4  E4 29 E4 28', 'e5  e5 28', 'e8  28 29', 'e24 3  28', 'e24  3 28', 'e5  e5 e5 29 e5 28', 'e24  28 29', 'e24  28', 'e8  25 28 29', 'E9  E9 29 28', 'E2  E2 33', 'E24 3  28', 'E9  28 29', 'E9  E9 28 29', 'E24  28 29', 'E13  29', 'E24  28', 'E9  32', 'E5  E5 28', 'E2  28', 'E19  E19 28 29', 'e19  e19 28 29', 'e2 28  e2 29', 'E9  E19 28 29', 'E19  E19 29 37', 'E24 3  28 29', 'E2  E2 29', 'e2  28 29', 'e6  28', 'e3  28 29', 'e4  28 29', 'e8  29 28', 'e4  29 28', 'e4  29', 'e13  29', 'e24  3 28 29', 'e24 3  28 29', 'e24  29', 'e9  29', 'e3  28', 'e13  29 28', 'e619   e6 28', 'e2  2829', 'e9  e9 29', 'e9  e29', 'e5 29  e5 28', 'e9 29  e9 28', 'e4 29 e4 28e4  e4', 'e2   e2 28 29', 'e5 e5  e5 29 e5 28', 'E  e2  28 29', 'e4 29e4 28 e4  e4', 'e4 29e4 28e4  e4', 'e2  28 229', 'e2  e2 28 29', 'e2  28', 'e2   28 29', 'e2  29', 'e4 e4  e4 29 e4 28', 'e4  e4 29 e4 28', 'e2   e2 28', 'e8   29 28', 'e5  e5 32  e5 37', 'e8  29', 'e5 29        e5 28', 'e5  e5 32 e5 37', 'e4  e4 29', 'e2  29 28', 'e5 29  e5 37', 'e5 32  e5 37', 'e4    e4 29 28', 'e417  e4 29 28', '9  e9 29', 'e4  e4 29 28', 'e5  e9 29', 'e4    e4 29  28', 'e4   e5 29 28', 'E4   E4 29 28', 'e4 19  e5 29 28', 'E9  e9 29', 'e5  e59 29', 'e4   e4 28 28', 'e5  e5  e5 29 e5 28', 'e5  E5 29', 'E5  E5 29', 'e5   e5 29', 'e5  e5  e5 29  e5 28', 'e9  e9 28 29', 'e2  e2 29', 'e2  e2 28', 'e24  28 3', 'e6  e6 28', 'e5  28 29', 'e5  29', 'e5  29 28', 'e11  e5 28', 'e8   28 29', 'e5  28', 'e9  37 29', 'e2  33', 'e9  29 28', 'e4 29 e4 28 e4  e4', 'E13  28 29', 'E8  28 29', 'e19  28 29', 'e19  e19 29 37', 'E19  29 37', 'e2  e2 33', 'e9  e9 29 28', 'e3  28 29 e3  28 29', 'E13  32', 'E13  28', 'E13  37', 'E3  28 29', 'E8  25 28 29', 'e5  e5  e6 29  e5 28', 'e3  e3 33', 'e4  e4  e4 28', 'e4  e4  e4 29 e4 28', 'e3  e30 33', 'e3  e3 29', 'e3  e3 28 29', 'e4 28  e4', 'e5   e5 28', 'e11   e5 28', 'E2  33', 'e13  e13 29', 'e19   e19 28 29', 'e19   e19 29 37', 'e9   e9 28 29', 'e9   e19 28 29', 'e2  e9 29', 'e2 29  e2 37', 'e9 29  e9 37', 'e9  e9 28', 'e9  e2 29', 'e9   e9 29 28', 'e2   e2 33', 'e8  28', 'e8  28 26', 'e8  28 24', 'e8  28 21', 'e8  28 28', 'e8  28 23', 'e8  28 22', 'e8  28 25', 'e9  29 37', 'e19  29 37', 'e19  37 29', 'e24  24 28 29', 'e9  e9 29 e9 37', 'e24  25 28 29', 'e19  28', 'e19 3  29', 'e27  28 29', 'e9  28', 'e9  26 29', 'e8  25 18 29', 'e4  e4 2928', 'e4   e4 2928', 'e11  NEDC e5 28 WLTP', 'e5  28 WLTP', 'E4  28', 'E4  28 29', 'E4  29 2', 'E5  29 28', 'E5  29', 'E4  E4 29 E4 28', 'e1 ...
# Modified 1309030 rows by replacing 'E' not followed by a letter with 'e'.
# Change in number of unique values: -359
# Values that had 'E' not followed by a letter (original state):
# ['E24 3 E24 9', 'E24 10 E24 3 E24 9', 'E24 2', 'E24 10 E24 2', 'E24 9', 'E24 10 E24 9', 'E13 1', 'E1 8', 'E1 10', 'E1 3', 'E24 10', 'E1 2', 'E24 3 9', 'E24 10 9', 'E1 08', 'E1 10 8', 'E24 3 9 10', 'E1 10 3', 'E24 10 3 9', 'E1 13', 'E19', 'E24 9 10', 'E24 9 19', 'E24 19', 'E8 19', 'E11 19', 'E18', 'E24 10 2', 'E24 2 10', 'E1 19', 'E1 9', 'E13 19', 'E 13 19', 'E9 19', 'E6 19', 'E12', 'E1 8 13', 'E13 17', 'E1 17', 'E24 17 19', 'E24 17 19 28', 'E24 17 19 28 29', 'E24 3 17 19 25', 'E24 3 17 25', 'E24 3 17', 'E24 3 17 19', 'E24 3 19 27 28', 'E24 3', 'E24 10 17', 'E24 3 E24 19', 'E24 3 9 19', 'E24 3 27', 'E24 3 19 27', 'E24 17', 'E24 17 19 25', 'E24 3 17 19 28', 'E24 3 19', 'E24 17 25', 'E24 17 29', 'E24 3 9 25', 'E24 3 17 29', 'E24 3 17 19 28 29', 'E24 3 27 28', 'E3 17', 'E3 17 19', 'E5 27', 'E5 17', 'E5 17 29', 'E9 17 19', 'E13 27 19', 'E13 19 27', 'E9 27 19', 'E9 17', 'E9 19 27', 'E13 17 19', 'E9 17 19 2', 'E6 19 E6 28', 'E11 19 NEDC E5 28 WLTP', 'E11 119', 'E11 19 28', 'E2 17', 'E1 17 29', 'E13 17 28 29', 'E2 22', 'E2 17 19 28 29', 'E2 17 19', 'E2 17 29 28', 'E2 17 29', 'E2 28 29', 'E17', 'E13 17 29', 'E13 17 25', 'E13 29', 'E13 28', 'E13 28 29', 'E2 19', 'E4 17', 'E2 17 19 29 28', 'E3 22', 'E6 28', 'E6 20', 'E3 17 25', 'E1 17 19', 'E9 19 28', 'E2 19 28', 'E9 17 19 28 29', 'E2 24', 'E5 19', 'E9 17 29', 'E2 28', 'E8 17', 'E8 17 19', 'E8 19 25', 'E13 22', 'E13 19 22', 'E4 22', 'E4 19 22', 'E4 19', 'E4 19 27', 'E2 17 28 29', 'E22', 'E2 20', 'E4 17 19', 'E4 17 19 28', 'E2 19 17', 'E4 17 28', 'E2 19 22', 'E2 19 2 17', 'E4 17 19 28 29', 'E9 19 25', 'E417', 'E3 28', 'E517', 'E11 17', 'E25 27', 'E6 15', 'E6 15 28', 'E6 20 28', 'E1 29', 'E4 17E4 29', 'E2 29', 'E27', 'E8 17 19 28 29', 'E8 19 28', 'E8 17 28 29', 'E8 17 25 29', 'E8 17 19 25 28 29', 'E8 19 25 28', 'E8 25', 'E8 17 29', 'E13 17 19 28 29', 'E13 19 27 28 29', 'E13 27', 'E13 19 27 28', 'E13 19 28', 'E2 19 30', 'E5 19 28', 'E11 19 5 28', 'E5 28', 'E4 17 19 29 28', 'E4 19 28', 'E2 12', 'E1 17 28 29', 'E13 3', 'E13 3 19', 'E5 17 19 29', 'E13 17 19 LOW', 'E13 19 27 32', 'E13 17 19 MID', 'E9 19 27 32', 'E13 17 19 HIGH', 'E24 3 7', 'E24 2 19', 'E6 19 28', 'E9 18', 'E19 17 28 29', 'E3 6', 'E24 19 28', 'E24 3 19 28', 'E24 2 29', 'E24 2 19 28 29', 'E24 3 10 17', 'E3 19', 'E3 17 19 28 29', 'E1 28 29', 'E13 17 19 25', 'E6 15 14', 'E5 15', 'E11 20', 'E20', 'E5 17 19 29 28', 'E5 17 19', 'E17 19 29 28', 'E4 17 19 29 2', 'E1 17 19 29 28', 'e24 17 E24 19', 'E2 19 E2 28', 'E9 19 E9 28', 'E9 17 E9 29', 'E9 17 19 E9 28 29', 'E2 17 19 E2 28 29', 'E9 17 19 E9 29 28', 'E2 17 E2 29', 'E9 19 27 3', 'E24 9 29', 'E24 9 19 28 29', 'E1 14', 'E1 14 29', 'E1 2 29', 'E1 8 29', 'E24 3 10', 'E13 27 19 HIGH', 'E24 19 3', 'E24 29', 'E1 02', 'E3 24', 'E1 02 29', 'E3 17 29', 'E3 17 25 29', 'E5 18', 'E13 3 E13 19', 'E5 1 7', 'E11', 'E 4 19 22', 'E14 17 19 4 29 28', 'E24 19 27', 'E17 19', 'E4 17 29 28', 'E 6 15', 'E4 17 29', 'E1 12', 'E5 16', 'E16 15', 'E36', 'E2', 'E19 17 19 E19 28 29', 'E41922', 'E24 28 29', 'E2 17E2 29', 'E9 37', 'E13 29 37', 'E2 29 37', 'E8 28 29', 'E13 33 37', 'E8 29', 'E9 29 37', 'E19 29 37', 'E8 29 37', 'E4 E4 29', 'E24 32 37', 'E24 29 37', 'E5 32', 'E2 33', 'E4 29 E4 28 E4 E4', 'E2429', 'E2 33 37', 'E2 E2 29', 'E6 37', 'E2 29 28', 'E1 29 37', 'E2 37', 'E9 29', 'E24 28', 'E8 28', 'E', 'E8 28 2', 'E2 28 33', 'E13 33', 'E13 37', 'E4 29 28', 'E24 32', 'E8 37', 'E4 E4 E4 28', 'E5 32 37', 'E24 37', 'E4 29 E4', 'E5 29', 'E4 E4 E4 29 E4 28', 'E5 E5 29', 'E9 28 29', 'E9 E9 29', 'E9 E9 29 28', 'E2 E2 33', 'E24 3 28', 'E9 E6 28', 'E9 E9 28 29', 'E4 28', 'E5 E5 E5 29 E5 28', 'E3 29', 'E9 32', 'E6 E6 28', 'E3 E3 33', 'E2 18 28 29', 'E5 E5 28', 'E4 E 4 29', 'E4 32 37', 'E4 32', 'E19 E19 28 29', 'E24 3 29', 'E4 33 37', 'E2 25 E2 29', 'E2 28 E2 29', 'E9 32 37', 'E2 E2 28', 'E9 219 28 29', 'E2 28E2 29', 'E5 28 E9 32', 'E5 29 E5 37', 'E9 E19 28 29', 'E19 E19 29 37', 'E1 33', 'E2 E9 29', 'E9 29 E9 28', 'E24 3 28 29', 'E2 33E2 37', 'E2 33 E2 37', 'E5 37', 'E5 32 E5 37', 'E22 33 E2 37', 'E e2 28 29', 'E4e 32 37', ' ...
# Modified 6 rows by replacing 'i', 'I', 'l', 'L' not followed by a letter with '1'.
# Change in number of unique values: -2
# Values that had 'i', 'I', 'l', 'L' not followed by a letter (original state):
# ['e2 I7', 'EL 08 33', 'el 29']
# Modified 639 rows by eliminating spaces after 'e'.
# Change in number of unique values: -32
# Values that had spaces after 'e' (original state):
# ['e 24 3 e24 9', 'e 24 2', 'e 24 9', 'e 24 10 e24 9', 'e 24 10 e 24 3 e24 9', 'e 11 19', 'e 19', 'e 1 19', 'e 24 9 19', 'e 24 19', 'e 13 19', 'e 8 19', 'e 24 9 10', 'e 20', 'e 17 e 19', '0 00e + 11', '1 47e + 12', '0 97e + 11', '4 43e + 11', '4 00e + 11', 'e 15', '1 12e + 11', '2 34e + 11', '1 35e + 11', '0 13e + 11', '2 27e + 11', '0 96e + 11', '1 02e + 11', '3 65e + 11', '2 56e + 11', '0 91e + 11', '2 80e + 11', '0 66e + 11', '0 03e + 11', '0 20e + 11', '0 95e + 11', '0 79e + 11', '1 60e + 11', 'e 17', 'e 24 3 17', 'e 4 19 22', 'e 24 3 17 19', 'e 6 15', 'e 24 17 19 25', 'e 24 10', 'e4 e 4 29', 'e e2 28 29', 'e4e 32 37', 'e5 29 e 5 37', 'e5 32 e 537', 'e 5 28', 'e 5 28 WLTP', 'e 13 28 29', 'e 24 29', 'e 24 28 29', 'e 29', 'e 13 29', 'e e5 29', 'e 24 3 28 29', 'e 24 3 28', 'e 28 29', 'e 28 e9 32', 'e5 29 e 37']
# Modified 20944 rows by removing leading zeros in country and type codes.
# Change in number of unique values: -6
# Values that had leading zeros in country or type codes (original state):
# ['e1 08', 'e1 02', '0 00e+ 11', '4 00e+ 11', '1 02e+ 11', '0 03e+ 11', 'e1 02 29', 'e01 2', 'e1 08 29', 'e1 02 e1 29', 'e1 08 33', 'E1 08 33', 'e2 37 029']
# Modified 2116 rows by eliminating trailing country codes.
# Change in number of unique values: -27
# Values that had trailing country codes (original state):
# ['e18', 'e24', 'e19', 'e12', 'e20', 'e11', 'e17', 'e17 e19', 'e9', 'e15', 'e22', 'e24 10 e2', 'e4 17 e4', 'e27', 'e14', 'e2', 'e4 29 e4 28 e4 e4', 'e17 e19 e29 e28', 'e4 29 e4', 'e29', 'e9 e29', 'e4 29e4 28e4 e4', 'e4 29 e4 28e4 e4', 'e4 29e4 28 e4 e4', 'e429e428e417e4', 'e4 29 e4 28 e4', 'e2 29 e2 28 e2 e2', 'e2 29e2 28e2 e2', 'e2 29 e2 28 e2', 'e4 e28 e29', 'e4 28 e4', 'e5 e28 e29', 'e33', 'e4 e17 e19 e28 e29', 'e28', 'e1 e29', 'e2 29 e28', 'e5 32 e4', 'e4 29 + e4', 'e9 29+ e9', 'e3', 'e5']

# %%
print(count_missing_values2(df, ['IT_valid', 'IT_invalid']))
all_to_nan_and_cat(df, ['IT_valid', 'IT_invalid'])
print(count_missing_values2(df, ['IT_valid', 'IT_invalid']))
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid   float64             0              0  14442792      0
# 1  IT_invalid  category       9564034              0         0      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0  14442792      0
# 1  IT_invalid  category             0              0   9564034      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458

# %% [markdown]
# ##### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT8.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT8.parquet")
all_to_nan_and_cat(df, ['IT_valid', 'IT_invalid'])
count_missing_values2(df, ['IT_valid', 'IT_invalid'])

# %% [markdown]
# #### Step 9: (f: filter_and_split_valid_tacs(df))

# %%
# Execute Step 9
# Filter valid IT codes (Type Approval codes (TAC)) and move them from IT_invalid to IT_valid
df = filter_and_split_valid_tacs(df)
# Out:
# === Filter and Split Valid TACs ===
# Transferred 2578512 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 310
# List of unique valid TACs transferred to 'IT_valid':
# ['e1 8', 'e1 3', 'e24 10 e24 3 e24 9', 'e24 9', 'e24 10 e24 9', 'e24 3 e24 9', 'e24 2', 'e24 10 e24 2', 'e1 10', 'e1 2', 'e24 10 e24 3', 'e13 1', 'e24 10', 'e1 13', 'e11 19', 'e1 19', 'e24 9 e24 10', 'e1 9', 'e24 19', 'e8 19', 'e24 19 e24 9', 'e1 18', 'e1 12', 'e24 3', 'e24 1', 'e13 19', 'e6 19', 'e9 19', 'e3 17', 'e3 19', 'e2 4', 'e2 22', 'e6 20', 'e2 17', 'e9 17', 'e5 17', 'e24 17', 'e6 15', 'e2 12', 'e13 22', 'e13 17', 'e2 17 e9 17', 'e17 19', 'e2 19', 'e11 20', 'e1 14', 'e1 17', 'e13 3', 'e4 17', 'e11 17', 'e13 13', 'e8 17', 'e4 19', 'e1 7', 'e4 22', 'e27 19', 'e24 19 e19 9', 'e1 4', 'e13 15', 'e2 24', 'e19 1', 'e1 29', 'e24 3 e24 19', 'e24 3 e24 17', 'e3 22', 'e5 27', 'e13 28', 'e13 27', 'e6 19 e6 28', 'e5 17 e5 29', 'e5 19', 'e6 28', 'e8 25', 'e1 17 e1 28 e1 29', 'e6 15 e6 28', 'e6 20 e6 28', 'e13 29', 'e4 19 e4 28', 'e5 28', 'e2 17 e2 19', 'e24 17 e24 19', 'e24 3 e24 17 e24 19', 'e2 28', 'e11 19 e5 28', 'e3 28', 'e5 29', 'e1 17 e1 19', 'e13 17 e13 19', 'e2 19 e2 28', 'e9 19 e9 28', 'e9 18', 'e13 19 e13 22', 'e2 20', 'e2 19 e2 17', 'e4 17 e4 19', 'e4 17 e4 19 e4 28', 'e2 29', 'e9 17 e9 29', 'e9 28', 'e25 27', 'e11 2', 'e6 2', 'e2 17 e2 29', 'e3 24', 'e13 3 e13 19', 'e24 14', 'e3 6', 'e5 17 e5 19 e5 29 e5 28', 'e2 14', 'e5 15', 'e9 17 e9 19', 'e9 19 e9 25', 'e9 29', 'e6 18', 'e24 10 e24 17', 'e8 17 e8 19', 'e9 27', 'e8 18', 'e4 17 e4 29', 'e4 19 e4 17', 'e24 17 e24 3', 'e24 17 e24 19 e24 3', 'e24 3 e24 19 e24 27 e24 28', 'e4 28', 'e1 2 e1 29', 'e24 17 e24 19 e24 25 e24 3', 'e24 27 e24 3 e24 28', 'e24 27 e24 3', 'e24 10 e24 17 e24 3', 'e24 19 e24 27 e24 38', 'e24 17 e24 19 e24 25', 'e5 17 e5 19', 'e24 29', 'e5 18', 'e13 19 e13 3', 'e8 29', 'e9 27 e9 19', 'e9 17 e9 19 e9 28 e9 29', 'e13 3 e13 20', 'e13 3 e13 21', 'e4 19 e4 27', 'e2 17 e2 19 e2 28 e2 29', 'e8 17 e8 29', 'e8 17 e8 19 e8 28 e8 29', 'e8 19 e8 25', 'e13 17 e13 28 e13 29', 'e2 29 e2 29', 'e2 28 e2 29', 'e5 16', 'e16 15', 'e6 16', 'e24 19 e24 3', 'e5 19 e5 28', 'e2 17 e9 29', 'e2 19 e9 28', 'e9 19 e19 28', 'e4 29 e4 28 e4 17 e4 19', 'e4 17 e4 28', 'e2 19 e2 22', 'e2 19 e2 29', 'e8 19 e8 28', 'e8 19 e8 25 e8 28', 'e8 17 e8 28 e8 29', 'e4 19 e4 22', 'e24 17 e24 25 e24 3', 'e3 17 e3 25', 'e3 19 e3 17', 'e3 17 e3 19', 'e4 17 e4 19 e4 28 e4 29', 'e19 19', 'e13 17 e13 25', 'e24 17 e24 19 e24 3 e24 25', 'e24 17 e24 3 e24 25', 'e24 19 e24 27 e24 3', 'e24 9 e24 3 e24 25', 'e24 3 e24 27', 'e24 17 e24 19 e24 3 e24 28', 'e8 17 e8 19 e8 25 e8 28 e8 29', 'e24 2 e24 29', 'e24 17 e24 19 e24 28 e24 29', 'e9 37', 'e9 32', 'e9 29 e9 28', 'e2 33', 'e5 32', 'e6 37', 'e13 37', 'e2 37', 'e5 32 e4 37', 'e5 37 e9 32', 'e5 28 e9 32', 'e4 37', 'e5 37', 'e4 32', 'e1 33', 'e24 28', 'e8 28', 'e13 33', 'e13 32', 'e24 32', 'e8 37', 'e5 37 e5 32', 'e24 37', 'e4 29', 'e5 29 e5 37', 'e1 28', 'e5 29 e5 28', 'e3 29', 'e2 25 e2 29', 'e2 33 e2 37', 'e5 32 e5 37', 'e22 33 e2 37', 'e3 33', 'e24 32 e5 37', 'e4 29 e4 28', 'e29 28', 'e17 29', 'e2 29 e2 28', 'e1 37', 'e9 29 e9 37', 'e4 32 e4 37', 'e4 33 e4 37', 'e13 28 e13 29', 'e1 29 e1 37', 'e13 29 e13 37', 'e1 28 e1 29', 'e2 29 e2 37', 'e5 32 e24 32', 'e11 29', 'e3 29 e3 29', 'e5 28 e5 29', 'e4 28 e4 29', 'e19 28', 'e9 29 e2 28', 'e3 28 e3 29', 'e23 29', 'e8 28 e8 29', 'e8 29 e8 37', 'e8 25 e8 28', 'e19 29 e19 37', 'e19 37 e19 29', 'e19 28 e19 29', 'e9 28 e9 29', 'e9 37 e9 29', 'e24 32 e24 37', 'e24 32 e5 32', 'e24 29 e24 37', 'e24 28 e24 29', 'e13 33 e13 37', 'e5 38 e9 32', 'e9 32 e9 37', 'e2 28 e2 33', 'e5 37 e5 29', 'e11 28', 'e28 29', 'e16 29', 'e12 28', 'e19 29', 'e11 32', 'e3 37', 'e9 33', 'e3 32', 'e8 29 e8 28', 'e9 32 e5 37', 'e9 32 e5 28', 'e5 29 e5 29', 'e4 29 e4 37', 'e24 29 e4 37', 'e2 29 e9 28', 'e2 33 e3 37', 'e3 33 e2 37', 'e29 37', 'e9 29 e29 28', 'e3 32 e3 37', 'e13 29 e13 38', 'e3 29 e3 28', 'e13 32 e13 37', 'e6 29 e6 28', 'e3 28 e3 32 e3 37', 'e24 29 e5 29', 'e6 35', 'e1 32', 'e5 37 e8 32', 'e5 33', 'e32 37', 'e9 28 e9 32', 'e6 29', 'e2 32', 'e18 28', 'e26 37', 'e2 28 e2 28', 'e5 29 e24 29', 'e5 32 e5 38', 'e5 32 e5 39', 'e4 37 e5 32',  ...
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 0
# 'IT_valid' unique count after processing: 311
# Difference in 'IT_valid' unique counts: 311
# 'IT_invalid' unique count before processing: 951
# 'IT_invalid' unique count after processing: 642
# Difference in 'IT_invalid' unique counts: -309
# ======================================
#
# Number of overlapping rows (should be 0): 0

# %%
print(count_missing_values2(df, ['IT_valid', 'IT_invalid']))
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0  11864280      0
# 1  IT_invalid  category             0              0  12142546      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458

# %% [markdown]
# ##### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT9.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT9.parquet")
all_to_nan_and_cat(df, ['IT_valid', 'IT_invalid'])
count_missing_values2(df, ['IT_valid', 'IT_invalid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0  11864280      0
# 1  IT_invalid  category             0              0  12142546      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458

# %% [markdown]
# #### Step 10: Expand TACs

# %%
# Step 10: Expand TACs with Shared Country Codes
df = expand_shared_country_codes(df)
# Out:
# Warning: Entry '' does not have enough parts to expand.
# Warning: Entry '0' does not have enough parts to expand.
# Warning: Entry '017' does not have enough parts to expand.
# Warning: Entry '10' does not have enough parts to expand.
# Warning: Entry '15' does not have enough parts to expand.
# Warning: Entry '17' does not have enough parts to expand.
# Warning: Entry '1719' does not have enough parts to expand.
# Warning: Entry '19' does not have enough parts to expand.
# Warning: Entry '2' does not have enough parts to expand.
# Warning: Entry '20' does not have enough parts to expand.
# Warning: Entry '22' does not have enough parts to expand.
# Warning: Entry '29' does not have enough parts to expand.
# Warning: Entry '3' does not have enough parts to expand.
# Warning: Entry '33' does not have enough parts to expand.
# Warning: Entry '8' does not have enough parts to expand.
# Warning: Entry '9' does not have enough parts to expand.
# Warning: Entry 'IP0014WAP1' does not have enough parts to expand.
# Warning: Entry 'IP0015WAP1' does not have enough parts to expand.
# Warning: Entry 'No' does not have enough parts to expand.
# Warning: Entry 'e' does not have enough parts to expand.
# Warning: Entry 'e1' does not have enough parts to expand.
# Warning: Entry 'e1117' does not have enough parts to expand.
# Warning: Entry 'e1119' does not have enough parts to expand.
# Warning: Entry 'e1317' does not have enough parts to expand.
# Warning: Entry 'e131719' does not have enough parts to expand.
# Warning: Entry 'e1319' does not have enough parts to expand.
# Warning: Entry 'e1328' does not have enough parts to expand.
# Warning: Entry 'e132829' does not have enough parts to expand.
# Warning: Entry 'e1329' does not have enough parts to expand.
# Warning: Entry 'e1337' does not have enough parts to expand.
# Warning: Entry 'e17' does not have enough parts to expand.
# Warning: Entry 'e212' does not have enough parts to expand.
# Warning: Entry 'e217' does not have enough parts to expand.
# Warning: Entry 'e219' does not have enough parts to expand.
# Warning: Entry 'e2429' does not have enough parts to expand.
# Warning: Entry 'e36' does not have enough parts to expand.
# Warning: Entry 'e37' does not have enough parts to expand.
# Warning: Entry 'e417' does not have enough parts to expand.
# Warning: Entry 'e41922' does not have enough parts to expand.
# Warning: Entry 'e41927' does not have enough parts to expand.
# Warning: Entry 'e429e428e417' does not have enough parts to expand.
# Warning: Entry 'e437' does not have enough parts to expand.
# Warning: Entry 'e517' does not have enough parts to expand.
# Warning: Entry 'e517e529' does not have enough parts to expand.
# Warning: Entry 'e519' does not have enough parts to expand.
# Warning: Entry 'e529' does not have enough parts to expand.
# Warning: Entry 'e532' does not have enough parts to expand.
# Warning: Entry 'e537' does not have enough parts to expand.
# Warning: Entry 'e619' does not have enough parts to expand.
# Warning: Entry 'e628' does not have enough parts to expand.
# Warning: Entry 'e637' does not have enough parts to expand.
# Warning: Entry 'e637e' does not have enough parts to expand.
# Warning: Entry 'e6e637' does not have enough parts to expand.
# Warning: Entry 'e81719' does not have enough parts to expand.
# Warning: Entry 'e819' does not have enough parts to expand.
# Warning: Entry 'e9' does not have enough parts to expand.
# Warning: Entry 'e917' does not have enough parts to expand.
# Warning: Entry 'e91719' does not have enough parts to expand.
# Warning: Entry 'e919' does not have enough parts to expand.
# Warning: Entry 'e929' does not have enough parts to expand.
# Warning: Entry 'e932' does not have enough parts to expand.
# Warning: Entry 'no' does not have enough parts to expand.
#
# Modified 2196513 rows by expanding shared country codes.
# Change in number of unique values in IT_invalid after expansion: 0
# Values that matched the shared country code criteria (original state):
# ['e24 3 9', 'e24 10 3 9', 'e24 3 9 10', 'e24 9 10', 'e24 2 10', 'e1 10 8', 'e1 8 10', 'e24 10 9', 'e1 10 3', 'e1 3 10'] ...
#
# Sample transformations:
# Before: e13 33 37 --> After: e13 33 e13 37
# Before: e8 29 37 --> After: e8 29 e8 37
# Before: e2 29 37 --> After: e2 29 e2 37
# Before: e9 28 29 --> After: e9 28 e9 29
# Before: e24 9 10 --> After: e24 9 e24 10

# %%
count_missing_values2(df, ['IT_valid', 'IT_invalid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0  11864280      0
# 1  IT_invalid  category             0              0  12142546      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458

# %%
# Again filter newly mined valid IT codes (Type Approval codes (TAC)) and move them from IT_invalid to IT_valid
df = filter_and_split_valid_tacs(df)
# Out:
# === Filter and Split Valid TACs ===
# Transferred 2196513 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 346
# List of unique valid TACs transferred to 'IT_valid':
# ['e24 3 e24 9', 'e24 10 e24 3 e24 9', 'e24 3 e24 9 e24 10', 'e24 9 e24 10', 'e24 2 e24 10', 'e1 10 e1 8', 'e1 8 e1 10', 'e24 10 e24 9', 'e1 10 e1 3', 'e1 3 e1 10', 'e24 9 e24 19', 'e24 10 e24 2', 'e24 19 e24 9', 'e1 2 e1 10', 'e3 17 e3 19', 'e29 9 e29 19', 'e1 8 e1 13', 'e9 17 e9 19', 'e24 10 e24 17', 'e24 17 e24 19', 'e13 17 e13 19', 'e8 17 e8 19', 'e24 17 e24 19 e24 25', 'e24 3 e24 17', 'e24 3 e24 17 e24 19', 'e24 3 e24 19', 'e2 17 e2 19', 'e24 3 e24 10', 'e24 3 e24 17 e24 19 e24 25', 'e24 17 e24 25', 'e9 27 e9 19', 'e34 3 e34 17', 'e24 3 e24 10 e24 17', 'e24 3 e24 9 e24 19', 'e4 17 e4 19', 'e13 19 e13 22', 'e11 1 e11 19', 'e4 19 e4 22', 'e2 19 e2 22', 'e2 19 e2 17', 'e24 3 e24 17 e24 25', 'e24 17 e24 3', 'e24 19 e24 3', 'e24 17 e24 19 e24 3', 'e12 17 e12 19', 'e24 3 e24 27', 'e24 2 e24 19', 'e24 3 e24 19 e24 17', 'e9 17 e9 1', 'e24 17 e24 10', 'e24 3 e24 17 e24 10', 'e24 3 e24 17 e24 1', 'e24 3 e24 17 e24 2', 'e24 3 e24 10 e24 1', 'e13 19 e13 17', 'e3 19 e3 17', 'e24 17 e24 19 e24 25 e24 3', 'e24 17 e24 3 e24 19', 'e1 17 e1 19', 'e13 17 e13 25', 'e1 28 e1 29', 'e24 17 e24 19 e24 28', 'e24 17 e24 19 e24 28 e24 29', 'e24 3 e24 19 e24 27 e24 28', 'e24 3 e24 19 e24 27', 'e24 3 e24 17 e24 19 e24 28', 'e24 17 e24 29', 'e24 3 e24 9 e24 25', 'e24 3 e24 17 e24 29', 'e24 3 e24 17 e24 19 e24 28 e24 29', 'e24 3 e24 27 e24 28', 'e24 27 e24 3', 'e24 19 e24 27 e24 3 e24 28', 'e24 17 e24 25 e24 3', 'e24 2 e24 29', 'e24 19 e24 17 e24 25 e24 3', 'e24 17 e24 25 e24 3 e24 19', 'e24 17 e24 19 e24 3 e24 28', 'e24 19 e24 17', 'e24 3 e24 19 e24 28', 'e5 17 e5 29', 'e9 19 e9 27', 'e13 19 e13 27', 'e9 17 e9 19 e9 2', 'e13 27 e13 19', 'e13 17 e13 28', 'e1 17 e1 29', 'e13 17 e13 29', 'e9 19 e9 27 e9 3', 'e13 19 e13 28', 'e9 17 e9 29', 'e13 17 e13 19 e13 28 e13 29', 'e13 19 e13 27 e13 28 e13 29', 'e9 17 e9 19 e9 28 e9 29', 'e13 19 e13 27 e13 28', 'e5 19 e5 28', 'e11 19 e11 28', 'e8 19 e8 28', 'e8 17 e8 29', 'e8 17 e8 19 e8 28 e8 29', 'e4 19 e4 27', 'e6 20 e6 28', 'e6 19 e6 28', 'e9 19 e9 28', 'e6 15 e6 28', 'e8 19 e8 25', 'e3 17 e3 25', 'e13 17 e13 28 e13 29', 'e8 17 e8 19 e8 25 e8 28 e8 29', 'e3 17 e3 19 e3 2', 'e2 17 e2 19 e2 28 e2 29', 'e2 17 e2 29 e2 28', 'e2 17 e2 29', 'e2 28 e2 29', 'e2 19 e2 28', 'e13 28 e13 29', 'e8 17 e8 28 e8 29', 'e19 28 e19 29', 'e2 17 e2 19 e2 29 e2 28', 'e9 28 e9 29', 'e1 17 e1 28 e1 29', 'e9 17 e9 19 e9 29 e9 28', 'e13 3 e13 19', 'e2 19 e2 3', 'e2 19 e2 30 e2 33', 'e4 29 e4 28', 'e13 17 e13 19 e13 25', 'e8 19 e8 25 e8 28', 'e8 17 e8 19 e8 2', 'e8 17 e8 25 e8 29', 'e2 17 e2 28 e2 29', 'e4 17 e4 19 e4 28', 'e4 17 e4 28', 'e2 19 e2 2 e2 17', 'e4 17 e4 19 e4 28 e4 29', 'e8 17 e8 8', 'e9 19 e9 25', 'e5 17 e5 19 e5 28 e5 29', 'e2 17 e2 19 e2 2', 'e6 2 e6 28', 'e2 19 e2 30', 'e11 19 e11 5 e11 28', 'e4 17 e4 19 e4 29 e4 28', 'e4 19 e4 28', 'e24 2 e24 19 e24 28 e24 29', 'e24 19 e24 27', 'e1 14 e1 29', 'e13 19 e13 27 e13 32', 'e9 19 e9 27 e9 32', 'e5 17 e5 19 e5 29', 'e1 2 e1 29', 'e4 17 e4 19 e4 2', 'e4 17 e4 4 e4 19', 'e24 3 e24 7', 'e9 27 e9 17', 'e19 17 e19 28 e19 29', 'e24 19 e24 2', 'e24 19 e24 17 e24 25', 'e24 17 e24 3 e24 25', 'e24 19 e24 27 e24 3', 'e24 25 e24 3 e24 9', 'e24 9 e24 3', 'e24 3 e24 27 e24 19 e24 28', 'e24 19 e24 3 e24 9', 'e24 19 e24 3 e24 27', 'e24 10 e24 3', 'e24 19 e24 3 e24 27 e24 28', 'e24 19 e24 3 e24 17', 'e14 17 e14 19 e14 3', 'e13 17 e13 18 e13 28 e13 29', 'e13 19 e13 3', 'e4 29 e4 28 e4 17 e4 19', 'e24 19 e24 28', 'e3 17 e3 19 e3 28 e3 29', 'e6 15 e6 14', 'e5 17 e5 19 e5 29 e5 28', 'e5 17 e5 19', 'e17 19 e17 29 e17 28', 'e4 17 e4 19 e4 29 e4 2', 'e1 17 e1 19 e1 29 e1 28', 'e3 17 e3 29', 'e24 1 e24 17', 'e19 17 e19 19 e19 28 e19 29', 'e24 3 e24 19 e24 2', 'e24 3 e24 27 e24 2', 'e24 2 e24 19 e24 2', 'e24 17 e24 19 e24 3 e24 28 e24 29', 'e24 9 e24 29', 'e24 9 e24 19 e24 28 e24 29', 'e1 8 e1 29', 'e24 17 e24 25 e24 19', 'e3 17 e3 28', 'e2 17 e2 28 e2 2', 'e3 17 e3 25 e3 29', 'e8 28 e8 29', 'e8 17 e8 1 e8 9', 'e5 1 e5 7', 'e8 17 e8 25 e8 2', 'e8 19 e8 25 e8 2', 'e8 17 e8 28 e8 2', 'e14 17 e14 19 e14 4 e ...
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 310
# 'IT_valid' unique count after processing: 532
# Difference in 'IT_valid' unique counts: 222
# 'IT_invalid' unique count before processing: 641
# 'IT_invalid' unique count after processing: 296
# Difference in 'IT_invalid' unique counts: -345
# ======================================
#
# Number of overlapping rows (should be 0): 0

# %%
from IPython.display import display, HTML

# Create a scrollable div for the output
unique_values = df['IT_valid'].cat.categories if df['IT_valid'].dtype.name == 'category' else df['IT_valid'].unique()
html_output = '<div style="max-height: 300px; overflow-y: scroll; border: 1px solid black;">' \
              + '<br>'.join(map(str, unique_values)) + '</div>'

# Display the scrollable output
display(HTML(html_output))
# Out:
# <div style="max-height: 300px; overflow-y: scroll; border: 1px solid black;">e1 10<br>e1 10 e1 3<br>e1 10 e1 8<br>e1 12<br>e1 13<br>e1 14<br>e1 14 e1 29<br>e1 17<br>e1 17 e1 19<br>e1 17 e1 19 e1 29 e1 28<br>e1 17 e1 2<br>e1 17 e1 28 e1 29<br>e1 17 e1 29<br>e1 18<br>e1 19<br>e1 2<br>e1 2 e1 10<br>e1 2 e1 29<br>e1 28<br>e1 28 e1 29<br>e1 28 e1 37<br>e1 29<br>e1 29 e1 28<br>e1 29 e1 35<br>e1 29 e1 37<br>e1 3<br>e1 3 e1 10<br>e1 32<br>e1 32 e1 37<br>e1 33<br>e1 33 e1 37<br>e1 37<br>e1 37 e1 29<br>e1 4<br>e1 7<br>e1 8<br>e1 8 e1 10<br>e1 8 e1 13<br>e1 8 e1 29<br>e1 8 e1 33<br>e1 9<br>e11 1 e11 19<br>e11 17<br>e11 19<br>e11 19 e11 28<br>e11 19 e11 5 e11 28<br>e11 19 e5 28<br>e11 2<br>e11 20<br>e11 28<br>e11 29<br>e11 32<br>e12 17 e12 19<br>e12 28<br>e12 28 e12 29<br>e12 29<br>e13 1<br>e13 13<br>e13 15<br>e13 17<br>e13 17 e13 18 e13 28 e13 29<br>e13 17 e13 19<br>e13 17 e13 19 e13 25<br>e13 17 e13 19 e13 28 e13 29<br>e13 17 e13 25<br>e13 17 e13 28<br>e13 17 e13 28 e13 29<br>e13 17 e13 29<br>e13 18 e13 28 e13 29<br>e13 19<br>e13 19 e13 17<br>e13 19 e13 22<br>e13 19 e13 27<br>e13 19 e13 27 e13 28<br>e13 19 e13 27 e13 28 e13 29<br>e13 19 e13 27 e13 32<br>e13 19 e13 28<br>e13 19 e13 3<br>e13 22<br>e13 27<br>e13 27 e13 19<br>e13 28<br>e13 28 e13 29<br>e13 29<br>e13 29 e13 1<br>e13 29 e13 28<br>e13 29 e13 37<br>e13 29 e13 38<br>e13 3<br>e13 3 e13 19<br>e13 3 e13 20<br>e13 3 e13 21<br>e13 3 e13 28<br>e13 32<br>e13 32 e13 37<br>e13 32 e13 38<br>e13 33<br>e13 33 e13 37<br>e13 37<br>e13 37 e13 29<br>e13 37 e13 37<br>e13 38<br>e13 39 e13 37<br>e13 7 e13 29<br>e14 17 e14 19 e14 3<br>e14 17 e14 19 e14 4 e14 29 e14 28<br>e16 15<br>e16 29<br>e17 19<br>e17 19 e17 29 e17 28<br>e17 28 e17 29<br>e17 29<br>e18 28<br>e19 1<br>e19 17 e19 19 e19 28 e19 29<br>e19 17 e19 28 e19 29<br>e19 19<br>e19 19 e19 28<br>e19 28<br>e19 28 e19 29<br>e19 29<br>e19 29 e19 37<br>e19 3 e19 29<br>e19 37 e19 29<br>e2 12<br>e2 14<br>e2 17<br>e2 17 e2 19<br>e2 17 e2 19 e2 2<br>e2 17 e2 19 e2 28 e2 29<br>e2 17 e2 19 e2 29 e2 28<br>e2 17 e2 28 e2 2<br>e2 17 e2 28 e2 29<br>e2 17 e2 29<br>e2 17 e2 29 e2 28<br>e2 17 e9 17<br>e2 17 e9 29<br>e2 18 e2 28 e2 29<br>e2 19<br>e2 19 e2 17<br>e2 19 e2 2 e2 17<br>e2 19 e2 22<br>e2 19 e2 28<br>e2 19 e2 29<br>e2 19 e2 3<br>e2 19 e2 30<br>e2 19 e2 30 e2 33<br>e2 19 e9 28<br>e2 20<br>e2 22<br>e2 24<br>e2 24 e2 29<br>e2 25 e2 29<br>e2 28<br>e2 28 e2 28<br>e2 28 e2 29<br>e2 28 e2 29 e2 37<br>e2 28 e2 33<br>e2 28 e2 37<br>e2 29<br>e2 29 e2 28<br>e2 29 e2 29<br>e2 29 e2 35<br>e2 29 e2 37<br>e2 29 e2 38<br>e2 29 e2 39<br>e2 29 e9 28<br>e2 32<br>e2 32 e2 37<br>e2 33<br>e2 33 e2 37<br>e2 33 e2 38<br>e2 33 e3 37<br>e2 37<br>e2 37 e2 29<br>e2 37 e2 33<br>e2 4<br>e22 33 e2 37<br>e23 29<br>e24 1<br>e24 1 e24 17<br>e24 10<br>e24 10 e24 17<br>e24 10 e24 17 e24 3<br>e24 10 e24 2<br>e24 10 e24 3<br>e24 10 e24 3 e24 9<br>e24 10 e24 9<br>e24 14<br>e24 17<br>e24 17 e24 10<br>e24 17 e24 19<br>e24 17 e24 19 e24 25<br>e24 17 e24 19 e24 25 e24 3<br>e24 17 e24 19 e24 28<br>e24 17 e24 19 e24 28 e24 29<br>e24 17 e24 19 e24 3<br>e24 17 e24 19 e24 3 e24 25<br>e24 17 e24 19 e24 3 e24 28<br>e24 17 e24 19 e24 3 e24 28 e24 29<br>e24 17 e24 25<br>e24 17 e24 25 e24 19<br>e24 17 e24 25 e24 3<br>e24 17 e24 25 e24 3 e24 19<br>e24 17 e24 29<br>e24 17 e24 3<br>e24 17 e24 3 e24 19<br>e24 17 e24 3 e24 25<br>e24 17 e24 3 e24 29<br>e24 18 e24 28 e24 29<br>e24 19<br>e24 19 e19 9<br>e24 19 e24 17<br>e24 19 e24 17 e24 25<br>e24 19 e24 17 e24 25 e24 3<br>e24 19 e24 17 e24 3<br>e24 19 e24 2<br>e24 19 e24 27<br>e24 19 e24 27 e24 3<br>e24 19 e24 27 e24 3 e24 28<br>e24 19 e24 27 e24 38<br>e24 19 e24 28<br>e24 19 e24 3<br>e24 19 e24 3 e24 17<br>e24 19 e24 3 e24 27<br>e24 19 e24 3 e24 27 e24 28<br>e24 19 e24 3 e24 9<br>e24 19 e24 9<br>e24 2<br>e24 2 e24 1<br>e24 2 e24 10<br>e24 2 e24 19<br>e24 2 e24 19 e24 2<br>e24 2 e24 19 e24 28 e24 29<br>e24 2 e24 29<br>e24 24 e24 28 e24 29<br>e24 25 e24 28 e24 29<br>e24 25 e24 3 e24 9<br>e24 27 e24 3<br>e24 27 e24 3 e24 28<br>e24 28<br>e24 28 e24 29<br>e24 28 e2 ...

# %% [markdown]
# ##### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT10.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT10.parquet")
count_missing_values2(df, ['IT_valid', 'IT_invalid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0   9667767      0
# 1  IT_invalid  category             0              0  14339059      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86458

# %% [markdown]
# #### Step 11:Expand Multiple Country Codes in TAC Entries

# %%
# Execute Step 11: Expand Multiple Country Codes in ITcode/TAC Entries
df = expand_multiple_country_codes(df)
# Out:
# === Step 11: Expand Multiple Country Codes ===
# Modified 9562 rows by expanding multiple country codes.
# Change in number of unique values after expansion: -30
# Values that matched the multiple country code criteria (original state):
# ['e11 19 NEDC e5 28 WLTP', 'e4 17 19 e4 29 28', 'e19 17 19 e19 28 29', 'e24 17 e24 19', 'e5 29+ e5 28', 'e4 17 e4 19', 'e2 19 e2 17', 'e4 29 28 e4 17 19', 'e5 17 e5 29', 'e4 17 e4 29'] ...
#
# Sample transformations:
# Before: e2 28e2 29 --> After: e2 28 e2 29
# Before: e11 e5 28 --> After: e5 28
# Before: e5 e5 29 --> After: e5 29
# Before: e2 e2 28 29 --> After: e2 28 e2 29
# Before: e4 e4 e4 29 e4 28 --> After: e4 29 e4 28
# Before: e4 e4 29 --> After: e4 29
# Before: e5 e5 29 --> After: e5 29
# Before: e11 NEDC e5 28 WLTP --> After: NEDC e5 28 WLTP
# Before: e11 NEDC e5 28 WLTP --> After: NEDC e5 28 WLTP
# Before: e11 e5 28 --> After: e5 28
# Before: e9 e9 28 29 --> After: e9 28 e9 29
# Before: e5 e5 32 e5 37 --> After: e5 32 e5 37
# Before: e9 e9 29 --> After: e9 29
# Before: e19 e19 28 29 --> After: e19 28 e19 29
# Before: e11 e5 28 --> After: e5 28
# Before: e2 e2 28 --> After: e2 28
# Before: e9 e9 29 --> After: e9 29
# Before: e2 28e2 29 --> After: e2 28 e2 29
# Before: e2 e2 28 29 --> After: e2 28 e2 29
# Before: e9 e9 28 29 --> After: e9 28 e9 29
# ============================================

# %%
# Again filter newly mined valid IT codes (Type Approval codes (TAC)) and move them from IT_invalid to IT_valid
df = filter_and_split_valid_tacs(df)
# Out:
# === Filter and Split Valid TACs ===
# Transferred 8120 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 72
# List of unique valid TACs transferred to 'IT_valid':
# ['e4 17 e4 19 e4 29 e4 28', 'e19 17 e19 19 e19 28 e19 29', 'e24 17 e24 19', 'e4 17 e4 19', 'e2 19 e2 17', 'e4 29 e4 28 e4 17 e4 19', 'e5 17 e5 29', 'e4 17 e4 29', 'e2 17 e2 19 e2 28 e2 29', 'e9 17 e9 19 e9 28 e9 29', 'e2 28 e2 29', 'e9 17 e9 19 e9 29 e9 28', 'e2 17 e2 29', 'e24 17 e24 3', 'e24 17 e24 19 e24 3', 'e24 17 e24 25 e24 3', 'e24 17 e24 19 e24 25', 'e24 17 e24 25', 'e24 19 e24 3', 'e24 3 e24 19', 'e9 17 e9 29', 'e2 17', 'e2 17 e2 19 e9 28 e9 29', 'e4 19 e4 28', 'e5 29', 'e4 29', 'e4 28', 'e4 29 e4 28', 'e2 29', 'e5 28', 'e9 29', 'e5 29 e5 28', 'e9 29 e9 28', 'e2 33', 'e6 28', 'e9 28 e9 29', 'e3 33', 'e19 28 e19 29', 'e2 28', 'e19 29 e19 37', 'e2 33 e2 37', 'e4 19 e4 29 e4 28', 'e32 37', 'e2 29 e2 28', 'e8 29 e8 28', 'e5 32 e5 37', 'e4 19 e5 29 e5 28', 'e4 28 e4 28', 'e4 37 e9 37 e9 29', 'e3 28 e3 29 e3 28 e3 29', 'e6 29 e5 28', 'e30 33', 'e3 29', 'e3 28 e3 29', 'e13 29', 'e9 29 e9 37 e9 28 e9 29', 'e9 28', 'e19 28', 'e9 29 e9 37', 'e29 28', 'e3 25 e3 29 e3 25 e3 29', 'e5 28 e9 32', 'e8 29', 'e5 37 e9 32', 'e9 32', 'e2 29 e2 37', 'e6 37', 'e6 29', 'e5 32 e4 37', 'e4 37 e9 37 e9 32', 'e5 32', 'e3 32 e3 37 e3 32 e3 37']
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 531
# 'IT_valid' unique count after processing: 544
# Difference in 'IT_valid' unique counts: 13
# 'IT_invalid' unique count before processing: 265
# 'IT_invalid' unique count after processing: 193
# Difference in 'IT_invalid' unique counts: -72
# ======================================
#
# Number of overlapping rows (should be 0): 0

# %%
count_missing_values2(df,['IT_valid','IT_invalid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0   9659647      0
# 1  IT_invalid  category             0              0  14347179      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0         86572

# %% [markdown]
# ##### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT11.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT11.parquet")

# %% [markdown]
# #### Step 12 individual mapping of invalid IT codes

# %%
from IPython.display import display, HTML

# Create a scrollable div for the output
unique_values = df['IT_invalid'].cat.categories if df['IT_invalid'].dtype.name == 'category' else df['IT_invalid'].unique()
html_output = '<div style="max-height: 300px; overflow-y: scroll; border: 1px solid black;">' \
              + '<br>'.join(map(str, unique_values)) + '</div>'

# Display the scrollable output
display(HTML(html_output))
# Out:
# <div style="max-height: 300px; overflow-y: scroll; border: 1px solid black;"><br>0<br>0 0e+ 11<br>0 13e+ 11<br>0 20e+ 11<br>0 3e+ 11<br>0 66e+ 11<br>0 79e+ 11<br>0 91e+ 11<br>0 95e+ 11<br>0 96e+ 11<br>0 97e+ 11<br>017<br>1 1<br>1 12e+ 11<br>1 2<br>1 2e+ 11<br>1 35e+ 11<br>1 47e+ 12<br>1 60e+ 11<br>1 7<br>10<br>15<br>17<br>17 19<br>17+ e5 19 29+ e5 28<br>1719<br>19<br>19 1<br>2<br>2 27e+ 11<br>2 34e+ 11<br>2 56e+ 11<br>2 6<br>2 77<br>2 79<br>2 80<br>2 80e+ 11<br>2 98<br>20<br>2013 341 e1 2<br>22<br>29<br>29+ e5 28<br>29+ e9 37<br>2928<br>3<br>3 65e+ 11<br>33<br>37+ e5 29<br>37+ e5 32<br>4 0e+ 11<br>4 43e+ 11<br>715 2007 EC 136 2014 EC J<br>715 2007 EC 136 2014 EC ZX<br>715 2007 EC 195 2013 EC J<br>8<br>9<br>9 e9 29<br>?3 29<br>E1 8 33<br>IP0014WAP1<br>IP0015WAP1<br>NEDC 28WLTP<br>NEDC e5 28 WLTP<br>No<br>Not applicable<br>e<br>e e2 28 29<br>e e5 29<br>e1<br>e1 0<br>e1 333<br>e11 119<br>e11 19 NED<br>e11 19 NEDC e5 28 WLTP<br>e1117<br>e1119<br>e13 17 19 HIGH<br>e13 17 19 High<br>e13 17 19 LOW<br>e13 17 19 Low<br>e13 17 19 MID<br>e13 17 19 Mid<br>e13 17 19 low<br>e13 17 19 mid<br>e13 1719<br>e13 1719 Mid<br>e13 1728 29<br>e13 27 19 HIGH<br>e13 27 19 Mid<br>e13 28 219<br>e1317<br>e131719<br>e1319<br>e1328<br>e132829<br>e1329<br>e1329 37<br>e1337<br>e17<br>e2 0<br>e2 1719<br>e2 28 229<br>e2 2829<br>e2 2937<br>e2 33 e237<br>e2 3337<br>e2 3729<br>e2 43 17 19<br>e212<br>e217<br>e217 19<br>e217 28 29<br>e219<br>e228 29<br>e229 e228 e217 e219<br>e233 e2 37<br>e24 1719<br>e24 19 27 328<br>e24 327<br>e2429<br>e3 28 e3 32 e3 37 e3 28 e3 32 e3 37<br>e36<br>e37<br>e4 17 e419<br>e4 19 2829<br>e4 19 2928<br>e4 19 80<br>e4 29 +<br>e4 29 + e4 37<br>e4 29 2817<br>e4 292817<br>e4 32 + e4 37<br>e4 32037<br>e4 33 337<br>e4 33 374<br>e4 342 37<br>e417<br>e417 e4 29 e4 28<br>e419 22<br>e41922<br>e41927<br>e429 e428 e417<br>e432 37<br>e437<br>e45 29<br>e46 37<br>e5 28 WLTP<br>e5 2832<br>e5 28WLTP<br>e5 29 e37<br>e5 32 e537<br>e5 37 WLTP e9 32 WLTP<br>e5 37 wltp e9 32 wltp<br>e5 3732<br>e517<br>e517 e5 29<br>e517 e519 e529 e528<br>e517 e529<br>e519<br>e529<br>e529 e537<br>e532<br>e537<br>e59 e5 29<br>e619<br>e619 e6 28<br>e619 e628<br>e628<br>e637<br>e637e<br>e8 192829<br>e8 919<br>e81719<br>e819<br>e9<br>e9 1719<br>e9 219 28 29<br>e9 2719<br>e9 29+<br>e9 29037<br>e9 3732<br>e917<br>e917 19<br>e91719<br>e91719 e92829<br>e919<br>e929<br>e932<br>er 19 22<br>no</div>

# %%
# Step 12: map some remaining values of IT_invalid to valid IT Codes/TACs


mappings_IT = [
    # Map 'e e2 28 29'
    (['e e2 28 29'], 'e2 28 29'),
    # Map 'e e5 29'
    (['e e5 29'], 'e5 29'),
    # Map 'e11 19 NED', 'e11 19 NEDC e5 28 WLTP'
    (['e11 19 NED'], 'e11 19'),
    (['e11 19 NEDC e5 28 WLTP'], 'e11 19 e5 28'),
    # Map 'e1117', 'e1119' to 'e11 17', 'e11 19'
    (['e1117'], 'e11 17'),
    (['e1119'], 'e11 19'),
    # Map variations of 'e13 17 19'
    (['e13 17 19 HIGH', 'e13 17 19 High', 'e13 17 19 LOW', 'e13 17 19 Low',
      'e13 17 19 MID', 'e13 17 19 Mid', 'e13 17 19 low', 'e13 17 19 mid',
      'e13 1719', 'e13 1719 Mid', 'e131719'], 'e13 17 19'),
    # Map 'e13 1728 29' to 'e13 17 28 29'
    (['e13 1728 29'], 'e13 17 28 29'),
    # Map 'e13 27 19' variations
    (['e13 27 19 HIGH', 'e13 27 19 Mid'], 'e13 27 19'),
    # Map concatenated 'e13' codes
    (['e1317'], 'e13 17'),
    (['e1319'], 'e13 19'),
    (['e1328'], 'e13 28'),
    (['e132829'], 'e13 28 29'),
    (['e1329'], 'e13 29'),
    (['e1329 37'], 'e13 29 37'),
    (['e1337'], 'e13 37'),
    # Map 'e2' concatenated codes
    (['e2 1719', 'e21719', 'e217 19'], 'e2 17 19'),
    (['e2 28 229', 'e2 2829', 'e228 29', 'e228 29'], 'e2 28 29'),
    (['e2 33 e237', 'e2 3337'], 'e2 33 37'),
    (['e2 2937'], 'e2 29 37'),
    (['e212'], 'e2 12'),
    (['e217'], 'e2 17'),
    (['e219'], 'e2 19'),
    # Map 'e24' codes
    (['e24 1719'], 'e24 17 19'),
    (['e2429'], 'e24 29'),
    # Map 'e4' codes
    (['e4 17 e419'], 'e4 17 e4 19'),
    (['e417'], 'e4 17'),
    (['e4 19 2829', 'e4 19 2928'], 'e4 19 28 29'),
    (['e417 e4 29 e4 28', 'e429 e428 e417'], 'e4 17 e4 28 e4 29'),
    (['e432 37', 'e4 32037'], 'e4 32 37'),
    (['e437'], 'e4 37'),
    # Map 'e5' codes
    (['e5 28 WLTP', 'e5 28WLTP', 'NEDC e5 28 WLTP'], 'e5 28'),
    (['e5 2832'], 'e5 28 32'),
    (['e5 32 e537'], 'e5 32 e5 37'),
    (['e5 37 WLTP e9 32 WLTP', 'e5 37 wltp e9 32 wltp'], 'e5 37 e9 32'),
    (['e5 3732'], 'e5 37 32'),
    (['e517'], 'e5 17'),
    (['e517 e5 29', 'e517 e529'], 'e5 17 e5 29'),
    (['e517 e519 e529 e528'], 'e5 17 e5 19 e5 29 e5 28'),
    (['e529'], 'e5 29'),
    (['e529 e537'], 'e5 29 e5 37'),
    (['e532'], 'e5 32'),
    (['e537'], 'e5 37'),
    (['e59 e5 29'], 'e5 9 e5 29'),
    # Map 'e6' codes
    (['e619'], 'e6 19'),
    (['e619 e6 28', 'e619 e628'], 'e6 19 e6 28'),
    (['e628'], 'e6 28'),
    (['e637', 'e637e'], 'e6 37'),
    # Map 'e8' codes
    (['e8 192829'], 'e8 19 28 29'),
    (['e81719'], 'e8 17 19'),
    (['e819'], 'e8 19'),
    # Map 'e9' codes
    (['e9 1719'], 'e9 17 19'),
    (['e9 2719'], 'e9 27 19'),
    (['e9 29+'], 'e9 29'),
    (['e9 3732'], 'e9 37 32'),
    (['e917'], 'e9 17'),
    (['e917 19', 'e91719'], 'e9 17 19'),
    (['e91719 e92829'], 'e9 17 19 e9 28 29'),
    (['e919'], 'e9 19'),
    (['e929'], 'e9 29'),
    (['e932'], 'e9 32'),
    # new mappings
    (['e1329 37'], 'e13 29 e13 37'),
    (['?3 29'], 'e3 29'),
    (['e4 29 + e4 37'], 'e4 29 e4 37'),
    (['e4 29 +'], 'e4 29'),
    (['e1 0'], 'e1 0'),
    (['e2 0'], 'e2 0'),
    (['e2 3729'], 'e2 37 e2 29'),
    (['e2 43 17 19'], 'e2 43 e2 17 e2 19'),
    (['e229 e228 e217 e219'], 'e2 29 e2 28 e2 17 e2 19'),
    (['e233 e2 37'], 'e2 33 e2 37'),
    (['e3 28 e3 32 e3 37 e3 28 e3 32 e3 37'], 'e3 28 e3 32 e3 37'),
    (['e4 29 2817', 'e4 292817'], 'e4 29 e4 28 e4 17'),
    (['e4 32 + e4 37'], 'e4 32 e4 37'),
    (['e41922', 'e419 22'], 'e4 19 e4 22'),
    (['e41927'], 'e4 19 e4 27'),
    (['e45 29'], 'e4 5 e4 29'),
    (['e46 37'], 'e4 6 e4 37'),
    (['e5 29 e37'], 'e5 29 e5 37'),
    (['e8 919'], 'e8 9 e8 19'),
    (['e9 219 28 29'], 'e9 2e9 19 e9 28 e9 29'),
    (['e9 29037'], 'e9 29 e9 37'),
    (['E1 8 33'], 'e1 8 e1 33'),
    ([''], np.nan)
]

# Apply the renaming to the 'IT_invalid' column
rename_catval(df, "IT_invalid", mappings_IT)

# %%
# after mapping filter and go through steps 10 and 11 again to extract newly generated valid IT codes (TACs)

df = filter_and_split_valid_tacs(df)

# Execute Step 10
df = expand_shared_country_codes(df)

df = filter_and_split_valid_tacs(df)

# Execute Step 11:
df = expand_multiple_country_codes(df)

df = filter_and_split_valid_tacs(df)
# Out:
# === Filter and Split Valid TACs ===
# Transferred 2996 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 53
# List of unique valid TACs transferred to 'IT_valid':
# ['e5 17', 'e11 17', 'e11 19 e5 28', 'e11 19', 'e2 17', 'e2 19', 'e9 17', 'e4 17', 'e13 19', 'e13 17', 'e8 9 e8 19', 'e6 19', 'e2 12', 'e4 17 e4 19', 'e4 19 e4 22', 'e4 19 e4 27', 'e9 19', 'e8 19', 'e24 29', 'e6 19 e6 28', 'e2 33 e2 37', 'e4 17 e4 28 e4 29', 'e4 29 e4 28 e4 17', 'e2 29 e2 28 e2 17 e2 19', 'e5 9 e5 29', 'e5 28', 'e5 37 e9 32', 'e5 32 e5 37', 'e5 29', 'e5 32', 'e5 37', 'e5 17 e5 29', 'e3 29', 'e6 28', 'e6 37', 'e1 8 e1 33', 'e13 29', 'e13 37', 'e9 32', 'e9 29', 'e4 29 e4 37', 'e4 32 e4 37', 'e5 17 e5 19 e5 29 e5 28', 'e5 29 e5 37', 'e4 29', 'e13 29 e13 37', 'e13 28', 'e2 37 e2 29', 'e3 28 e3 32 e3 37', 'e4 6 e4 37', 'e9 29 e9 37', 'e4 5 e4 29', 'e4 37']
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 543
# 'IT_valid' unique count after processing: 551
# Difference in 'IT_valid' unique counts: 8
# 'IT_invalid' unique count before processing: 158
# 'IT_invalid' unique count after processing: 105
# Difference in 'IT_invalid' unique counts: -53
# ======================================
#
# Number of overlapping rows (should be 0): 0
# Warning: Entry '0' does not have enough parts to expand.
# Warning: Entry '017' does not have enough parts to expand.
# Warning: Entry '10' does not have enough parts to expand.
# Warning: Entry '15' does not have enough parts to expand.
# Warning: Entry '17' does not have enough parts to expand.
# Warning: Entry '1719' does not have enough parts to expand.
# Warning: Entry '19' does not have enough parts to expand.
# Warning: Entry '2' does not have enough parts to expand.
# Warning: Entry '20' does not have enough parts to expand.
# Warning: Entry '22' does not have enough parts to expand.
# Warning: Entry '29' does not have enough parts to expand.
# Warning: Entry '2928' does not have enough parts to expand.
# Warning: Entry '3' does not have enough parts to expand.
# Warning: Entry '33' does not have enough parts to expand.
# Warning: Entry '8' does not have enough parts to expand.
# Warning: Entry '9' does not have enough parts to expand.
# Warning: Entry 'IP0014WAP1' does not have enough parts to expand.
# Warning: Entry 'IP0015WAP1' does not have enough parts to expand.
# Warning: Entry 'No' does not have enough parts to expand.
# Warning: Entry 'e' does not have enough parts to expand.
# Warning: Entry 'e1' does not have enough parts to expand.
# Warning: Entry 'e17' does not have enough parts to expand.
# Warning: Entry 'e36' does not have enough parts to expand.
# Warning: Entry 'e37' does not have enough parts to expand.
# Warning: Entry 'e519' does not have enough parts to expand.
# Warning: Entry 'e9' does not have enough parts to expand.
# Warning: Entry 'no' does not have enough parts to expand.
#
# Modified 3721 rows by expanding shared country codes.
# Change in number of unique values in IT_invalid after expansion: 0
# Values that matched the shared country code criteria (original state):
# ['e13 17 19', 'e13 27 19', 'e9 17 19', 'e9 27 19', 'e8 17 19', 'e2 17 19', 'e13 17 28 29', 'e24 17 19', 'e2 28 29', 'e2 33 37'] ...
#
# Sample transformations:
# Before: e13 17 19 --> After: e13 17 e13 19
# Before: e5 28 32 --> After: e5 28 e5 32
# Before: e13 17 19 --> After: e13 17 e13 19
# Before: e13 17 19 --> After: e13 17 e13 19
# Before: e13 17 19 --> After: e13 17 e13 19
# === Filter and Split Valid TACs ===
# Transferred 3721 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 18
# List of unique valid TACs transferred to 'IT_valid':
# ['e13 17 e13 19', 'e13 27 e13 19', 'e9 17 e9 19', 'e9 27 e9 19', 'e8 17 e8 19', 'e2 17 e2 19', 'e13 17 e13 28 e13 29', 'e24 17 e24 19', 'e2 28 e2 29', 'e2 33 e2 37', 'e4 19 e4 28 e4 29', 'e4 32 e4 37', 'e8 19 e8 28 e8 29', 'e13 28 e13 29', 'e5 28 e5 32', 'e5 37 e5 32', 'e9 37 e9 32', 'e2 29 e2 37']
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 550
# 'IT_valid' unique count after processing: 553
# Difference in 'IT_valid' unique counts: 3
# 'IT_invalid' unique count before processing: 105
# 'IT_invalid' unique count after processing: 88
# Difference in 'IT_invalid' unique counts: -17
# ======================================
#
# Number of overlapping rows (should be 0): 0
#
# === Step 11: Expand Multiple Country Codes ===
# Modified 16 rows by expanding multiple country codes.
# Change in number of unique values after expansion: 1
# Values that matched the multiple country code criteria (original state):
# ['e2 43 e2 17 e2 19', '17+ e5 19 29+ e5 28', 'e9 2 e9 19 e9 28 e9 29', 'e9 17 19 e9 28 29'] ...
#
# Sample transformations:
# Before: e2 43 e2 17 e2 19 --> After: 43 e2 17 e2 19
# Before: e2 43 e2 17 e2 19 --> After: 43 e2 17 e2 19
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: e9 17 19 e9 28 29 --> After: e9 17 e9 19 e9 28 e9 29
# Before: e9 17 19 e9 28 29 --> After: e9 17 e9 19 e9 28 e9 29
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: e2 43 e2 17 e2 19 --> After: 43 e2 17 e2 19
# Before: e9 17 19 e9 28 29 --> After: e9 17 e9 19 e9 28 e9 29
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# Before: e9 2e9 19 e9 28 e9 29 --> After: e9 2 e9 19 e9 28 e9 29
# Before: e2 43 e2 17 e2 19 --> After: 43 e2 17 e2 19
# Before: 17+ e5 19 29+ e5 28 --> After: 17+ e5 19 29+ e5 28
# ============================================
#
# === Filter and Split Valid TACs ===
# Transferred 4 rows containing valid TAC entries to 'IT_valid'.
# Number of unique TACs transferred to 'IT_valid': 2
# List of unique valid TACs transferred to 'IT_valid':
# ['e9 2 e9 19 e9 28 e9 29', 'e9 17 e9 19 e9 28 e9 29']
#
# --- Unique Counts Statistics ---
# 'IT_valid' unique count before processing: 552
# 'IT_valid' unique count after processing: 554
# Difference in 'IT_valid' unique counts: 2
# 'IT_invalid' unique count before processing: 88
# 'IT_invalid' unique count after processing: 86
# Difference in 'IT_invalid' unique counts: -2
# ======================================
#
# Number of overlapping rows (should be 0): 0

# %%
count_missing_values2(df, ['IT_invalid', 'IT_valid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0  IT_invalid  category             0              0  14440472      0
# 1    IT_valid  category             0              0   9652926      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0             0

# %%
# Count number of remaining "invalid", i.e. not correctly parsed and extracted values
df.IT_invalid.notna().sum()
# Out:
# 2320

# %% [markdown]
# ##### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT12.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT12.parquet")
count_missing_values2(df, ['IT_valid', 'IT_invalid'])
# Out:
#        Column Data Type  nan (string)  None (string)    np.nan  pd.NA  \
# 0    IT_valid  category             0              0   9652926      0
# 1  IT_invalid  category             0              0  14440472      0
#
#    None (object)  Empty string
# 0              0             0
# 1              0             0

# %% [markdown]
# #### Step 13: split IT into 5 columns

# %%
# Split 'IT_valid' column into 5 separate columns for each TAC (up to 5 TACs)
tac_df = split_valid_tacs(df['IT_valid'])

# Concatenate the new columns back to the original DataFrame
df = pd.concat([df, tac_df], axis=1)

# Display the first few rows to verify the result
print(df.head())
# Out:
#        ID Country  VFN    Mp              Mh  \
# 0  280060      UK  NaN  None         UNKNOWN
# 1  280060      UK  NaN  None         AUDI AG
# 2  280060      PL  NaN  None      VOLKSWAGEN
# 3  280060      HU  NaN  None  HYUNDAI ASSAN
# 4  280060      HU  NaN  None            OPEL
#
#                                 Man       MMS                  Tan  \
# 0                           UNKNOWN  VAUXHALL                  NaN
# 1                               NaN      AUDI                  NaN
# 2                     VOLKSWAGEN AG       NaN  e1*2001/116*0211*27
# 3  HYUNDAI ASSAN OTOMOTIV SANAYI VE   Hyundai  e11*2007/46*0192*04
# 4                      ADAM OPEL AG      Opel   e1*2007/46*0374*14
#
#              T       Va                       Ve              Mk  \
# 0  A-H/MONOCAB     BF11              2A05ASXEGA7        VAUXHALL
# 1           B8  LCAKAQ1      QM6B4006R8K927MGEM0            AUDI
# 2           1T   CFHCAF  FD6FD62E0187MQS7N1VR0S0      VOLKSWAGEN
# 3          ELH    F5D31                   M65AZ1  HYUNDAI ASSAN
# 4         0G-A  CAHBC12               BA1N1FMHD5            Opel
#
#                          Cn  Ct   Cr     r  m (kg)  Mt  Enedc (g/km)  \
# 0  ZAFIRA SRI XP 150 CDTI A  M1  NaN  14.0  1613.0 NaN         191.0
# 1              S4 T QUATTRO  M1  NaN   3.0  1735.0 NaN           NaN
# 2                    TOURAN  M1  NaN   1.0  1629.0 NaN         131.0
# 3                      ix35  M1  NaN   1.0  1500.0 NaN         139.0
# 4     Insignia Limousine HB  M1  NaN   4.0  1613.0 NaN         114.0
#
#    Ewltp (g/km)  W (mm)  At1 (mm)  At2 (mm)      Ft Fm  ec (cm3)  ep (KW)  \
# 0           NaN  2703.0    1488.0    1512.0  DIESEL  M    1910.0      NaN
# 1           NaN     NaN       NaN       NaN  PETROL  M    2995.0      NaN
# 2           NaN  2675.0    1794.0    1794.0  DIESEL  M    1968.0    103.0
# 3           NaN  2640.0    1585.0    1586.0  DIESEL  M    1685.0     85.0
# 4           NaN  2737.0    1587.0    1590.0  DIESEL  M    1956.0    120.0
#
#    z (Wh/km)   IT  Ernedc (g/km)  Erwltp (g/km)  De  Vf Status  year  \
# 0        NaN  NaN            NaN            NaN NaN NaN      P  2010
# 1        NaN  NaN            NaN            NaN NaN NaN      P  2011
# 2        NaN  NaN            NaN            NaN NaN NaN      P  2012
# 3        NaN  NaN            NaN            NaN NaN NaN      P  2013
# 4        NaN  NaN            NaN            NaN NaN NaN      P  2014
#
#   Date of registration  Fuel consumption   ech RLFI  Electric range (km)  \
# 0                  NaN                NaN  NaN  NaN                  NaN
# 1                  NaN                NaN  NaN  NaN                  NaN
# 2                  NaN                NaN  NaN  NaN                  NaN
# 3                  NaN                NaN  NaN  NaN                  NaN
# 4                  NaN                NaN  NaN  NaN                  NaN
#
#    #identical occurences IT_valid IT_invalid IT_1 IT_2 IT_3 IT_4 IT_5
# 0                    1.0      NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 1                    1.0      NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 2                    1.0      NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 3                   30.0      NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 4                    1.0      NaN        NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Count unique IT codes across all IT_columns
count_unique_it_codes(df)
# Out:
# Counting unique IT codes across all IT columns...
# Identified IT code columns: ['IT_valid', 'IT_invalid', 'IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
# Total unique IT codes found: 726
# Top 10 most common IT codes:
# e1 29     1204823
# e13 29     625033
# e1 2       404091
# e24 19     370820
# e2 29      355815
# e8 29      340792
# e13 37     322692
# e24 29     313932
# e24 17     294846
# e8 37      288572
# dtype: int64
# e1 29            1204823
# e13 29            625033
# e1 2              404091
# e24 19            370820
# e2 29             355815
#                   ...
# e5 37 e3 32            1
# e13 37 e13 37          1
# e6 15 e6 14            1
# e8 39 e8 37            1
# e14 28                 1
# Length: 726, dtype: int64

# %% [markdown]
# ### save/read

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT_split.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Mp_Mh_IT_split.parquet")
#all_to_nan_and_cat(df, ['IT_valid', 'IT_invalid', 'IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'])
#print(count_missing_values2(df, ['IT_valid', 'IT_invalid', 'IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']))

# %%
df.to_parquet("..\\data\\EU\\EU_all_current_shared_Okt_23.parquet")

# %%
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Okt_23.parquet")

# %% [markdown]
# ## **Inspect categories**

# %%
# Again, inspect the unique categories in each categorical column after processing
for col in df.select_dtypes(include=['category']):
    num_categories = df[col].nunique(dropna=True)
    print(f"Column '{col}' has {num_categories} unique categorical values.")
# Out:
# Column 'Country' has 30 unique categorical values.
# Column 'VFN' has 29048 unique categorical values.
# Column 'Mh' has 218 unique categorical values.
# Column 'Man' has 477 unique categorical values.
# Column 'MMS' has 11561 unique categorical values.
# Column 'Tan' has 49909 unique categorical values.
# Column 'T' has 26611 unique categorical values.
# Column 'Va' has 72533 unique categorical values.
# Column 'Ve' has 182640 unique categorical values.
# Column 'Mk' has 1745 unique categorical values.
# Column 'Cn' has 80814 unique categorical values.
# Column 'Ct' has 9 unique categorical values.
# Column 'Cr' has 2 unique categorical values.
# Column 'Ft' has 11 unique categorical values.
# Column 'Fm' has 6 unique categorical values.
# Column 'IT' has 1928 unique categorical values.
# Column 'Status' has 1 unique categorical values.
# Column 'Date of registration' has 1095 unique categorical values.
# Column 'ech' has 36 unique categorical values.
# Column 'RLFI' has 1544 unique categorical values.
# Column 'IT_valid' has 553 unique categorical values.
# Column 'IT_invalid' has 85 unique categorical values.
# Column 'IT_1' has 178 unique categorical values.
# Column 'IT_2' has 130 unique categorical values.
# Column 'IT_3' has 54 unique categorical values.
# Column 'IT_4' has 24 unique categorical values.
# Column 'IT_5' has 3 unique categorical values.

# %% [markdown]
# # 1.C Pipeline Part 2 (Step by Step)
# All functions can be seen with description in the utils_co2.py function conglomeration
# This will be done in the summary of data treatment
# - taking the dataframe coming from renaming/mapping categories above
# - drop rows without target values
# - declare and drop irrelevant columns
# - filter df by year (default everything after 2018)
# + Identify electric cars
# + identify electric (or hybrid) cars by looking at electric range and electric capacity
# + making separate column whichs marks the non electric cars
# + fill then all the nan values in electri range and electric capacity with 0 (because they have non, which is equal to 0)
# - Outlier handling
# - Outlier handling function (IQR factor ab dem als Outlier gewertet wird)
# - Zusätzlich in die Funktion: ersetzen durch median oder row delete
# + give to the next steps

# %% [markdown]
# ## 1.C.0 Import and Load

# %%
import numpy as np
import pandas as pd

import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from utils_CO2 import *

# set option so that e.g. df.head() will show all columns and none are omitted
pd.set_option('display.max_columns', None)

# Load dataframe
# file_path = os.path.abspath(os.path.join('..', 'data', 'EU', 'EU_all_current_shared_Okt_23.parquet')
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Okt_23.parquet")

# %%
inspect_data(df)
# Out:
# ========================================
# 🚀 Basic Data Overview
# ========================================
# 🗂 Shape of the DataFrame: 14442792 rows, 49 columns
#
# 🔍 First 5 rows of the DataFrame:
#        ID Country  VFN                Mp              Mh  \
# 0  280060      UK  NaN               NaN         UNKNOWN
# 1  280060      UK  NaN               NaN         AUDI AG
# 2  280060      PL  NaN  Volkswagen Group      VOLKSWAGEN
# 3  280060      HU  NaN               NaN  HYUNDAI ASSAN
# 4  280060      HU  NaN    General Motors            OPEL
#
#                                 Man       MMS                  Tan  \
# 0                           UNKNOWN  VAUXHALL                  NaN
# 1                               NaN      AUDI                  NaN
# 2                     VOLKSWAGEN AG       NaN  e1*2001/116*0211*27
# 3  HYUNDAI ASSAN OTOMOTIV SANAYI VE   Hyundai  e11*2007/46*0192*04
# 4                      ADAM OPEL AG      Opel   e1*2007/46*0374*14
#
#              T       Va                       Ve              Mk  \
# 0  A-H/MONOCAB     BF11              2A05ASXEGA7        VAUXHALL
# 1           B8  LCAKAQ1      QM6B4006R8K927MGEM0            AUDI
# 2           1T   CFHCAF  FD6FD62E0187MQS7N1VR0S0      VOLKSWAGEN
# 3          ELH    F5D31                   M65AZ1  HYUNDAI ASSAN
# 4         0G-A  CAHBC12               BA1N1FMHD5            Opel
#
#                          Cn  Ct   Cr     r  m (kg)  Mt  Enedc (g/km)  \
# 0  ZAFIRA SRI XP 150 CDTI A  M1  NaN  14.0  1613.0 NaN         191.0
# 1              S4 T QUATTRO  M1  NaN   3.0  1735.0 NaN           NaN
# 2                    TOURAN  M1  NaN   1.0  1629.0 NaN         131.0
# 3                      ix35  M1  NaN   1.0  1500.0 NaN         139.0
# 4     Insignia Limousine HB  M1  NaN   4.0  1613.0 NaN         114.0
#
#    Ewltp (g/km)  W (mm)  At1 (mm)  At2 (mm)      Ft Fm  ec (cm3)  ep (KW)  \
# 0           NaN  2703.0    1488.0    1512.0  DIESEL  M    1910.0      NaN
# 1           NaN     NaN       NaN       NaN  PETROL  M    2995.0      NaN
# 2           NaN  2675.0    1794.0    1794.0  DIESEL  M    1968.0    103.0
# 3           NaN  2640.0    1585.0    1586.0  DIESEL  M    1685.0     85.0
# 4           NaN  2737.0    1587.0    1590.0  DIESEL  M    1956.0    120.0
#
#    z (Wh/km)   IT  Ernedc (g/km)  Erwltp (g/km)  De  Vf Status  year  \
# 0        NaN  NaN            NaN            NaN NaN NaN      P  2010
# 1        NaN  NaN            NaN            NaN NaN NaN      P  2011
# 2        NaN  NaN            NaN            NaN NaN NaN      P  2012
# 3        NaN  NaN            NaN            NaN NaN NaN      P  2013
# 4        NaN  NaN            NaN            NaN NaN NaN      P  2014
#
#   Date of registration  Fuel consumption   ech RLFI  Electric range (km)  \
# 0                  NaN                NaN  NaN  NaN                  NaN
# 1                  NaN                NaN  NaN  NaN                  NaN
# 2                  NaN                NaN  NaN  NaN                  NaN
# 3                  NaN                NaN  NaN  NaN                  NaN
# 4                  NaN                NaN  NaN  NaN                  NaN
#
#    #identical occurences                              tvv IT_valid IT_invalid  \
# 0                    1.0       A-H/MONOCABBF112A05ASXEGA7      NaN        NaN
# 1                    1.0     B8LCAKAQ1QM6B4006R8K927MGEM0      NaN        NaN
# 2                    1.0  1TCFHCAFFD6FD62E0187MQS7N1VR0S0      NaN        NaN
# 3                   30.0                   ELHF5D31M65AZ1      NaN        NaN
# 4                    1.0            0G-ACAHBC12BA1N1FMHD5      NaN        NaN
#
#   IT_1 IT_2 IT_3 IT_4 IT_5
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN
#
# 📊 DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14442792 entries, 0 to 14442791
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     Int64
#  1   Country                category
#  2   VFN                    category
#  3   Mp                     category
#  4   Mh                     category
#  5   Man                    category
#  6   MMS                    category
#  7   Tan                    category
#  8   T                      category
#  9   Va                     category
#  10  Ve                     category
#  11  Mk                     category
#  12  Cn                     category
#  13  Ct                     category
#  14  Cr                     category
#  15  r                      float32
#  16  m (kg)                 float32
#  17  Mt                     float32
#  18  Enedc (g/km)           float32
#  19  Ewltp (g/km)           float32
#  20  W (mm)                 float32
#  21  At1 (mm)               float32
#  22  At2 (mm)               float32
#  23  Ft                     category
#  24  Fm                     category
#  25  ec (cm3)               float32
#  26  ep (KW)                float32
#  27  z (Wh/km)              float32
#  28  IT                     category
#  29  Ernedc (g/km)          float32
#  30  Erwltp (g/km)          float32
#  31  De                     float32
#  32  Vf                     float32
#  33  Status                 category
#  34  year                   int32
#  35  Date of registration   category
#  36  Fuel consumption       float32
#  37  ech                    category
#  38  RLFI                   category
#  39  Electric range (km)    float32
#  40  #identical occurences  float32
#  41  tvv                    category
#  42  IT_valid               category
#  43  IT_invalid             category
#  44  IT_1                   category
#  45  IT_2                   category
#  46  IT_3                   category
#  47  IT_4                   category
#  48  IT_5                   category
# dtypes: Int64(1), category(29), float32(18), int32(1)
# memory usage: 1.9 GB
#
# 📈 Summary Statistics of Numeric Columns:
#                     ID             r        m (kg)            Mt  \
# count       14442792.0  1.444279e+07  1.442872e+07  1.063981e+07
# mean    35442140.89188  7.544409e+00  1.634169e+03  1.799300e+03
# std    44079806.984158  1.099097e+02  3.443328e+02  3.689104e+02
# min                1.0  1.000000e+00  1.000000e+00  0.000000e+00
# 25%         1901050.75  1.000000e+00  1.393000e+03  1.533000e+03
# 50%          9007275.0  1.000000e+00  1.590000e+03  1.748000e+03
# 75%         65014533.0  1.000000e+00  1.825000e+03  2.003000e+03
# max        149695043.0  5.909200e+04  9.928000e+03  6.612000e+03
#
#        Enedc (g/km)  Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)  \
# count  8.976101e+06  1.087719e+07  1.219070e+07  1.191959e+07  1.170436e+07
# mean   1.275489e+02  1.424030e+02  2.742043e+03  1.572893e+03  1.572726e+03
# std    4.481242e+01  5.580564e+01  3.241919e+02  1.746379e+02  1.635476e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.550000e+02  0.000000e+00
# 25%    1.110000e+02  1.280000e+02  2.626000e+03  1.538000e+03  1.536000e+03
# 50%    1.270000e+02  1.460000e+02  2.700000e+03  1.569000e+03  1.570000e+03
# 75%    1.490000e+02  1.700000e+02  2.850000e+03  1.605000e+03  1.611000e+03
# max    9.850000e+02  7.300000e+02  6.100000e+03  5.361000e+03  1.583000e+04
#
#            ec (cm3)       ep (KW)     z (Wh/km)  Ernedc (g/km)  Erwltp (g/km)  \
# count  1.382890e+07  1.304137e+07  1.301226e+06   1.804377e+06   2.854646e+06
# mean   1.829225e+03  1.297542e+02  1.910682e+02   1.920890e+00   1.524807e+00
# std    6.009905e+02  6.176083e+01  5.642786e+01   8.527987e-01   4.958403e-01
# min    0.000000e+00  0.000000e+00  1.000000e+00   0.000000e+00   0.000000e+00
# 25%    1.496000e+03  9.200000e+01  1.600000e+02   1.200000e+00   1.100000e+00
# 50%    1.950000e+03  1.100000e+02  1.770000e+02   1.700000e+00   1.660000e+00
# 75%    1.995000e+03  1.430000e+02  2.150000e+02   2.600000e+00   1.950000e+00
# max    8.463800e+04  1.770000e+03  2.756000e+03   9.200000e+00   2.000000e+01
#
#                   De            Vf          year  Fuel consumption   \
# count  326737.000000  1.143262e+06  1.444279e+07       3.972676e+06
# mean        0.044491  4.228077e-02  2.019142e+03       5.787786e+00
# std         0.339691  1.983620e-01  3.212640e+00       2.254286e+00
# min        -1.000000  0.000000e+00  2.010000e+03       1.000000e-01
# 25%         0.001000  0.000000e+00  2.018000e+03       5.000000e+00
# 50%         0.015000  0.000000e+00  2.020000e+03       5.800000e+00
# 75%         0.030000  0.000000e+00  2.022000e+03       6.800000e+00
# max         7.200000  2.000000e+00  2.023000e+03       9.900000e+01
#
#        Electric range (km)  #identical occurences
# count         1.094995e+06           1.444279e+07
# mean          2.040938e+02           5.553494e+00
# std           1.918173e+02           5.717576e+01
# min           1.000000e+00           1.000000e+00
# 25%           5.600000e+01           1.000000e+00
# 50%           7.600000e+01           1.000000e+00
# 75%           4.120000e+02           2.000000e+00
# max           8.830000e+02           2.744900e+04
#
# ❓ Missing Values Overview:
#                           Dtype Missing Count Percent Missing
# ID                        Int64             0           0.00%
# Country                category             0           0.00%
# VFN                    category       6022343          41.70%
# Mp                     category       2467065          17.08%
# Mh                     category          3756           0.03%
# Man                    category        310768           2.15%
# MMS                    category       6048284          41.88%
# Tan                    category        490543           3.40%
# T                      category         62037           0.43%
# Va                     category        100484           0.70%
# Ve                     category        225223           1.56%
# Mk                     category         42908           0.30%
# Cn                     category         49370           0.34%
# Ct                     category         24710           0.17%
# Cr                     category       2826753          19.57%
# r                       float32             4           0.00%
# m (kg)                  float32         14075           0.10%
# Mt                      float32       3802983          26.33%
# Enedc (g/km)            float32       5466691          37.85%
# Ewltp (g/km)            float32       3565598          24.69%
# W (mm)                  float32       2252091          15.59%
# At1 (mm)                float32       2523206          17.47%
# At2 (mm)                float32       2738433          18.96%
# Ft                     category         24373           0.17%
# Fm                     category         85880           0.59%
# ec (cm3)                float32        613895           4.25%
# ep (KW)                 float32       1401419           9.70%
# z (Wh/km)               float32      13141566          90.99%
# IT                     category       9564034          66.22%
# Ernedc (g/km)           float32      12638415          87.51%
# Erwltp (g/km)           float32      11588146          80.23%
# De                      float32      14116055          97.74%
# Vf                      float32      13299530          92.08%
# Status                 category             0           0.00%
# year                      int32             0           0.00%
# Date of registration   category       9206861          63.75%
# Fuel consumption        float32      10470116          72.49%
# ech                    category      13991213          96.87%
# RLFI                   category      13685744          94.76%
# Electric range (km)     float32      13347797          92.42%
# #identical occurences   float32             0           0.00%
# tvv                    category        245331           1.70%
# IT_valid               category       9652926          66.84%
# IT_invalid             category      14440472          99.98%
# IT_1                   category       9652926          66.84%
# IT_2                   category      12204576          84.50%
# IT_3                   category      14316902          99.13%
# IT_4                   category      14391741          99.65%
# IT_5                   category      14441337          99.99%
#
# 🔑 Unique Values in Categorical/Object Columns:
# Column 'Country' has 30 unique values
# Column 'VFN' has 29048 unique values
# Column 'Mp' has 27 unique values
# Column 'Mh' has 218 unique values
# Column 'Man' has 477 unique values
# Column 'MMS' has 11561 unique values
# Column 'Tan' has 49909 unique values
# Column 'T' has 26611 unique values
# Column 'Va' has 72533 unique values
# Column 'Ve' has 182640 unique values
# Column 'Mk' has 1745 unique values
# Column 'Cn' has 80814 unique values
# Column 'Ct' has 9 unique values
# Column 'Cr' has 2 unique values
# Column 'Ft' has 11 unique values
# Column 'Fm' has 6 unique values
# Column 'IT' has 1928 unique values
# Column 'Status' has 1 unique values
# Column 'Date of registration' has 1095 unique values
# Column 'ech' has 36 unique values
# Column 'RLFI' has 1544 unique values
# Column 'tvv' has 394014 unique values
# Column 'IT_valid' has 553 unique values
# Column 'IT_invalid' has 85 unique values
# Column 'IT_1' has 178 unique values
# Column 'IT_2' has 130 unique values
# Column 'IT_3' has 54 unique values
# Column 'IT_4' has 24 unique values
# Column 'IT_5' has 3 unique values

# %% [markdown]
# ## 1.C.1 Declare columns to delete

# %%
##################################################################################################################################
##############################################    Declare columns to delete    ###################################################
##################################################################################################################################
# Define the dictionary of columns to drop
columns_to_drop_dict = {
    # Global lists of columns to be dropped (default)
    "Car Identifiers":          ['Ve', 'Va', 'T', 'Tan', 'ID', 'tvv'],
    "Administrative Values":    ['Date of registration', 'Status', 'Dr', 'Vf', 'De'],
    "Data Related Columns":     ['r', 'R', 'Version_file'],
    "Brand Related":            ['Mp', 'Man', 'MMS'],
    "Temporary or Transformed": ['IT', 'IT_valid', 'IT_invalid', 'Non_Electric_Car'],
    "Target Redundant":         ['Enedc (g/km)', 'Fuel consumption ', 'Erwltp (g/km)', 
                                'Ernedc (g/km)', 'E (g/km)', 'Er (g/km)'],
    "Collinear Attributes":     ['m (kg)'], # At2 will be removed after calculation of "Area (m2)"
    "Other Columns":            ['Cr', 'ech', 'RLFI', 'Electric range (km)', 'z (Wh/km)', 'year'],
    # Additional columns to be dropped (individual)
    "Individual Columns":       ['Mk', 'Country', 'Cn', 'VFN']
}


##################################################################################################################################
####################################   Declare columns as gaussian or not for outlier handling   #################################
##################################################################################################################################
# Declare gaussian and non gaussian distributed columns
gaussian_cols = ['m (kg)', 'Mt',  'W (mm)', 'At1 (mm)', 'At2 (mm)']
non_gaussian_cols = [ 'ec (cm3)', 'ep (KW)', 'Ewltp (g/km)']
# lambda values for BoxCox Transformation of non-gaussian columns
lambda_dict = {
    'ec (cm3)': -0.669,
    'ep (KW)':  -0.599,
}
##################################################################################################################################

# %% [markdown]
# ## 1.C.2 Common Steps of Preprocessing / Feature Engineeering

# %%
##################################################################################################################################
################################  Common Steps of Preprocessing / Feature Engineeering ###########################################
##################################################################################################################################
    
# Drop rows where 'Ewltp (g/km)' is NaN
df = drop_rows_without_target(df, target='Ewltp (g/km)')
print("Dropped all rows without the target variable.")

# Make electric car column and replace nans with 0s in electric range&capacity column
df = process_electric_car_data(df, replace_nan=False, make_electric_car_column=True)
# Drop all electric
df = df[df['Non_Electric_Car'] == 'True']
print('Dropped all electric cars.')

# Filter data frame for cars and entries which are younger than 2019
df = filter_dataframe_by_year(df, year=2019)

# Drop everything except top 3 countries
df = df[df['Country'].isin(['DE', 'FR', 'IT'])]
print("Dropped all but top 3 countries (DE, FR, IT).")

# Drop columns as specified
df = drop_irrelevant_columns(df, columns_to_drop_dict)

# Outlier Handling (first run): replace with median for gaussian, drop for non-gaussian numerical attributes
#df = replace_outliers_with_median(df, columns=gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True)
#df = iqr_outlier_removal(df, columns=non_gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True)
# Out:
# Dropped all rows without the target variable.
# Dropped all electric cars.
# Dropped all years prior to 2019.
# Dropped all but top 3 countries (DE, FR, IT).
#
# ====== Dropping/Selecting Columns ======
# Columns "Car Identifiers" have been dropped: ['Ve', 'Va', 'T', 'Tan', 'ID', 'tvv']
# Columns "Administrative Values" have been dropped: ['Date of registration', 'Status', 'Vf', 'De']
# Columns "Data Related Columns" have been dropped: ['r']
# Columns "Brand Related" have been dropped: ['Mp', 'Man', 'MMS']
# Columns "Temporary or Transformed" have been dropped: ['IT', 'IT_valid', 'IT_invalid', 'Non_Electric_Car']
# Columns "Target Redundant" have been dropped: ['Enedc (g/km)', 'Fuel consumption ', 'Erwltp (g/km)', 'Ernedc (g/km)']
# Columns "Collinear Attributes" have been dropped: ['m (kg)']
# Columns "Other Columns" have been dropped: ['Cr', 'ech', 'RLFI', 'Electric range (km)', 'z (Wh/km)', 'year']
# Columns "Individual Columns" have been dropped: ['Mk', 'Country', 'Cn', 'VFN']
# Columns now present in the DataFrame: ['Mh', 'Ct', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft', 'Fm', 'ec (cm3)', 'ep (KW)', '#identical occurences', 'IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']

# %% [markdown]
# ### save/load

# %%
# Saving file in the repository data folder
#save_data(df, file_name = 'Data_Preprocessed_after_M.parquet')
df.to_parquet("..\\data\\Preprocessed\\intermediate\\Data_Preprocessed_minimal_with_fuel_consumption_with_weights.parquet")

# %%
df = pd.read_parquet("..\\data\\Preprocessed\\intermediate\\Data_Preprocessed_minimal_without_fuel_consumption_with_weights.parquet")

# %% [markdown]
# ## 1.C.3 Category Selection

# %% [markdown]
# ### generate category list

# %%
generate_category_lists(df, max_categories=20, min_cat_percent=0.1, top_n=20)
# Out:
# # For variable 'Mh', the top 20 categories are displayed based on their value_counts:
# # 'VOLKSWAGEN': 789301, 'BMW AG': 723673, 'MERCEDES-BENZ AG': 671403, 'AUDI AG': 579785, 'SKODA': 334917, 'FORD WERKE GMBH': 242485, 'SEAT': 191332, 'RENAULT': 130460, 'PSA': 127805, 'OPEL AUTOMOBILE': 124876, 'AUTOMOBILES PEUGEOT': 93215, 'VOLVO': 86865, 'PORSCHE': 78453, 'JAGUAR LAND ROVER LIMITED': 70811, 'FIAT GROUP': 67796, 'AUTOMOBILES CITROEN': 52733, 'AA-IVA': 33387, 'STELLANTIS EUROPE': 29971, 'TOYOTA': 26112, 'DACIA': 23646
# # Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# # ['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA']
# # Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# # If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
# df = filter_categories(df, 'Mh', drop=False, top_n=20, categories_to_keep=['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA'], other_label='Other', min_cat_percent=0.1)
#
# # For variable 'Ct', these are the categories available and their respective value_counts:
# # 'M1': 4259289, 'M1G': 417875, 'N1': 533, 'N2': 35, 'N1G': 24, 'N2G': 4, 'N3': 4, 'M2': 0, 'N3G': 0
# # Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# # ['M1', 'M1G', 'N1', 'N2', 'N1G', 'N2G', 'N3', 'M2', 'N3G']
# # Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# # If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
# df = filter_categories(df, 'Ct', drop=False, top_n=20, categories_to_keep=['M1', 'M1G', 'N1', 'N2', 'N1G', 'N2G', 'N3', 'M2', 'N3G'], other_label='Other', min_cat_percent=0.1)
#
# # For variable 'Ft', these are the categories available and their respective value_counts:
# # 'DIESEL': 2320878, 'PETROL': 2293843, 'PETROL/ELECTRIC': 21728, 'NG-BIOMETHANE': 18156, 'LPG': 8898, 'E85': 5873, 'ELECTRIC': 5566, 'DIESEL/ELECTRIC': 5241, 'HYDROGEN': 70, 'BIODIESEL': 0, 'OTHER': 0
# # Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# # ['DIESEL', 'PETROL', 'PETROL/ELECTRIC', 'NG-BIOMETHANE', 'LPG', 'E85', 'ELECTRIC', 'DIESEL/ELECTRIC', 'HYDROGEN', 'BIODIESEL', 'OTHER']
# # Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# # If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
# df = filter_categories(df, 'Ft', drop=False, top_n=20, categories_to_keep=['DIESEL', 'PETROL', 'PETROL/ELECTRIC', 'NG-BIOMETHANE', 'LPG', 'E85', 'ELECTRIC', 'DIESEL/ELECTRIC', 'HYDROGEN', 'BIODIESEL', 'OTHER'], other_label='Other', min_cat_percent=0.1)
#
# # For variable 'Fm', these are the categories available and their respective value_counts:
# # 'M': 3881690, 'H': 755160, 'P': 26970, 'B': 9835, 'E': 5566, 'F': 1033
# # Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# # ['M', 'H', 'P', 'B', 'E', 'F']
# # Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# # If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
# df = filter_categories(df, 'Fm', drop=False, top_n=20, categories_to_keep=['M', 'H', 'P', 'B', 'E', 'F'], other_label='Other', min_cat_percent=0.1)
#
# # Handling IT columns: ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
# # Aggregating IT codes across IT_1 to IT_5 and listing the top categories:
# # 'e1 29': 450239, 'e13 29': 292380, 'e13 37': 181449, 'e24 29': 175265, 'e24 17': 168087, 'e24 19': 163279, 'e2 29': 145153, 'e8 29': 144732, 'e24 28': 130765, 'e9 29': 125027, 'e1 2': 118521, 'e8 37': 102146, 'e13 19': 99698, 'e24 3': 97498, 'e24 37': 95575, 'e13 28': 91373, 'e2 17': 90679, 'e13 17': 85774, 'e9 37': 77894, 'e8 19': 74383
# # Please choose the number of top ITs to retain and adjust the 'top_n' and 'min_cat_percent' parameters in the function call.
# # Current top 20 ITs:
# # ['e1 29', 'e13 29', 'e13 37', 'e24 29', 'e24 17', 'e24 19', 'e2 29', 'e8 29', 'e24 28', 'e9 29', 'e1 2', 'e8 37', 'e13 19', 'e24 3', 'e24 37', 'e13 28', 'e2 17', 'e13 17', 'e9 37', 'e8 19']
# df = retain_top_n_ITs(df, top_n=20, IT_columns=['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'], other_label='Other', min_cat_percent=0.1)

# %% [markdown]
# ### select categories

# %%
# For variable 'Mh', the top 20 categories are displayed based on their value_counts:
# 'VOLKSWAGEN': 789301, 'BMW AG': 723673, 'MERCEDES-BENZ AG': 671403, 'AUDI AG': 579785, 'SKODA': 334917, 'FORD WERKE GMBH': 242485, 'SEAT': 191332, 'RENAULT': 130460, 'PSA': 127805, 'OPEL AUTOMOBILE': 124876, 'AUTOMOBILES PEUGEOT': 93215, 'VOLVO': 86865, 'PORSCHE': 78453, 'JAGUAR LAND ROVER LIMITED': 70811, 'FIAT GROUP': 67796, 'AUTOMOBILES CITROEN': 52733, 'AA-IVA': 33387, 'STELLANTIS EUROPE': 29971, 'TOYOTA': 26112, 'DACIA': 23646
# Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# ['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA']
# Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
df = filter_categories(df, 'Mh', drop=False, top_n=20, categories_to_keep=['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA'], other_label='Other', min_cat_percent=0.1)

# For variable 'Ct', these are the categories available and their respective value_counts:
# 'M1': 4259289, 'M1G': 417875, 'N1': 533, 'N2': 35, 'N1G': 24, 'N2G': 4, 'N3': 4, 'M2': 0, 'N3G': 0
# Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# ['M1', 'M1G', 'N1', 'N2', 'N1G', 'N2G', 'N3', 'M2', 'N3G']
# Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
df = filter_categories(df, 'Ct', drop=False, top_n=20, categories_to_keep=['M1', 'M1G', 'N1', 'N2'], other_label='Other', min_cat_percent=0.1)

# For variable 'Ft', these are the categories available and their respective value_counts:
# 'DIESEL': 2320878, 'PETROL': 2293843, 'PETROL/ELECTRIC': 21728, 'NG-BIOMETHANE': 18156, 'LPG': 8898, 'E85': 5873, 'ELECTRIC': 5566, 'DIESEL/ELECTRIC': 5241, 'HYDROGEN': 70, 'BIODIESEL': 0, 'OTHER': 0
# Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# ['DIESEL', 'PETROL', 'PETROL/ELECTRIC', 'NG-BIOMETHANE', 'LPG', 'E85', 'ELECTRIC', 'DIESEL/ELECTRIC', 'HYDROGEN', 'BIODIESEL', 'OTHER']
# Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
df = filter_categories(df, 'Ft', drop=True, top_n=20, categories_to_keep=['DIESEL', 'PETROL', 'NG-BIOMETHANE', 'LPG', 'E85', 'BIODIESEL', 'OTHER'], other_label='Other', min_cat_percent=0.1)

# For variable 'Fm', these are the categories available and their respective value_counts:
# 'M': 3881690, 'H': 755160, 'P': 26970, 'B': 9835, 'E': 5566, 'F': 1033
# Please choose which categories to include or adjust the 'top_n' and 'min_cat_percent' parameters.
# ['M', 'H', 'P', 'B', 'E', 'F']
# Note: If both `top_n` and `categories_to_keep` are provided, `categories_to_keep` will be ignored.
# If drop = True, rows will be dropped; otherwise, they will be labeled as 'Other'.
df = filter_categories(df, 'Fm', drop=False, top_n=20, categories_to_keep=['M', 'H', 'P', 'B', 'E', 'F'], other_label='Other', min_cat_percent=0.1)

# Handling IT columns: ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
# Aggregating IT codes across IT_1 to IT_5 and listing the top categories:
# 'e1 29': 450239, 'e13 29': 292380, 'e13 37': 181449, 'e24 29': 175265, 'e24 17': 168087, 'e24 19': 163279, 'e2 29': 145153, 'e8 29': 144732, 'e24 28': 130765, 'e9 29': 125027, 'e1 2': 118521, 'e8 37': 102146, 'e13 19': 99698, 'e24 3': 97498, 'e24 37': 95575, 'e13 28': 91373, 'e2 17': 90679, 'e13 17': 85774, 'e9 37': 77894, 'e8 19': 74383
# Please choose the number of top ITs to retain and adjust the 'top_n' and 'min_cat_percent' parameters in the function call.
# Current top 20 ITs:
# ['e1 29', 'e13 29', 'e13 37', 'e24 29', 'e24 17', 'e24 19', 'e2 29', 'e8 29', 'e24 28', 'e9 29', 'e1 2', 'e8 37', 'e13 19', 'e24 3', 'e24 37', 'e13 28', 'e2 17', 'e13 17', 'e9 37', 'e8 19']
df = retain_top_n_ITs(df, top_n=20, IT_columns=['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'], other_label='Other', min_cat_percent=0.1)
# Out:
# Categories to keep after applying thresholds: ['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA']
# Replaced 201220 values in 'Mh' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['M1', 'M1G']
# Replaced 600 values in 'Ct' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['DIESEL', 'PETROL', 'NG-BIOMETHANE', 'LPG', 'E85']
# Dropped 32605 rows where 'Ft' is not in the specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['M', 'H', 'B']
# Replaced 1034 values in 'Fm' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Retaining top 20 ITs that occur more than 0.1% and labeling others as 'Other'...
# Top ITs meeting the threshold: ['e1 29', 'e13 29', 'e13 37', 'e24 29', 'e24 17', 'e24 19', 'e2 29', 'e8 29', 'e24 28', 'e9 29', 'e1 2', 'e8 37', 'e13 19', 'e24 3', 'e24 37', 'e13 28', 'e2 17', 'e13 17', 'e9 37', 'e8 19']
# Updated 'IT_1' categories: ['Other', 'e1 2', 'e2 17', 'e24 19', 'e24 17', 'e13 17', 'e24 3', 'e13 19', 'e8 19', 'e13 29', 'e13 28', 'e1 29', 'e2 29', 'e24 29', 'e24 28', 'e9 29', 'e13 37', 'e9 37', 'e8 29', 'e8 37', 'e24 37']
# Updated 'IT_2' categories: ['e24 17', 'e24 19', 'e13 19', 'Other', 'e8 19', 'e2 17', 'e24 29', 'e13 29', 'e1 29', 'e13 28', 'e2 29', 'e9 29', 'e8 29', 'e24 28', 'e13 37', 'e9 37', 'e8 37', 'e24 37']
# Updated 'IT_3' categories: ['Other', 'e24 19', 'e24 17', 'e24 28', 'e24 29', 'e13 28', 'e13 29', 'e2 29', 'e1 29', 'e8 29', 'e2 17', 'e9 29']
# Updated 'IT_4' categories: ['Other', 'e24 29', 'e24 28', 'e13 29', 'e2 29', 'e9 29', 'e8 29']
# Updated 'IT_5' categories: ['e24 29', 'e8 29', 'Other']
# Replacement complete.
#
# =======================

# %% [markdown]
# ## 1.C.4 NaN Handling

# %% [markdown]
# ### explore

# %%
count_missing_values(df)
# Out:
#                  Dtype Missing Count Percent Missing
# Mh            category            13           0.00%
# Ct            category          2495           0.05%
# m (kg)         float32            23           0.00%
# Mt             float32         79117           1.69%
# Ewltp (g/km)   float32             0           0.00%
# W (mm)         float32        753911          16.11%
# At1 (mm)       float32        880244          18.81%
# At2 (mm)       float32        881190          18.83%
# Ft            category             6           0.00%
# Fm            category             5           0.00%
# ec (cm3)       float32          5669           0.12%
# ep (KW)        float32            60           0.00%
# IT_1          category       1984690          42.41%
# IT_2          category       3423270          73.14%
# IT_3          category       4599522          98.27%
# IT_4          category       4645481          99.26%
# IT_5          category       4679148          99.98%

# %% [markdown]
# ### generate nan-handling dictionary

# %%
nan_handling_strategy = generate_strategy_dict_code(df, default_strategy='drop', special_columns=None)
print(nan_handling_strategy)
# Out:
# nan_handling_strategy = {
#     'Mh': 'drop',
#     'Ct': 'drop',
#     'Mt': 'drop',
#     'Ewltp (g/km)': 'drop',
#     'W (mm)': 'drop',
#     'At1 (mm)': 'drop',
#     'Ft': 'drop',
#     'Fm': 'drop',
#     'ec (cm3)': 'drop',
#     'ep (KW)': 'drop',
#     'Fuel consumption ': 'drop',
#     '#identical occurences': 'drop',
#     'IT_1': 'leave_as_nan',
#     'IT_2': 'leave_as_nan',
#     'IT_3': 'leave_as_nan',
#     'IT_4': 'leave_as_nan',
#     'IT_5': 'leave_as_nan',
#     'Area (m2)': 'drop',
# }

# %% [markdown]
# ### choose nan-nandling for each column

# %%
# Possible strategies can be 'drop', 'mean', 'median', 'mode', 'zero', or 'leave_as_nan'

nan_handling_strategy = {
    'Mh': 'drop',
    'Ct': 'drop',
    'Mt': 'drop',
    'Ewltp (g/km)': 'drop',
    'W (mm)': 'drop',
    'At1 (mm)': 'drop',
    'Ft': 'drop',
    'Fm': 'drop',
    'ec (cm3)': 'drop',
    'ep (KW)': 'drop',
    'Fuel consumption ': 'drop',
    '#identical occurences': 'drop',
    'IT_1': 'leave_as_nan',
    'IT_2': 'leave_as_nan',
    'IT_3': 'leave_as_nan',
    'IT_4': 'leave_as_nan',
    'IT_5': 'leave_as_nan',
    'Area (m2)': 'drop',
}

# %% [markdown]
# ### handle NaNs (execute)

# %%
# NaN handling
df = handle_nans(df, nan_handling_strategy)
# Out:
# =========  Handle NaNs  ==============
# WARNING: The following columns specified in strategy_dict are not in the DataFrame and will be skipped: ['Fuel consumption ', 'Area (m2)']
# WARNING: The following columns are in the DataFrame but not specified in strategy_dict and will be left unchanged: ['At2 (mm)']
# Column 'Mh': Dropped 13 row(s) containing NaN(s).
# Column 'Ct': Dropped 2095 row(s) containing NaN(s).
# Column 'Mt': Dropped 73445 row(s) containing NaN(s).
# Column 'Ewltp (g/km)': Dropped 0 row(s) containing NaN(s).
# Column 'W (mm)': Dropped 742057 row(s) containing NaN(s).
# Column 'At1 (mm)': Dropped 868279 row(s) containing NaN(s).
# Column 'Ft': Dropped 6 row(s) containing NaN(s).
# Column 'Fm': Dropped 5 row(s) containing NaN(s).
# Column 'ec (cm3)': Dropped 28 row(s) containing NaN(s).
# Column 'ep (KW)': Dropped 5 row(s) containing NaN(s).
# Column '#identical occurences': Dropped 0 row(s) containing NaN(s).
#
# Column 'IT_1': Left 1675280 NaN(s) as is.
# Column 'IT_2': Left 2836625 NaN(s) as is.
# Column 'IT_3': Left 3652029 NaN(s) as is.
# Column 'IT_4': Left 3697088 NaN(s) as is.
# Column 'IT_5': Left 3730558 NaN(s) as is.
# =======================

# %% [markdown]
# ### (optional) separate treatment of Erwltp and Ernedc (only if in df)

# %%
# If thre is any IT employed (any IT value present), fill na of Erwltp and Ewltp
#df = handle_nans_IT_related_columns(df, ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'], target_columns = ['Erwltp (g/km)', 'Ernedc (g/km)'] , strategy='mean')

# %% [markdown]
# ## Calculate optimal Lambda for BoxCox

# %%
lambda_opt_ep = optimal_boxcox_lambda_weighted(
    series=df['ep (KW)'],
    frequency=df['#identical occurences'],
    coarse=True
)
# Out:
# After filtering, values < 1 in series: 0
# Expanded series statistics after filtering:
# count    1.902950e+07
# mean     1.019254e+02
# std      4.983161e+01
# min      4.400000e+01
# 25%      7.300000e+01
# 50%      9.200000e+01
# 75%      1.100000e+02
# max      1.177000e+03
# Name: ep (KW), dtype: float64
# Values < 1 in expanded series after filtering: 0

# %%
lambda_opt_ep
# Out:
# -0.5993114627478149

# %%
lambda_opt_ec = optimal_boxcox_lambda_weighted(
    series=df['ec (cm3)'],
    frequency=df['#identical occurences'],
    coarse=True
)
# Out:
# After filtering, values < 1 in series: 0
# Expanded series statistics after filtering:
# count    1.902950e+07
# mean     1.535223e+03
# std      5.179662e+02
# min      6.580000e+02
# 25%      1.199000e+03
# 50%      1.498000e+03
# 75%      1.968000e+03
# max      7.993000e+03
# Name: ec (cm3), dtype: float64
# Values < 1 in expanded series after filtering: 0

# %%
lambda_opt_ec
# Out:
# -0.6695044159470497

# %%
# Apply BoxCox Transfromation for ec and ep
df = apply_boxcox_transformation_df(df, lambda_dict)

# %% [markdown]
# ## 1.C.5 Encode categorical columns

# %% [markdown]
# ### explore

# %%
# count unique IT values
count_unique_it_codes(df)

# %% [markdown]
# ### encode (execute)

# %%
# Encoding categorical attributes
df = encode_categorical_columns(df, exclude_prefix='IT_', drop_first=True)
df = encode_top_its(df, n=0)  # Encode all present IT values

# %% [markdown]
# ## 1.C.6 Save Dataframe

# %%
# Saving file in the repository data folder
#save_data(df, file_name = 'Data_Preprocessed_finished.parquet')
df.to_parquet(os.path.join('..', 'data', 'Preprocessing', 'minimal_withoutfc_dupesdropped_frequencies_area_outliers3.0_tn20_mcp00.10.parquet'))

# %% [markdown]
# # 1.D Pipeline Part 2 (All in One and batch processig)

# %% [markdown]
# ## 1.D.0 Import and Load

# %%
import numpy as np
import pandas as pd

import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from utils_CO2 import *

# set option so that e.g. df.head() will show all columns and none are omitted
pd.set_option('display.max_columns', None)

# Load dataframe from file
df = pd.read_parquet("..\\data\\EU\\EU_all_current_shared_Okt_23.parquet")

# %%
df.dtypes
# Out:
# ID                          Int64
# Country                  category
# VFN                      category
# Mp                         object
# Mh                       category
# Man                      category
# MMS                      category
# Tan                      category
# T                        category
# Va                       category
# Ve                       category
# Mk                       category
# Cn                       category
# Ct                       category
# Cr                       category
# r                         float32
# m (kg)                    float32
# Mt                        float32
# Enedc (g/km)              float32
# Ewltp (g/km)              float32
# W (mm)                    float32
# At1 (mm)                  float32
# At2 (mm)                  float32
# Ft                       category
# Fm                       category
# ec (cm3)                  float32
# ep (KW)                   float32
# z (Wh/km)                 float32
# IT                       category
# Ernedc (g/km)             float32
# Erwltp (g/km)             float32
# De                        float32
# Vf                        float32
# Status                   category
# year                        int32
# Date of registration     category
# Fuel consumption          float32
# ech                      category
# RLFI                     category
# Electric range (km)       float32
# #identical occurences     float32
# IT_valid                 category
# IT_invalid               category
# IT_1                     category
# IT_2                     category
# IT_3                     category
# IT_4                     category
# IT_5                     category
# dtype: object

# %% [markdown]
# ## 1.D.1 Specify Parameters and define batch processing function

# %%
##################################################################################################################################
##############################################    Declare columns to delete    ###################################################
##################################################################################################################################
# Define the dictionary of columns to drop
columns_to_drop_dict = {
    # Global lists of columns to be dropped (default)
    "Car Identifiers":          ['Ve', 'Va', 'T', 'Tan', 'ID', 'tvv'],
    "Administrative Values":    ['Date of registration', 'Status', 'Dr', 'Vf', 'De'],
    "Data Related Columns":     ['r', 'R', 'Version_file'],
    "Brand Related":            ['Mp', 'Man', 'MMS'],
    "Temporary or Transformed": ['IT', 'IT_valid', 'IT_invalid', 'Non_Electric_Car'],
    "Target Redundant":         ['Enedc (g/km)', 'Fuel consumption ', 'Erwltp (g/km)', 
                                'Ernedc (g/km)', 'E (g/km)', 'Er (g/km)'],
    "Collinear Attributes":     ['m (kg)'], # At2 will be removed after calculation of "Area (m2)"
    "Other Columns":            ['Cr', 'ech', 'RLFI', 'Electric range (km)', 'z (Wh/km)', 'year'],
    # Additional columns to be dropped (individual)
    "Individual Columns":       ['Mk', 'Country', 'Cn', 'VFN']
}


##################################################################################################################################
####################################   Declare columns as gaussian or not for outlier handling   #################################
##################################################################################################################################
# Declare gaussian and non gaussian distributed columns
gaussian_cols = ['m (kg)', 'Mt',  'W (mm)', 'At1 (mm)', 'At2 (mm)']
non_gaussian_cols = [ 'ec (cm3)', 'ep (KW)', 'Ewltp (g/km)']
# lambda values for BoxCox Transformation of non-gaussian columns
lambda_dict = {
    'ec (cm3)': -0.669,
    'ep (KW)':  -0.599,
}
##################################################################################################################################



##################################################################################################################################
#######################   Specify Categories to keep (if not superseded by other filter parameters)  #############################
##################################################################################################################################
# Declare categories to keep (if not superseded by top_n parameter or not meeting percentage threshold (min_cat_percent)
categories_to_keep_dict = {
    "Mh":   ['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA',
             'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP',
             'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA'],
    "Ct":   ['M1', 'M1G', 'N1', 'N2'],
    "Ft":   ['DIESEL', 'PETROL', 'NG-BIOMETHANE', 'LPG', 'E85', 'HYDROGEN', 'BIODIESEL', 'OTHER'],
    "Fm":   ['M', 'H', 'P', 'B', 'E', 'F'],
}
##################################################################################################################################



##################################################################################################################################
###########################################   Declare NaN Handling Strategies   ##################################################
##################################################################################################################################  
# Possible strategies can be 'drop', 'mean', 'median', 'mode', 'zero', or 'leave_as_nan'
nan_handling_strategy = {
    'Mh':           'drop',
    'Ct':           'drop',
    'Mt':           'drop',
    'Ewltp (g/km)': 'drop',
    'W (mm)':       'drop',
    'At1 (mm)':     'drop',
    'At2 (mm)':     'drop',
    'Ft':           'drop',
    'Fm':           'drop',
    'ec (cm3)':     'drop',
    'ep (KW)':      'drop',
    'IT_1':         'leave_as_nan',
    'IT_2':         'leave_as_nan',
    'IT_3':         'leave_as_nan',
    'IT_4':         'leave_as_nan',
    'IT_5':         'leave_as_nan',
}
##################################################################################################################################



##################################################################################################################################
#####################  Define function to batch process the rest of the preprocessing with variations ############################
##################################################################################################################################

def process_datasets(df,
                     prefix_processed_filename = 'preprocessed_dataset',
                     top_n_list=[5, 10, 15, 20],
                     min_cat_percent_list=[0.1, 1, 5, 10],
                     IQR_outlier_multiplier = 1.5,
                     drop_first_category_at_encoding=True,
                     drop_dupes=True,
                     preserve_weights=True,
                     gaussian_cols = None,
                     non_gaussian_cols = None,
                     categories_to_keep = None,
                     nan_handling_strategy = None):
    
    # initialize filename_list
    filename_list = []
    
    # "save" copy of intermediate dataframe
    df_intermediate = df.copy()
    
    ############# Process all combinations of top_n_list and min_cat_percent ###############
    ########################################################################################
    for top_n in top_n_list:
        for min_cat_percent in min_cat_percent_list:
            
            df = df_intermediate.copy()
                        
            # Create a filename that reflects the parameters
            filename = f"{prefix_processed_filename}_tn{top_n:02d}_mcp{min_cat_percent:05.2f}.parquet"
            filename_list.append(filename)
            
            print("\n=========================================================")
            print(f"====== Processing file {filename} ======")
            print("===========================================================")
            
            # Apply the transformations with current top_n and min_cat_percent
            
            # Filter categories and drop or label "other" according to specified parameters (top_n, min_cat_percent) and/or categories_to_keep
            df = filter_categories(df, 'Mh', drop=False, top_n=top_n, categories_to_keep=categories_to_keep['Mh'],    other_label='Other', min_cat_percent=min_cat_percent)
            df = filter_categories(df, 'Ct', drop=False, top_n=top_n, categories_to_keep=categories_to_keep['Ct'],     other_label='Other', min_cat_percent=min_cat_percent)
            df = filter_categories(df, 'Ft', drop=True,  top_n=top_n, categories_to_keep=categories_to_keep['Ft'],     other_label='Other', min_cat_percent=min_cat_percent)
            df = filter_categories(df, 'Fm', drop=False, top_n=top_n, categories_to_keep=categories_to_keep['Fm'],     other_label='Other', min_cat_percent=min_cat_percent)
            df = retain_top_n_ITs (df,                   top_n=top_n, IT_columns=['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'],  other_label='Other', min_cat_percent=min_cat_percent)
            
            # NaN handling
            df = handle_nans(df, nan_handling_strategy)
            
            # Encoding categorical attributes
            df = encode_categorical_columns(df, exclude_prefix='IT_', drop_first=drop_first_category_at_encoding)
            df = encode_top_its(df, n=0)  # Encode all present IT values
            
            # Drop duplicates
            df = drop_duplicates(df, drop=drop_dupes, subset=None, preserve_weights=preserve_weights)
            
            # Outlier Handling (second run: because of row removal outlier calculation may have changed). no outlier handling on 'Area (m2)'
            #df = replace_outliers_with_median(df, columns=gaussian_cols, IQR_distance_multiplier=IQR_outlier_multiplier, apply_outlier_removal=True)
            #df = iqr_outlier_removal(df, columns=non_gaussian_cols, IQR_distance_multiplier=IQR_outlier_multiplier, apply_outlier_removal=True)
            df = replace_outliers_with_median_weighted(df, columns=gaussian_cols, IQR_distance_multiplier=IQR_outlier_multiplier, apply_outlier_removal=True, 
                        use_weighted_quartiles=True, weight_column='frequency')
            df = iqr_outlier_removal_weighted(df, columns=non_gaussian_cols, IQR_distance_multiplier=IQR_outlier_multiplier, apply_outlier_removal=True, 
                        use_weighted_quartiles=True, weight_column='frequency')
            
            # Calculate new attribute 'Area (m2)' and remove 'W (mm)' and 'At2 (mm)'
            df['Area (m2)'] = (df['W (mm)'] * ((df['At1 (mm)'] + df['At2 (mm)'])/2)) / 1000000
            df = df.drop(['At2 (mm)', 'W (mm)'], axis=1)
            print("Calculated attribute 'Area (m2)' as W * (At1+At2)/2) / 1000000.")
            print("Removed columns 'W (mm)' and 'At2 (mm)' (collinearity with At1 and Area)")
            
            print("=======================\n")
            
            # Save the DataFrame
            df.to_parquet(os.path.join('..', 'data', 'Preprocessed', filename))
               
    # return list of newly saved dataset files        
    return df, filename_list

# %% [markdown]
# ## 1.D.2 Execute batch processing

# %%
##################################################################################################################################
################################  Common Steps of Preprocessing / Feature Engineeering ###########################################
##################################################################################################################################
    
# Drop rows where 'Ewltp (g/km)' is NaN
df = drop_rows_without_target(df, target='Ewltp (g/km)')
print("Dropped all rows without the target variable.")

# Make electric car column and replace nans with 0s in electric range&capacity column
df = process_electric_car_data(df, replace_nan=False, make_electric_car_column=True)
# Drop all electric
df = df[df['Non_Electric_Car'] == 'True']
print('Dropped all electric cars.')

# Filter data frame for cars and entries which are younger than 2019
df = filter_dataframe_by_year(df, year=2019)

# Drop everything except top 3 countries
df = df[df['Country'].isin(['DE', 'FR', 'IT'])]
print("Dropped all but top 3 countries (DE, FR, IT).")

# Drop columns as specified
df = drop_irrelevant_columns(df, columns_to_drop_dict)

# Apply BoxCox Transfromation for non-gaussian columns (ec and ep)
df = apply_boxcox_transformation_df(df, lambda_dict)

# Outlier Handling (first run): replace with median for gaussian, drop for non-gaussian numerical attributes
#df = replace_outliers_with_median(df, columns=gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True)
#df = iqr_outlier_removal(df, columns=non_gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True)
df = replace_outliers_with_median_weighted(df, columns=gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True, 
                        use_weighted_quartiles=True, weight_column='#identical occurences')
df = iqr_outlier_removal_weighted(df, columns=non_gaussian_cols, IQR_distance_multiplier=3.0, apply_outlier_removal=True, 
                        use_weighted_quartiles=True, weight_column='#identical occurences')
            

##################################################################################################################################
#####################  Batch process the rest of the Preprocessing with various parameter combinations ###########################
##################################################################################################################################
        
df, filename_list = process_datasets(df = df,
                                 prefix_processed_filename = 'minimal_withoutfc_dupesdropped_frequencies_area_removedskew_outliers3_0_NoW_runagain',
                                 top_n_list=[20],
                                 min_cat_percent_list=[0.1],
                                 IQR_outlier_multiplier = 3.0,
                                 drop_first_category_at_encoding=True,
                                 drop_dupes=True,
                                 preserve_weights=True,
                                 gaussian_cols = gaussian_cols,
                                 non_gaussian_cols = non_gaussian_cols,
                                 categories_to_keep = categories_to_keep_dict,
                                 nan_handling_strategy = nan_handling_strategy
                                 )

# edit file_mapping.csv (append new dataset)
create_or_append_file_mapping(filename_list)
# Out:
# Dropped all rows without the target variable.
# Dropped all electric cars.
# Dropped all years prior to 2019.
# Dropped all but top 3 countries (DE, FR, IT).
#
# ====== Dropping/Selecting Columns ======
# Columns "Car Identifiers" have been dropped: ['Ve', 'Va', 'T', 'Tan', 'ID']
# Columns "Administrative Values" have been dropped: ['Date of registration', 'Status', 'Vf', 'De']
# Columns "Data Related Columns" have been dropped: ['r']
# Columns "Brand Related" have been dropped: ['Mp', 'Man', 'MMS']
# Columns "Temporary or Transformed" have been dropped: ['IT', 'IT_valid', 'IT_invalid', 'Non_Electric_Car']
# Columns "Target Redundant" have been dropped: ['Enedc (g/km)', 'Fuel consumption ', 'Erwltp (g/km)', 'Ernedc (g/km)']
# Columns "Collinear Attributes" have been dropped: ['m (kg)']
# Columns "Other Columns" have been dropped: ['Cr', 'ech', 'RLFI', 'Electric range (km)', 'z (Wh/km)', 'year']
# Columns "Individual Columns" have been dropped: ['Mk', 'Country', 'Cn', 'VFN']
# Columns now present in the DataFrame: ['Mh', 'Ct', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft', 'Fm', 'ec (cm3)', 'ep (KW)', '#identical occurences', 'IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
#
# ===  Replacing outliers in Gaussian columns with median  ===
# Replaced 3131 outliers in column 'Mt' with median value 1500.0.
# Replaced 143449 outliers in column 'W (mm)' with median value 2624.0.
# Replaced 2519 outliers in column 'At1 (mm)' with median value 1545.0.
# Replaced 1403 outliers in column 'At2 (mm)' with median value 1542.0.
# DataFrame shape after replacing outliers in Gaussian columns: (4674587, 17)
#
# ===  Removing outliers from non-Gaussian columns  ===
# Capped 0 outliers in column 'ec (cm3)' between 1.4706560373306274 and 1.4964877367019653.
# Capped 0 outliers in column 'ep (KW)' between 1.4451904296875 and 1.6627321243286133.
# Capped 151522 outliers in column 'Ewltp (g/km)' between 33.0 and 243.0.
# DataFrame shape after capping outliers in non-Gaussian columns: (4674587, 17)
#
# =========================================================
# ====== Processing file minimal_withoutfc_dupesdropped_frequencies_area_removedskew_outliers3_0_NoW_runagain_tn20_mcp00.10.parquet ======
# ===========================================================
# Categories to keep after applying thresholds: ['VOLKSWAGEN', 'BMW AG', 'MERCEDES-BENZ AG', 'AUDI AG', 'SKODA', 'FORD WERKE GMBH', 'SEAT', 'RENAULT', 'PSA', 'OPEL AUTOMOBILE', 'AUTOMOBILES PEUGEOT', 'VOLVO', 'PORSCHE', 'JAGUAR LAND ROVER LIMITED', 'FIAT GROUP', 'AUTOMOBILES CITROEN', 'AA-IVA', 'STELLANTIS EUROPE', 'TOYOTA', 'DACIA']
# Replaced 200589 values in 'Mh' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['M1', 'M1G']
# Replaced 594 values in 'Ct' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['DIESEL', 'PETROL', 'NG-BIOMETHANE', 'LPG', 'E85']
# Dropped 26963 rows where 'Ft' is not in the specified categories or occur less than 0.1% of total rows.
# Categories to keep after applying thresholds: ['M', 'H', 'B']
# Replaced 1034 values in 'Fm' with 'Other' where not in specified categories or occur less than 0.1% of total rows.
# Retaining top 20 ITs that occur more than 0.1% and labeling others as 'Other'...
# Top ITs meeting the threshold: ['e1 29', 'e13 29', 'e13 37', 'e24 29', 'e24 17', 'e24 19', 'e2 29', 'e8 29', 'e24 28', 'e9 29', 'e1 2', 'e8 37', 'e13 19', 'e24 3', 'e24 37', 'e13 28', 'e2 17', 'e13 17', 'e9 37', 'e8 19']
# Updated 'IT_1' categories: ['Other', 'e1 2', 'e2 17', 'e24 19', 'e24 17', 'e13 17', 'e24 3', 'e13 19', 'e8 19', 'e13 29', 'e13 28', 'e1 29', 'e2 29', 'e24 29', 'e24 28', 'e9 29', 'e13 37', 'e9 37', 'e8 29', 'e8 37', 'e24 37']
# Updated 'IT_2' categories: ['e24 17', 'e24 19', 'e13 19', 'Other', 'e8 19', 'e2 17', 'e24 29', 'e13 29', 'e1 29', 'e13 28', 'e2 29', 'e9 29', 'e8 29', 'e24 28', 'e13 37', 'e9 37', 'e8 37', 'e24 37']
# Updated 'IT_3' categories: ['Other', 'e24 19', 'e24 17', 'e24 28', 'e24 29', 'e13 28', 'e13 29', 'e2 29', 'e1 29', 'e8 29', 'e2 17', 'e9 29']
# Updated 'IT_4' categories: ['Other', 'e24 29', 'e24 28', 'e13 29', 'e2 29', 'e9 29', 'e8 29']
# Updated 'IT_5' categories: ['e24 29', 'e8 29', 'Other']
# Replacement complete.
#
# =======================
#
#
# =========  Handle NaNs  ==============
# WARNING: The following columns are in the DataFrame but not specified in strategy_dict and will be left unchanged: ['#identical occurences']
# Column 'Mh': Dropped 13 row(s) containing NaN(s).
# Column 'Ct': Dropped 2095 row(s) containing NaN(s).
# Column 'Mt': Dropped 73424 row(s) containing NaN(s).
# Column 'Ewltp (g/km)': Dropped 0 row(s) containing NaN(s).
# Column 'W (mm)': Dropped 742035 row(s) containing NaN(s).
# Column 'At1 (mm)': Dropped 868257 row(s) containing NaN(s).
# Column 'At2 (mm)': Dropped 869004 row(s) containing NaN(s).
# Column 'Ft': Dropped 4 row(s) containing NaN(s).
# Column 'Fm': Dropped 3 row(s) containing NaN(s).
# Column 'ec (cm3)': Dropped 0 row(s) containing NaN(s).
# Column 'ep (KW)': Dropped 0 row(s) containing NaN(s).
#
# Column 'IT_1': Left 1675243 NaN(s) as is.
# Column 'IT_2': Left 2836588 NaN(s) as is.
# Column 'IT_3': Left 3651992 NaN(s) as is.
# Column 'IT_4': Left 3697051 NaN(s) as is.
# Column 'IT_5': Left 3730521 NaN(s) as is.
# =======================
#
#
# ======  Encoding Categorical Variables ===========
# Identified categorical columns to encode (excluding 'IT_'): ['Mh', 'Ct', 'Ft', 'Fm']
# One-hot encoding completed with dummy variable trap prevention for columns: ['Mh', 'Ct', 'Ft', 'Fm']
#
# Column 'Mh' encoded into 19 values (baseline category dropped):
# Dropped category: AA-IVA (Count: 13116)
# Encoded values: AUDI AG (Count: 435206), AUTOMOBILES CITROEN (Count: 46350), AUTOMOBILES PEUGEOT (Count: 84057), BMW AG (Count: 570368), DACIA (Count: 18220), FIAT GROUP (Count: 58207), FORD WERKE GMBH (Count: 220440), JAGUAR LAND ROVER LIMITED (Count: 49859), MERCEDES-BENZ AG (Count: 539347), OPEL AUTOMOBILE (Count: 117258), PORSCHE (Count: 61244), PSA (Count: 121769), RENAULT (Count: 103381), SEAT (Count: 149169), SKODA (Count: 262904), TOYOTA (Count: 19701), VOLKSWAGEN (Count: 634025), VOLVO (Count: 72090), Other (Count: 154921)
#
# Column 'Ct' encoded into 2 values (baseline category dropped):
# Dropped category: M1 (Count: 3415790)
# Encoded values: M1G (Count: 315444), Other (Count: 398)
#
# Column 'Ft' encoded into 4 values (baseline category dropped):
# Dropped category: DIESEL (Count: 1880162)
# Encoded values: E85 (Count: 4174), LPG (Count: 4520), NG-BIOMETHANE (Count: 14312), PETROL (Count: 1828464)
#
# Column 'Fm' encoded into 3 values (baseline category dropped):
# Dropped category: B (Count: 5297)
# Encoded values: H (Count: 457283), M (Count: 3268143), Other (Count: 909)
# =======================
#
#
# ===  Encoding Categories of IT Columns (Innovative Technologies)  ===
# Encoding all IT codes...
# Counting unique IT codes across all IT columns...
# Identified IT code columns: ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
# Total unique IT codes found: 21
# Top 10 most common IT codes:
# Other     911330
# e1 29     311051
# e13 29    176609
# e24 17    167710
# e24 19    162418
# e24 29    122005
# e1 2      117985
# e24 28    104139
# e8 29      99657
# e13 19     98536
# dtype: int64
#
# Total IT codes to encode: 21
#
# Identified IT code columns: ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5']
# Total IT code entries after stacking and filtering: 3066765
# Shape of the one-hot encoded IT code DataFrame: (2056389, 21)
# One-hot encoding completed.
#
# Original IT code columns ['IT_1', 'IT_2', 'IT_3', 'IT_4', 'IT_5'] removed after encoding.
#
# =======================
#
#
# =========  Dropping Duplicates  ==============
# Grouping by columns: ['Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'ec (cm3)', 'ep (KW)', 'Mh_AUDI AG', 'Mh_AUTOMOBILES CITROEN', 'Mh_AUTOMOBILES PEUGEOT', 'Mh_BMW AG', 'Mh_DACIA', 'Mh_FIAT GROUP', 'Mh_FORD WERKE GMBH', 'Mh_JAGUAR LAND ROVER LIMITED', 'Mh_MERCEDES-BENZ AG', 'Mh_OPEL AUTOMOBILE', 'Mh_PORSCHE', 'Mh_PSA', 'Mh_RENAULT', 'Mh_SEAT', 'Mh_SKODA', 'Mh_TOYOTA', 'Mh_VOLKSWAGEN', 'Mh_VOLVO', 'Mh_Other', 'Ct_M1G', 'Ct_Other', 'Ft_E85', 'Ft_LPG', 'Ft_NG-BIOMETHANE', 'Ft_PETROL', 'Fm_H', 'Fm_M', 'Fm_Other', 'IT_code_Other', 'IT_code_e1 2', 'IT_code_e1 29', 'IT_code_e13 17', 'IT_code_e13 19', 'IT_code_e13 28', 'IT_code_e13 29', 'IT_code_e13 37', 'IT_code_e2 17', 'IT_code_e2 29', 'IT_code_e24 17', 'IT_code_e24 19', 'IT_code_e24 28', 'IT_code_e24 29', 'IT_code_e24 3', 'IT_code_e24 37', 'IT_code_e8 19', 'IT_code_e8 29', 'IT_code_e8 37', 'IT_code_e9 29', 'IT_code_e9 37']
# Total frequency before drops: 19029436
# Total frequency after drops: 19029436
# Total frequencies are consistent before and after dropping duplicates.
# Initial row count: 3731632
# Final row count: 2000450
# Number of duplicates dropped: 1731182
# =======================
#
#
# ===  Replacing outliers in Gaussian columns with median  ===
# Replaced 0 outliers in column 'Mt' with median value 1501.0.
# Replaced 0 outliers in column 'W (mm)' with median value 2624.0.
# Replaced 0 outliers in column 'At1 (mm)' with median value 1545.0.
# Replaced 8 outliers in column 'At2 (mm)' with median value 1545.0.
# DataFrame shape after replacing outliers in Gaussian columns: (2000450, 57)
#
# ===  Removing outliers from non-Gaussian columns  ===
# Capped 0 outliers in column 'ec (cm3)' between 1.4707142114639282 and 1.4964441061019897.
# Capped 0 outliers in column 'ep (KW)' between 1.458200454711914 and 1.6529746055603027.
# Capped 14 outliers in column 'Ewltp (g/km)' between 40.0 and 243.0.
# DataFrame shape after capping outliers in non-Gaussian columns: (2000450, 57)
# Calculated attribute 'Area (m2)' as W * (At1+At2)/2) / 1000000.
# Removed columns 'W (mm)' and 'At2 (mm)' (collinearity with At1 and Area)
# =======================
#
# Filename 'minimal_withoutfc_dupesdropped_frequencies_area_removedskew_outliers3_0_NoW_runagain_tn20_mcp00.10.parquet' already exists. Skipping.
# No new filenames to add.

# %% [markdown]
# # 1.E Choose Dataset

# %%
import numpy as np
import pandas as pd

import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from utils_CO2 import *

# set option so that e.g. df.head() will show all columns and none are omitted
pd.set_option('display.max_columns', None)

# %%
# 1.Load and view file mapping

file_mapping_df = load_file_mapping()
display(file_mapping_df.style.set_properties(**{'max-width': '100%'}))
# Out:
# <style type="text/css">
# #T_95ecc_row0_col0, #T_95ecc_row0_col1, #T_95ecc_row1_col0, #T_95ecc_row1_col1, #T_95ecc_row2_col0, #T_95ecc_row2_col1, #T_95ecc_row3_col0, #T_95ecc_row3_col1, #T_95ecc_row4_col0, #T_95ecc_row4_col1, #T_95ecc_row5_col0, #T_95ecc_row5_col1, #T_95ecc_row6_col0, #T_95ecc_row6_col1, #T_95ecc_row7_col0, #T_95ecc_row7_col1, #T_95ecc_row8_col0, #T_95ecc_row8_col1, #T_95ecc_row9_col0, #T_95ecc_row9_col1, #T_95ecc_row10_col0, #T_95ecc_row10_col1, #T_95ecc_row11_col0, #T_95ecc_row11_col1, #T_95ecc_row12_col0, #T_95ecc_row12_col1, #T_95ecc_row13_col0, #T_95ecc_row13_col1, #T_95ecc_row14_col0, #T_95ecc_row14_col1, #T_95ecc_row15_col0, #T_95ecc_row15_col1, #T_95ecc_row16_col0, #T_95ecc_row16_col1, #T_95ecc_row17_col0, #T_95ecc_row17_col1, #T_95ecc_row18_col0, #T_95ecc_row18_col1, #T_95ecc_row19_col0, #T_95ecc_row19_col1, #T_95ecc_row20_col0, #T_95ecc_row20_col1, #T_95ecc_row21_col0, #T_95ecc_row21_col1, #T_95ecc_row22_col0, #T_95ecc_row22_col1, #T_95ecc_row23_col0, #T_95ecc_row23_col1, #T_95ecc_row24_col0, #T_95ecc_row24_col1, #T_95ecc_row25_col0, #T_95ecc_row25_col1, #T_95ecc_row26_col0, #T_95ecc_row26_col1, #T_95ecc_row27_col0, #T_95ecc_row27_col1, #T_95ecc_row28_col0, #T_95ecc_row28_col1, #T_95ecc_row29_col0, #T_95ecc_row29_col1, #T_95ecc_row30_col0, #T_95ecc_row30_col1, #T_95ecc_row31_col0, #T_95ecc_row31_col1, #T_95ecc_row32_col0, #T_95ecc_row32_col1, #T_95ecc_row33_col0, #T_95ecc_row33_col1, #T_95ecc_row34_col0, #T_95ecc_row34_col1, #T_95ecc_row35_col0, #T_95ecc_row35_col1, #T_95ecc_row36_col0, #T_95ecc_row36_col1, #T_95ecc_row37_col0, #T_95ecc_row37_col1, #T_95ecc_row38_col0, #T_95ecc_row38_col1, #T_95ecc_row39_col0, #T_95ecc_row39_col1, #T_95ecc_row40_col0, #T_95ecc_row40_col1, #T_95ecc_row41_col0, #T_95ecc_row41_col1, #T_95ecc_row42_col0, #T_95ecc_row42_col1, #T_95ecc_row43_col0, #T_95ecc_row43_col1, #T_95ecc_row44_col0, #T_95ecc_row44_col1, #T_95ecc_row45_col0, #T_95ecc_row45_col1, #T_95ecc_row46_col0, #T_95ecc_row46_col1, #T_95ecc_row47_col0, #T_95ecc_row47_col1, #T_95ecc_row48_col0, #T_95ecc_row48_col1, #T_95ecc_row49_col0, #T_95ecc_row49_col1, #T_95ecc_row50_col0, #T_95ecc_row50_col1, #T_95ecc_row51_col0, #T_95ecc_row51_col1, #T_95ecc_row52_col0, #T_95ecc_row52_col1, #T_95ecc_row53_col0, #T_95ecc_row53_col1, #T_95ecc_row54_col0, #T_95ecc_row54_col1, #T_95ecc_row55_col0, #T_95ecc_row55_col1, #T_95ecc_row56_col0, #T_95ecc_row56_col1, #T_95ecc_row57_col0, #T_95ecc_row57_col1, #T_95ecc_row58_col0, #T_95ecc_row58_col1, #T_95ecc_row59_col0, #T_95ecc_row59_col1, #T_95ecc_row60_col0, #T_95ecc_row60_col1, #T_95ecc_row61_col0, #T_95ecc_row61_col1, #T_95ecc_row62_col0, #T_95ecc_row62_col1, #T_95ecc_row63_col0, #T_95ecc_row63_col1, #T_95ecc_row64_col0, #T_95ecc_row64_col1, #T_95ecc_row65_col0, #T_95ecc_row65_col1, #T_95ecc_row66_col0, #T_95ecc_row66_col1, #T_95ecc_row67_col0, #T_95ecc_row67_col1, #T_95ecc_row68_col0, #T_95ecc_row68_col1, #T_95ecc_row69_col0, #T_95ecc_row69_col1, #T_95ecc_row70_col0, #T_95ecc_row70_col1, #T_95ecc_row71_col0, #T_95ecc_row71_col1 {
#   max-width: 100%;
# }
# </style>
# <table id="T_95ecc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95ecc_level0_col0" class="col_heading level0 col0" >number</th>
#       <th id="T_95ecc_level0_col1" class="col_heading level0 col1" >filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95ecc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95ecc_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_95ecc_row0_col1" class="data row0 col1" >minimal_with_fuel_consumption_tn05_mcp00.10.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95ecc_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_95ecc_row1_col1" class="data row1 col1" >minimal_with_fuel_consumption_tn05_mcp01.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_95ecc_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_95ecc_row2_col1" class="data row2 col1" >minimal_with_fuel_consumption_tn05_mcp05.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_95ecc_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_95ecc_row3_col1" class="data row3 col1" >minimal_with_fuel_consumption_tn05_mcp10.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_95ecc_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_95ecc_row4_col1" class="data row4 col1" >minimal_with_fuel_consumption_tn10_mcp00.10.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_95ecc_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_95ecc_row5_col1" class="data row5 col1" >minimal_with_fuel_consumption_tn10_mcp01.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_95ecc_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_95ecc_row6_col1" class="data row6 col1" >minimal_with_fuel_consumption_tn10_mcp05.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_95ecc_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_95ecc_row7_col1" class="data row7 col1" >minimal_with_fuel_consumption_tn10_mcp10.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_95ecc_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_95ecc_row8_col1" class="data row8 col1" >minimal_with_fuel_consumption_tn15_mcp00.10.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_95ecc_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_95ecc_row9_col1" class="data row9 col1" >minimal_with_fuel_consumption_tn15_mcp01.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_95ecc_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_95ecc_row10_col1" class="data row10 col1" >minimal_with_fuel_consumption_tn15_mcp05.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_95ecc_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_95ecc_row11_col1" class="data row11 col1" >minimal_with_fuel_consumption_tn15_mcp10.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_95ecc_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_95ecc_row12_col1" class="data row12 col1" >minimal_with_fuel_consumption_tn20_mcp00.10.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_95ecc_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_95ecc_row13_col1" class="data row13 col1" >minimal_with_fuel_consumption_tn20_mcp01.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_95ecc_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_95ecc_row14_col1" class="data row14 col1" >minimal_with_fuel_consumption_tn20_mcp05.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_95ecc_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_95ecc_row15_col1" class="data row15 col1" >minimal_with_fuel_consumption_tn20_mcp10.00.parquet</td>
#     </tr>
#     <tr>
#       <th id="T_95ecc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_95ecc_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_95ecc_row16_col1" class="data row16 col1" >minimal_without_fuel_consumption_tn05_mcp00.10.par

# %%
# 2. Choose and load dataset by number
df = load_data_by_number(72)
# Out:
# Loaded parquet file from local path.
# Loaded file: 'minimal_withoutfc_dupesdropped_frequencies_area_removedskew_outliers3_0_NoW_runagain_tn20_mcp00.10.parquet'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000450 entries, 0 to 2000449
# Data columns (total 56 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Mt                            float32
#  1   Ewltp (g/km)                  float32
#  2   At1 (mm)                      float32
#  3   ec (cm3)                      float32
#  4   ep (KW)                       float32
#  5   Mh_AUDI AG                    uint8
#  6   Mh_AUTOMOBILES CITROEN        uint8
#  7   Mh_AUTOMOBILES PEUGEOT        uint8
#  8   Mh_BMW AG                     uint8
#  9   Mh_DACIA                      uint8
#  10  Mh_FIAT GROUP                 uint8
#  11  Mh_FORD WERKE GMBH            uint8
#  12  Mh_JAGUAR LAND ROVER LIMITED  uint8
#  13  Mh_MERCEDES-BENZ AG           uint8
#  14  Mh_OPEL AUTOMOBILE            uint8
#  15  Mh_PORSCHE                    uint8
#  16  Mh_PSA                        uint8
#  17  Mh_RENAULT                    uint8
#  18  Mh_SEAT                       uint8
#  19  Mh_SKODA                      uint8
#  20  Mh_TOYOTA                     uint8
#  21  Mh_VOLKSWAGEN                 uint8
#  22  Mh_VOLVO                      uint8
#  23  Mh_Other                      uint8
#  24  Ct_M1G                        uint8
#  25  Ct_Other                      uint8
#  26  Ft_E85                        uint8
#  27  Ft_LPG                        uint8
#  28  Ft_NG-BIOMETHANE              uint8
#  29  Ft_PETROL                     uint8
#  30  Fm_H                          uint8
#  31  Fm_M                          uint8
#  32  Fm_Other                      uint8
#  33  IT_code_Other                 int32
#  34  IT_code_e1 2                  int32
#  35  IT_code_e1 29                 int32
#  36  IT_code_e13 17                int32
#  37  IT_code_e13 19                int32
#  38  IT_code_e13 28                int32
#  39  IT_code_e13 29                int32
#  40  IT_code_e13 37                int32
#  41  IT_code_e2 17                 int32
#  42  IT_code_e2 29                 int32
#  43  IT_code_e24 17                int32
#  44  IT_code_e24 19                int32
#  45  IT_code_e24 28                int32
#  46  IT_code_e24 29                int32
#  47  IT_code_e24 3                 int32
#  48  IT_code_e24 37                int32
#  49  IT_code_e8 19                 int32
#  50  IT_code_e8 29                 int32
#  51  IT_code_e8 37                 int32
#  52  IT_code_e9 29                 int32
#  53  IT_code_e9 37                 int32
#  54  frequency                     int32
#  55  Area (m2)                     float32
# dtypes: float32(6), int32(22), uint8(28)
# memory usage: 282.4 MB
